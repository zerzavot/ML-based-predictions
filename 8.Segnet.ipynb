# %% [markdown]
# # SegNet

# %% [markdown]
# #### Google Colab Doğrulama
#
# 3 tane datasetimiz var. Onlara ulaşabilmek adına doğrulama işlemlerini gerçekleştiriyoruz.

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 145483 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.23-0ubuntu1~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.23-0ubuntu1~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.23-0ubuntu1~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# Bağlanıp bağlanmadığımız görmek amacıyla drive daki çalışma alanımızın içindekileri listele komutunu çalıştırıyoruz.

# %%
ls "/content/drive/My Drive/CT"
# Out:
# checkpoint    denseNet_model_78.h5               my_model_fra.h5  transfer/
# covid/        earlystop_model.h5                 non-covid/       works/
# COVID/        model.h5                           NonCOVID/
# CT_COVID/     model_weights.data-00000-of-00001  Normalize/
# CT_NonCOVID/  model_weights.index                saved_models/

# %% [markdown]
# #### Kütüphaneler

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import cv2
import os
from tqdm import tqdm
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from keras.models import Model,Sequential, Input, load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.applications import DenseNet121, MobileNetV2


from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import numpy as np

from keras.callbacks import ModelCheckpoint, EarlyStopping

# %% [markdown]
# Normalize edilmiş değerleri önceki ipynb dosyamızda npy olarak kaydetmiştik. Bu aşama, işlemlerimizi hızlandırmak için yapıldı. numpy kütüphanesinden load() metodunu çağırarak normalize olmuş datamızı kullanmaya başlayabiliriz.

# %%
a= "/content/drive/My Drive/CT/Normalize/"

#300 veri bulunan dataset
l1x=a+ "X_nparray300.npy"
l1y=a+ "y_nparray300.npy"

#1200 veri bulunan dataset
l2x=a+ "X_nparray1200.npy"
l2y=a+ "y_nparray1200.npy"

#3000 veri bulunan dataset
l3x=a+ "X_nparray3000.npy"
l3y=a+ "y_nparray3000.npy"

loaded_array_x1200 = np.load(l2x)
loaded_array_y1200 = np.load(l2y)

# %%
X=loaded_array_x1200
y=loaded_array_y1200

# %% [markdown]
# Datamızın doğru yüklendiğine emin olmak için shape metodunu kullanarak inceliyoruz.

# %%
print("Shape of input data: {} and shape of target variable: {}".format(X.shape, y.shape))
# Out:
# Shape of input data: (2481, 64, 64, 3) and shape of target variable: (2481, 2)

# %%
SEED= 42

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3, random_state=SEED)

# %% [markdown]
# Verisetimiz üzerinde kaç tane forward ve backward propagation yapılacağını ayarladığımız apoch sayımızı 50,100 ve 200 vereceğiz.
#
# Tüm veri kümesini aynı anda sinir ağına veremeyeceğimiz için dataseti parçalara böleriz. Yani batch size olarak adlandırdığımız bu hiperparametre üzerinde çalışılacak bir parti örneğin miktarını bize söyler. Burada 64'er adet image lar halinde modelimize göndereceğiz.

# %%
EPOCHS = 100
# 50, 100, 200
SIZE=64
N_ch=3
BATCH_SIZE = 64
SEED= 42

IMG_W= 64
IMG_H= 64
CHANNELS = 3

INPUT_SHAPE=(IMG_W, IMG_H, CHANNELS)

# %%
from keras.applications.densenet import DenseNet169, preprocess_input
import keras
import tensorflow as tf
from keras.layers.core import  Activation, Reshape, Permute
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import  UpSampling2D, ZeroPadding2D
from keras import models
from keras.layers import Conv2D, InputLayer, MaxPool2D
from keras import optimizers
from keras.layers import Conv2D, MaxPooling2D

sgd = optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)


def build_segnet( input_height=64, input_width=64):
    kernel = 3
    filter_size = 64
    pad = 1
    pool_size = 2
    SIZE=64
    N_ch=3

    #model = models.Sequential()
    input = Input(shape=(SIZE, SIZE, N_ch))
    x = Conv2D(3, (3, 3), padding='same')(input)
    

    #ben encoder
   
    x = Conv2D(64, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(strides=(2, 2), padding='same')(x)

    x = Conv2D(64*2, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(64*2, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(strides=(2, 2), padding='same')(x)

    
    x = Conv2D(64*4, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(64*4, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(64*4, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D( strides=(2, 2), padding='same')(x)

   
    x = Conv2D(64*8, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(64*8, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(64*8, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D( strides=(2, 2), padding='same')(x)

    x=UpSampling2D()(x)
    x = Conv2D(64*8, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(64*8, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(64*8, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Activation('relu')(x)

    x=UpSampling2D()(x)
    x = Conv2D(64*8, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(64*8, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Activation('relu')(x)
    x = Conv2D(64*4, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x=UpSampling2D()(x)
    x = Conv2D(64*4, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(64*4, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(64*2, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x=UpSampling2D()(x)
    x = Conv2D(64*2, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(64, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x=UpSampling2D()(x)
    x = Conv2D(64, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

   
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # binary output
    output = Dense(2,activation = 'sigmoid', name='root')(x)

    model = Model(input,output)

    # model.summary()
    # --------------------------------------------
    


    model.compile(loss="binary_crossentropy", optimizer=sgd, metrics=['accuracy'] )
    model.summary()
    return model

# %%
input_height = 64
input_width = 64
epochs = 7


model = build_segnet( input_height=input_height, input_width=input_width)
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 64, 64, 3)         84
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 64)        1792
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64, 64, 64)        256
# _________________________________________________________________
# activation (Activation)      (None, 64, 64, 64)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 128)       73856
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 128)       512
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 128)       147584
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 128)       512
# _________________________________________________________________
# activation_2 (Activation)    (None, 32, 32, 128)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 256)       295168
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 256)       1024
# _________________________________________________________________
# activation_3 (Activation)    (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 256)       590080
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 16, 16, 256)       1024
# _________________________________________________________________
# activation_4 (Activation)    (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 16, 256)       590080
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 16, 16, 256)       1024
# _________________________________________________________________
# activation_5 (Activation)    (None, 16, 16, 256)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 8, 8, 512)         1180160
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_6 (Activation)    (None, 8, 8, 512)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 8, 8, 512)         2359808
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_7 (Activation)    (None, 8, 8, 512)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 8, 8, 512)         2359808
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_8 (Activation)    (None, 8, 8, 512)         0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 512)         0
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 8, 8, 512)         0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 8, 8, 512)         2359808
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_9 (Activation)    (None, 8, 8, 512)         0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 8, 8, 512)         2359808
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 8, 8, 512)         2048
# _________________________________________________________________
# activation_10 (Activation)   (None, 8, 8, 512)         0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 8, 8, 512)         2359808
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 8, 8, 512)         2048
# _________________________________________________________________
# dropout (Dropout)            (None, 8, 8, 512)         0
# _________________________________________________________________
# activation_11 (Activation)   (None, 8, 8, 512)         0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 16, 16, 512)       0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 16, 16, 512)       2359808
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 16, 16, 512)       2048
# _________________________________________________________________
# activation_12 (Activation)   (None, 16, 16, 512)       0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 16, 16, 512)       2359808
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 16, 16, 512)       2048
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 16, 512)       0
# _________________________________________________________________
# activation_13 (Activation)   (None, 16, 16, 512)       0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 16, 16, 256)       1179904
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 16, 16, 256)       1024
# _________________________________________________________________
# activation_14 (Activation)   (None, 16, 16, 256)       0
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 32, 32, 256)       590080
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 32, 32, 256)       1024
# _________________________________________________________________
# activation_15 (Activation)   (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 32, 32, 256)       590080
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 32, 32, 256)       1024
# _________________________________________________________________
# activation_16 (Activation)   (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 32, 32, 128)       295040
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 32, 32, 128)       512
# _________________________________________________________________
# activation_17 (Activation)   (None, 32, 32, 128)       0
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 64, 64, 128)       0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 64, 64, 128)       147584
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 64, 64, 128)       512
# _________________________________________________________________
# activation_18 (Activation)   (None, 64, 64, 128)       0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 64, 64, 64)        73792
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 64, 64, 64)        256
# _________________________________________________________________
# activation_19 (Activation)   (None, 64, 64, 64)        0
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 128, 128, 64)      0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 128, 128, 64)      36928
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 128, 128, 64)      256
# _________________________________________________________________
# activation_20 (Activation)   (None, 128, 128, 64)      0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 64)                0
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 64)                256
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 256)               16640
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 256)               1024
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# root (Dense)                 (None, 2)                 514
# =================================================================
# Total params: 22,354,646
# Trainable params: 22,341,334
# Non-trainable params: 13,312
# _________________________________________________________________

# %%
datagen = ImageDataGenerator(rotation_range=360, # rotasyon
                        width_shift_range=0.2, # yatayda shift
                        height_shift_range=0.2, # dikeyde kayma
                        zoom_range=0.2, # büyültme
                        horizontal_flip=True, # yatayda çevirme
                        vertical_flip=True)  #dikeyde çevirme

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold, train_test_split, cross_val_predict, cross_val_score
from sklearn import metrics
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import median_absolute_error



annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
checkpoint = ModelCheckpoint('model_CNN2.h5', verbose=1, save_best_only=True)



datagen.fit(X_train)

hist = model.fit_generator(datagen.flow(X_train, y_train, batch_size=BATCH_SIZE),
               steps_per_epoch=X_train.shape[0] // BATCH_SIZE,
               epochs=EPOCHS,
               verbose=2,
               callbacks=[annealer, checkpoint],
               validation_data=(X_val, y_val))
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 27/27 - 18s - loss: 0.7593 - accuracy: 0.6681 - val_loss: 275.3633 - val_accuracy: 0.4980
#
# Epoch 00001: val_loss improved from inf to 275.36328, saving model to model_CNN2.h5
# Epoch 2/100
# 27/27 - 6s - loss: 0.5820 - accuracy: 0.7536 - val_loss: 28.7574 - val_accuracy: 0.4980
#
# Epoch 00002: val_loss improved from 275.36328 to 28.75738, saving model to model_CNN2.h5
# Epoch 3/100
# 27/27 - 6s - loss: 0.5387 - accuracy: 0.7476 - val_loss: 13.6505 - val_accuracy: 0.4980
#
# Epoch 00003: val_loss improved from 28.75738 to 13.65051, saving model to model_CNN2.h5
# Epoch 4/100
# 27/27 - 6s - loss: 0.4687 - accuracy: 0.7703 - val_loss: 17.5340 - val_accuracy: 0.4980
#
# Epoch 00004: val_loss did not improve from 13.65051
# Epoch 5/100
# 27/27 - 6s - loss: 0.5078 - accuracy: 0.7572 - val_loss: 125.6393 - val_accuracy: 0.4980
#
# Epoch 00005: val_loss did not improve from 13.65051
# Epoch 6/100
# 27/27 - 6s - loss: 0.4516 - accuracy: 0.7757 - val_loss: 14.6568 - val_accuracy: 0.4980
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
#
# Epoch 00006: val_loss did not improve from 13.65051
# Epoch 7/100
# 27/27 - 6s - loss: 0.4009 - accuracy: 0.8032 - val_loss: 3.3066 - val_accuracy: 0.5101
#
# Epoch 00007: val_loss improved from 13.65051 to 3.30663, saving model to model_CNN2.h5
# Epoch 8/100
# 27/27 - 6s - loss: 0.4150 - accuracy: 0.8032 - val_loss: 0.7726 - val_accuracy: 0.6846
#
# Epoch 00008: val_loss improved from 3.30663 to 0.77262, saving model to model_CNN2.h5
# Epoch 9/100
# 27/27 - 6s - loss: 0.4227 - accuracy: 0.7925 - val_loss: 0.5136 - val_accuracy: 0.7745
#
# Epoch 00009: val_loss improved from 0.77262 to 0.51355, saving model to model_CNN2.h5
# Epoch 10/100
# 27/27 - 6s - loss: 0.4926 - accuracy: 0.7590 - val_loss: 0.7925 - val_accuracy: 0.6121
#
# Epoch 00010: val_loss did not improve from 0.51355
# Epoch 11/100
# 27/27 - 6s - loss: 0.4513 - accuracy: 0.7769 - val_loss: 0.5731 - val_accuracy: 0.7785
#
# Epoch 00011: val_loss did not improve from 0.51355
# Epoch 12/100
# 27/27 - 6s - loss: 0.4040 - accuracy: 0.8020 - val_loss: 0.5263 - val_accuracy: 0.7946
#
# Epoch 00012: val_loss did not improve from 0.51355
# Epoch 13/100
# 27/27 - 6s - loss: 0.3954 - accuracy: 0.8116 - val_loss: 0.5469 - val_accuracy: 0.7987
#
# Epoch 00013: val_loss did not improve from 0.51355
# Epoch 14/100
# 27/27 - 6s - loss: 0.4245 - accuracy: 0.7949 - val_loss: 0.4522 - val_accuracy: 0.7852
#
# Epoch 00014: val_loss improved from 0.51355 to 0.45222, saving model to model_CNN2.h5
# Epoch 15/100
# 27/27 - 6s - loss: 0.3933 - accuracy: 0.8224 - val_loss: 0.4964 - val_accuracy: 0.7705
#
# Epoch 00015: val_loss did not improve from 0.45222
# Epoch 16/100
# 27/27 - 6s - loss: 0.3774 - accuracy: 0.8248 - val_loss: 0.3745 - val_accuracy: 0.8148
#
# Epoch 00016: val_loss improved from 0.45222 to 0.37448, saving model to model_CNN2.h5
# Epoch 17/100
# 27/27 - 6s - loss: 0.3701 - accuracy: 0.8188 - val_loss: 0.3339 - val_accuracy: 0.8362
#
# Epoch 00017: val_loss improved from 0.37448 to 0.33390, saving model to model_CNN2.h5
# Epoch 18/100
# 27/27 - 6s - loss: 0.3834 - accuracy: 0.8104 - val_loss: 0.5022 - val_accuracy: 0.8067
#
# Epoch 00018: val_loss did not improve from 0.33390
# Epoch 19/100
# 27/27 - 6s - loss: 0.3849 - accuracy: 0.8164 - val_loss: 0.4292 - val_accuracy: 0.7973
#
# Epoch 00019: val_loss did not improve from 0.33390
# Epoch 20/100
# 27/27 - 6s - loss: 0.3735 - accuracy: 0.8170 - val_loss: 0.7029 - val_accuracy: 0.7758
#
# Epoch 00020: val_loss did not improve from 0.33390
# Epoch 21/100
# 27/27 - 6s - loss: 0.3631 - accuracy: 0.8283 - val_loss: 0.5501 - val_accuracy: 0.7436
#
# Epoch 00021: val_loss did not improve from 0.33390
# Epoch 22/100
# 27/27 - 6s - loss: 0.3883 - accuracy: 0.8116 - val_loss: 0.5376 - val_accuracy: 0.8027
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
#
# Epoch 00022: val_loss did not improve from 0.33390
# Epoch 23/100
# 27/27 - 6s - loss: 0.3467 - accuracy: 0.8289 - val_loss: 0.5339 - val_accuracy: 0.8121
#
# Epoch 00023: val_loss did not improve from 0.33390
# Epoch 24/100
# 27/27 - 6s - loss: 0.3516 - accuracy: 0.8373 - val_loss: 0.3939 - val_accuracy: 0.8389
#
# Epoch 00024: val_loss did not improve from 0.33390
# Epoch 25/100
# 27/27 - 6s - loss: 0.3614 - accuracy: 0.8152 - val_loss: 0.4361 - val_accuracy: 0.8081
#
# Epoch 00025: val_loss did not improve from 0.33390
# Epoch 26/100
# 27/27 - 6s - loss: 0.3361 - accuracy: 0.8379 - val_loss: 0.9248 - val_accuracy: 0.7034
#
# Epoch 00026: val_loss did not improve from 0.33390
# Epoch 27/100
# 27/27 - 6s - loss: 0.3638 - accuracy: 0.8301 - val_loss: 0.4998 - val_accuracy: 0.7919
#
# Epoch 00027: val_loss did not improve from 0.33390
# Epoch 28/100
# 27/27 - 6s - loss: 0.3458 - accuracy: 0.8331 - val_loss: 0.4393 - val_accuracy: 0.8201
#
# Epoch 00028: val_loss did not improve from 0.33390
# Epoch 29/100
# 27/27 - 6s - loss: 0.3418 - accuracy: 0.8339 - val_loss: 0.5728 - val_accuracy: 0.7933
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
#
# Epoch 00029: val_loss did not improve from 0.33390
# Epoch 30/100
# 27/27 - 6s - loss: 0.3362 - accuracy: 0.8272 - val_loss: 0.5584 - val_accuracy: 0.7906
#
# Epoch 00030: val_loss did not improve from 0.33390
# Epoch 31/100
# 27/27 - 6s - loss: 0.3257 - accuracy: 0.8433 - val_loss: 0.4400 - val_accuracy: 0.8215
#
# Epoch 00031: val_loss did not improve from 0.33390
# Epoch 32/100
# 27/27 - 6s - loss: 0.3256 - accuracy: 0.8361 - val_loss: 0.4643 - val_accuracy: 0.8161
#
# Epoch 00032: val_loss did not improve from 0.33390
# Epoch 33/100
# 27/27 - 6s - loss: 0.3329 - accuracy: 0.8415 - val_loss: 0.3153 - val_accuracy: 0.8430
#
# Epoch 00033: val_loss improved from 0.33390 to 0.31527, saving model to model_CNN2.h5
# Epoch 34/100
# 27/27 - 6s - loss: 0.3827 - accuracy: 0.8343 - val_loss: 0.2990 - val_accuracy: 0.8510
#
# Epoch 00034: val_loss improved from 0.31527 to 0.29902, saving model to model_CNN2.h5
# Epoch 35/100
# 27/27 - 6s - loss: 0.3359 - accuracy: 0.8427 - val_loss: 0.3005 - val_accuracy: 0.8470
#
# Epoch 00035: val_loss did not improve from 0.29902
# Epoch 36/100
# 27/27 - 6s - loss: 0.3231 - accuracy: 0.8469 - val_loss: 0.2860 - val_accuracy: 0.8577
#
# Epoch 00036: val_loss improved from 0.29902 to 0.28603, saving model to model_CNN2.h5
# Epoch 37/100
# 27/27 - 6s - loss: 0.3360 - accuracy: 0.8433 - val_loss: 0.2911 - val_accuracy: 0.8658
#
# Epoch 00037: val_loss did not improve from 0.28603
# Epoch 38/100
# 27/27 - 6s - loss: 0.3105 - accuracy: 0.8469 - val_loss: 0.3302 - val_accuracy: 0.8604
#
# Epoch 00038: val_loss did not improve from 0.28603
# Epoch 39/100
# 27/27 - 6s - loss: 0.3144 - accuracy: 0.8499 - val_loss: 0.3135 - val_accuracy: 0.8550
#
# Epoch 00039: val_loss did not improve from 0.28603
# Epoch 40/100
# 27/27 - 6s - loss: 0.3128 - accuracy: 0.8487 - val_loss: 0.4846 - val_accuracy: 0.8215
#
# Epoch 00040: val_loss did not improve from 0.28603
# Epoch 41/100
# 27/27 - 6s - loss: 0.3337 - accuracy: 0.8439 - val_loss: 0.3551 - val_accuracy: 0.8644
#
# Epoch 00041: val_loss did not improve from 0.28603
# Epoch 42/100
# 27/27 - 6s - loss: 0.3235 - accuracy: 0.8451 - val_loss: 0.2929 - val_accuracy: 0.8738
#
# Epoch 00042: val_loss did not improve from 0.28603
# Epoch 43/100
# 27/27 - 6s - loss: 0.3219 - accuracy: 0.8541 - val_loss: 0.2698 - val_accuracy: 0.8725
#
# Epoch 00043: val_loss improved from 0.28603 to 0.26980, saving model to model_CNN2.h5
# Epoch 44/100
# 27/27 - 6s - loss: 0.3268 - accuracy: 0.8487 - val_loss: 0.2911 - val_accuracy: 0.8591
#
# Epoch 00044: val_loss did not improve from 0.26980
# Epoch 45/100
# 27/27 - 6s - loss: 0.3250 - accuracy: 0.8529 - val_loss: 0.6690 - val_accuracy: 0.7544
#
# Epoch 00045: val_loss did not improve from 0.26980
# Epoch 46/100
# 27/27 - 6s - loss: 0.3228 - accuracy: 0.8475 - val_loss: 0.4571 - val_accuracy: 0.8027
#
# Epoch 00046: val_loss did not improve from 0.26980
# Epoch 47/100
# 27/27 - 6s - loss: 0.3362 - accuracy: 0.8409 - val_loss: 0.3524 - val_accuracy: 0.8242
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00047: val_loss did not improve from 0.26980
# Epoch 48/100
# 27/27 - 6s - loss: 0.2977 - accuracy: 0.8589 - val_loss: 0.6660 - val_accuracy: 0.7450
#
# Epoch 00048: val_loss did not improve from 0.26980
# Epoch 49/100
# 27/27 - 6s - loss: 0.2955 - accuracy: 0.8660 - val_loss: 0.6290 - val_accuracy: 0.7557
#
# Epoch 00049: val_loss did not improve from 0.26980
# Epoch 50/100
# 27/27 - 6s - loss: 0.2984 - accuracy: 0.8696 - val_loss: 0.5226 - val_accuracy: 0.7852
#
# Epoch 00050: val_loss did not improve from 0.26980
# Epoch 51/100
# 27/27 - 6s - loss: 0.3083 - accuracy: 0.8612 - val_loss: 0.2966 - val_accuracy: 0.8765
#
# Epoch 00051: val_loss did not improve from 0.26980
# Epoch 52/100
# 27/27 - 6s - loss: 0.3049 - accuracy: 0.8612 - val_loss: 0.3315 - val_accuracy: 0.8336
#
# Epoch 00052: val_loss did not improve from 0.26980
# Epoch 53/100
# 27/27 - 6s - loss: 0.3004 - accuracy: 0.8600 - val_loss: 0.3618 - val_accuracy: 0.8282
#
# Epoch 00053: val_loss did not improve from 0.26980
# Epoch 54/100
# 27/27 - 6s - loss: 0.2989 - accuracy: 0.8696 - val_loss: 0.6506 - val_accuracy: 0.7396
#
# Epoch 00054: val_loss did not improve from 0.26980
# Epoch 55/100
# 27/27 - 6s - loss: 0.2867 - accuracy: 0.8726 - val_loss: 0.7217 - val_accuracy: 0.7530
#
# Epoch 00055: val_loss did not improve from 0.26980
# Epoch 56/100
# 27/27 - 6s - loss: 0.2944 - accuracy: 0.8672 - val_loss: 0.4622 - val_accuracy: 0.8107
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00056: val_loss did not improve from 0.26980
# Epoch 57/100
# 27/27 - 6s - loss: 0.2887 - accuracy: 0.8756 - val_loss: 0.6006 - val_accuracy: 0.7611
#
# Epoch 00057: val_loss did not improve from 0.26980
# Epoch 58/100
# 27/27 - 6s - loss: 0.2801 - accuracy: 0.8756 - val_loss: 0.3126 - val_accuracy: 0.8483
#
# Epoch 00058: val_loss did not improve from 0.26980
# Epoch 59/100
# 27/27 - 6s - loss: 0.2909 - accuracy: 0.8684 - val_loss: 0.3427 - val_accuracy: 0.8336
#
# Epoch 00059: val_loss did not improve from 0.26980
# Epoch 60/100
# 27/27 - 6s - loss: 0.2844 - accuracy: 0.8762 - val_loss: 0.2696 - val_accuracy: 0.8738
#
# Epoch 00060: val_loss improved from 0.26980 to 0.26958, saving model to model_CNN2.h5
# Epoch 61/100
# 27/27 - 6s - loss: 0.2872 - accuracy: 0.8738 - val_loss: 0.6927 - val_accuracy: 0.7450
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00061: val_loss did not improve from 0.26958
# Epoch 62/100
# 27/27 - 6s - loss: 0.2827 - accuracy: 0.8816 - val_loss: 0.2376 - val_accuracy: 0.8940
#
# Epoch 00062: val_loss improved from 0.26958 to 0.23757, saving model to model_CNN2.h5
# Epoch 63/100
# 27/27 - 6s - loss: 0.2918 - accuracy: 0.8744 - val_loss: 0.2594 - val_accuracy: 0.8779
#
# Epoch 00063: val_loss did not improve from 0.23757
# Epoch 64/100
# 27/27 - 6s - loss: 0.2750 - accuracy: 0.8762 - val_loss: 0.2860 - val_accuracy: 0.8658
#
# Epoch 00064: val_loss did not improve from 0.23757
# Epoch 65/100
# 27/27 - 6s - loss: 0.2891 - accuracy: 0.8666 - val_loss: 0.2742 - val_accuracy: 0.8577
#
# Epoch 00065: val_loss did not improve from 0.23757
# Epoch 66/100
# 27/27 - 6s - loss: 0.2670 - accuracy: 0.8858 - val_loss: 0.5107 - val_accuracy: 0.7852
#
# Epoch 00066: val_loss did not improve from 0.23757
# Epoch 67/100
# 27/27 - 6s - loss: 0.2616 - accuracy: 0.8804 - val_loss: 1.2085 - val_accuracy: 0.6470
#
# Epoch 00067: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00067: val_loss did not improve from 0.23757
# Epoch 68/100
# 27/27 - 6s - loss: 0.2529 - accuracy: 0.8900 - val_loss: 0.8834 - val_accuracy: 0.7195
#
# Epoch 00068: val_loss did not improve from 0.23757
# Epoch 69/100
# 27/27 - 6s - loss: 0.2672 - accuracy: 0.8786 - val_loss: 0.2702 - val_accuracy: 0.8859
#
# Epoch 00069: val_loss did not improve from 0.23757
# Epoch 70/100
# 27/27 - 6s - loss: 0.2499 - accuracy: 0.8906 - val_loss: 0.4254 - val_accuracy: 0.8027
#
# Epoch 00070: val_loss did not improve from 0.23757
# Epoch 71/100
# 27/27 - 6s - loss: 0.2644 - accuracy: 0.8906 - val_loss: 1.8618 - val_accuracy: 0.5490
#
# Epoch 00071: val_loss did not improve from 0.23757
# Epoch 72/100
# 27/27 - 6s - loss: 0.2538 - accuracy: 0.8858 - val_loss: 1.2170 - val_accuracy: 0.6148
#
# Epoch 00072: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00072: val_loss did not improve from 0.23757
# Epoch 73/100
# 27/27 - 6s - loss: 0.2469 - accuracy: 0.8756 - val_loss: 2.2298 - val_accuracy: 0.5342
#
# Epoch 00073: val_loss did not improve from 0.23757
# Epoch 74/100
# 27/27 - 6s - loss: 0.2643 - accuracy: 0.8816 - val_loss: 2.2026 - val_accuracy: 0.5302
#
# Epoch 00074: val_loss did not improve from 0.23757
# Epoch 75/100
# 27/27 - 6s - loss: 0.2493 - accuracy: 0.8935 - val_loss: 3.2163 - val_accuracy: 0.5034
#
# Epoch 00075: val_loss did not improve from 0.23757
# Epoch 76/100
# 27/27 - 6s - loss: 0.2538 - accuracy: 0.8876 - val_loss: 1.1421 - val_accuracy: 0.6242
#
# Epoch 00076: val_loss did not improve from 0.23757
# Epoch 77/100
# 27/27 - 6s - loss: 0.2503 - accuracy: 0.8858 - val_loss: 0.4927 - val_accuracy: 0.7732
#
# Epoch 00077: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00077: val_loss did not improve from 0.23757
# Epoch 78/100
# 27/27 - 6s - loss: 0.2446 - accuracy: 0.8959 - val_loss: 0.2496 - val_accuracy: 0.8779
#
# Epoch 00078: val_loss did not improve from 0.23757
# Epoch 79/100
# 27/27 - 6s - loss: 0.2524 - accuracy: 0.8929 - val_loss: 0.3159 - val_accuracy: 0.8510
#
# Epoch 00079: val_loss did not improve from 0.23757
# Epoch 80/100
# 27/27 - 6s - loss: 0.2628 - accuracy: 0.8870 - val_loss: 0.4378 - val_accuracy: 0.8228
#
# Epoch 00080: val_loss did not improve from 0.23757
# Epoch 81/100
# 27/27 - 6s - loss: 0.2421 - accuracy: 0.8959 - val_loss: 0.1954 - val_accuracy: 0.9235
#
# Epoch 00081: val_loss improved from 0.23757 to 0.19538, saving model to model_CNN2.h5
# Epoch 82/100
# 27/27 - 6s - loss: 0.2273 - accuracy: 0.9043 - val_loss: 0.7993 - val_accuracy: 0.7221
#
# Epoch 00082: val_loss did not improve from 0.19538
# Epoch 83/100
# 27/27 - 6s - loss: 0.2526 - accuracy: 0.8917 - val_loss: 0.6754 - val_accuracy: 0.7450
#
# Epoch 00083: val_loss did not improve from 0.19538
# Epoch 84/100
# 27/27 - 6s - loss: 0.2530 - accuracy: 0.8929 - val_loss: 0.2577 - val_accuracy: 0.8993
#
# Epoch 00084: val_loss did not improve from 0.19538
# Epoch 85/100
# 27/27 - 6s - loss: 0.2637 - accuracy: 0.8882 - val_loss: 1.1731 - val_accuracy: 0.6148
#
# Epoch 00085: val_loss did not improve from 0.19538
# Epoch 86/100
# 27/27 - 6s - loss: 0.2513 - accuracy: 0.8906 - val_loss: 0.6064 - val_accuracy: 0.7624
#
# Epoch 00086: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00086: val_loss did not improve from 0.19538
# Epoch 87/100
# 27/27 - 6s - loss: 0.2254 - accuracy: 0.8995 - val_loss: 0.4307 - val_accuracy: 0.8027
#
# Epoch 00087: val_loss did not improve from 0.19538
# Epoch 88/100
# 27/27 - 6s - loss: 0.2363 - accuracy: 0.8959 - val_loss: 0.8888 - val_accuracy: 0.6886
#
# Epoch 00088: val_loss did not improve from 0.19538
# Epoch 89/100
# 27/27 - 6s - loss: 0.2457 - accuracy: 0.8911 - val_loss: 0.6710 - val_accuracy: 0.7383
#
# Epoch 00089: val_loss did not improve from 0.19538
# Epoch 90/100
# 27/27 - 6s - loss: 0.2343 - accuracy: 0.9013 - val_loss: 0.7750 - val_accuracy: 0.7490
#
# Epoch 00090: val_loss did not improve from 0.19538
# Epoch 91/100
# 27/27 - 6s - loss: 0.2259 - accuracy: 0.9025 - val_loss: 0.2606 - val_accuracy: 0.8940
#
# Epoch 00091: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00091: val_loss did not improve from 0.19538
# Epoch 92/100
# 27/27 - 6s - loss: 0.2353 - accuracy: 0.8995 - val_loss: 0.3064 - val_accuracy: 0.8819
#
# Epoch 00092: val_loss did not improve from 0.19538
# Epoch 93/100
# 27/27 - 6s - loss: 0.2318 - accuracy: 0.9007 - val_loss: 0.2226 - val_accuracy: 0.8980
#
# Epoch 00093: val_loss did not improve from 0.19538
# Epoch 94/100
# 27/27 - 6s - loss: 0.2417 - accuracy: 0.8876 - val_loss: 2.8915 - val_accuracy: 0.5034
#
# Epoch 00094: val_loss did not improve from 0.19538
# Epoch 95/100
# 27/27 - 6s - loss: 0.2038 - accuracy: 0.9079 - val_loss: 1.1469 - val_accuracy: 0.6430
#
# Epoch 00095: val_loss did not improve from 0.19538
# Epoch 96/100
# 27/27 - 6s - loss: 0.2039 - accuracy: 0.9103 - val_loss: 2.1556 - val_accuracy: 0.5262
#
# Epoch 00096: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00096: val_loss did not improve from 0.19538
# Epoch 97/100
# 27/27 - 6s - loss: 0.2873 - accuracy: 0.8756 - val_loss: 0.7222 - val_accuracy: 0.7087
#
# Epoch 00097: val_loss did not improve from 0.19538
# Epoch 98/100
# 27/27 - 6s - loss: 0.2291 - accuracy: 0.8953 - val_loss: 0.2326 - val_accuracy: 0.8980
#
# Epoch 00098: val_loss did not improve from 0.19538
# Epoch 99/100
# 27/27 - 6s - loss: 0.2108 - accuracy: 0.9079 - val_loss: 1.6369 - val_accuracy: 0.6148
#
# Epoch 00099: val_loss did not improve from 0.19538
# Epoch 100/100
# 27/27 - 6s - loss: 0.2258 - accuracy: 0.9085 - val_loss: 0.2330 - val_accuracy: 0.9074
#
# Epoch 00100: val_loss did not improve from 0.19538

# %%
print("training_accuracy   = ", hist.history['accuracy'][-1])
print("validation_accuracy = ", hist.history['val_accuracy'][-1])
print("training_loss   = ", hist.history['loss'][-1])
print("validation_loss = ", hist.history['val_loss'][-1])
# Out:
# training_accuracy   =  0.9084928035736084
# validation_accuracy =  0.9073825478553772
# training_loss   =  0.2258290797472
# validation_loss =  0.2330327183008194

# %%
# Accuracy ve Loss değerlerinin görselleştirilmeleri

plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy ~ SGD')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss ~ SGD')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from keras.models import Sequential
from keras.layers import Dense

y_pred = np.argmax(model.predict(X_val), axis=-1)
y_test= np.argmax(y_val,axis=1)


# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy: %f' % accuracy)
# precision tp / (tp + fp)
precision = precision_score(y_test, y_pred)
print('Precision: %f' % precision)
# recall: tp / (tp + fn)
recall = recall_score(y_test, y_pred)
print('Recall: %f' % recall)
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(y_test, y_pred)
print('F1 score: %f' % f1)

#kappa
kappa = cohen_kappa_score(y_test, y_pred)
print('Cohens kappa: %f' % kappa)
# ROC AUC
auc = roc_auc_score(y_test, y_pred)
print('ROC AUC: %f' % auc)

# precision
pre=precision_score(y_test, y_pred)
print('Precision =  %.3f'%pre)

# confusion matrix
cf = confusion_matrix(y_test, y_pred)
print(cf)
# Out:
# Accuracy: 0.907383
# Precision: 0.960366
# Recall: 0.849057
# F1 score: 0.901288
# Cohens kappa: 0.814676
# ROC AUC: 0.907149
# Precision =  0.960
# [[361  13]
#  [ 56 315]]

# %%
# R2 & MSE

def scoreResults(model, x_train, x_test, y_train, y_test):

    y_train_predict = model.predict(x_train)
    y_test_predict = model.predict(x_test)

    r2_train = metrics.r2_score(y_train, y_train_predict)
    r2_test = metrics.r2_score(y_test, y_test_predict)

    mse_train = metrics.mean_squared_error(y_train, y_train_predict)
    mse_test = metrics.mean_squared_error(y_test, y_test_predict)



    return [r2_train, r2_test, mse_train, mse_test]

from sklearn import metrics

lr=model
result_lr = scoreResults(model = lr, x_train = X_train, x_test = X_val, y_train = y_train, y_test = y_val)

print(f"Train R2 Score: {result_lr[0]:.4f} MSE: {result_lr[2]:.4f}")
print(f"Test R2 Score: {result_lr[1]:9.4f} MSE: {result_lr[3]:.4f}")
# Out:
# Train R2 Score: 0.7580 MSE: 0.0605
# Test R2 Score:    0.7128 MSE: 0.0718

# %% [markdown]
# ### Karmaşıklık Matrisi

# %%
plt.matshow(cf)
plt.title('Confusion Matrix Plot')
plt.colorbar()
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
class_names = ["Covid","non-covid"]

from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(cm, classes, title='Confusion matrix', cmap=plt.cm.Blues):
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    plt.figure(figsize=(10,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="black" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    
# compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=2)

# plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, title='Normalized confusion matrix')
plt.show()

# %% [markdown]
# #### ROC AUC Score

# %%
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

fp1, tp1, threshold1 = roc_curve(y_test, y_pred)


def plotRoc():
    plt.subplots(1, figsize=(10,10))
    plt.title('Receiver Operating Characteristic - DecisionTree')
    plt.plot(fp1, tp1)
    plt.plot([0, 1], ls="--")
    plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()

print('roc_auc_score for Model: ', roc_auc_score(y_test, y_pred))

plotRoc()
# Out:
# roc_auc_score for Model:  0.9071486227424074
