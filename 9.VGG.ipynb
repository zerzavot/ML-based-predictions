# %% [markdown]
# # VGG

# %% [markdown]
# #### Google Colab Doğrulama
#
# 3 tane datasetimiz var. Onlara ulaşabilmek adına doğrulama işlemlerini gerçekleştiriyoruz.

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 145483 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.23-0ubuntu1~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.23-0ubuntu1~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.23-0ubuntu1~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# Bağlanıp bağlanmadığımız görmek amacıyla drive daki çalışma alanımızın içindekileri listele komutunu çalıştırıyoruz.

# %%
ls "/content/drive/My Drive/CT"
# Out:
# checkpoint    denseNet_model_78.h5               my_model_fra.h5  transfer/
# covid/        earlystop_model.h5                 non-covid/       works/
# COVID/        model.h5                           NonCOVID/
# CT_COVID/     model_weights.data-00000-of-00001  Normalize/
# CT_NonCOVID/  model_weights.index                saved_models/

# %% [markdown]
# #### Kütüphaneler

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import cv2
import os
from tqdm import tqdm
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from keras.models import Model,Sequential, Input, load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.applications import DenseNet121, MobileNetV2


from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import numpy as np

from keras.callbacks import ModelCheckpoint, EarlyStopping

# %% [markdown]
# Normalize edilmiş değerleri önceki ipynb dosyamızda npy olarak kaydetmiştik. Bu aşama, işlemlerimizi hızlandırmak için yapıldı. numpy kütüphanesinden load() metodunu çağırarak normalize olmuş datamızı kullanmaya başlayabiliriz.

# %%
a= "/content/drive/My Drive/CT/Normalize/"

#300 veri bulunan dataset
l1x=a+ "X_nparray300.npy"
l1y=a+ "y_nparray300.npy"

#1200 veri bulunan dataset
l2x=a+ "X_nparray1200.npy"
l2y=a+ "y_nparray1200.npy"

#3000 veri bulunan dataset
l3x=a+ "X_nparray3000.npy"
l3y=a+ "y_nparray3000.npy"

loaded_array_x1200 = np.load(l2x)
loaded_array_y1200 = np.load(l2y)

# %%
X=loaded_array_x1200
y=loaded_array_y1200

# %% [markdown]
# Datamızın doğru yüklendiğine emin olmak için shape metodunu kullanarak inceliyoruz.

# %%
print("Shape of input data: {} and shape of target variable: {}".format(X.shape, y.shape))
# Out:
# Shape of input data: (2481, 64, 64, 3) and shape of target variable: (2481, 2)

# %%
SEED= 42

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3, random_state=SEED)

# %% [markdown]
# Verisetimiz üzerinde kaç tane forward ve backward propagation yapılacağını ayarladığımız apoch sayımızı 50,100 ve 200 vereceğiz.
#
# Tüm veri kümesini aynı anda sinir ağına veremeyeceğimiz için dataseti parçalara böleriz. Yani batch size olarak adlandırdığımız bu hiperparametre üzerinde çalışılacak bir parti örneğin miktarını bize söyler. Burada 64'er adet image lar halinde modelimize göndereceğiz.

# %%
EPOCHS = 100
# 50, 100, 200
SIZE=64
N_ch=3
BATCH_SIZE = 64
SEED= 42

IMG_W= 64
IMG_H= 64
CHANNELS = 3

INPUT_SHAPE=(IMG_W, IMG_H, CHANNELS)

# %%
from keras.applications.densenet import DenseNet169, preprocess_input
import keras
import tensorflow as tf
from keras.layers.core import  Activation, Reshape, Permute
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import  UpSampling2D, ZeroPadding2D
from keras import models
from keras.layers import Conv2D, InputLayer, MaxPool2D
from keras import optimizers
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import  Flatten, Dense, Dropout
from keras.applications import VGG16
from keras.models import Model
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import Dense, GlobalAveragePooling2D
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D



def build_VGG():
  vgg16_model = VGG16(weights = 'imagenet', include_top = False,input_shape=INPUT_SHAPE)
  x = vgg16_model.output
  x = GlobalAveragePooling2D()(x)
  x = BatchNormalization()(x)
  x = Dropout(0.5)(x)
  x = Dense(256, activation='relu')(x)
  x = BatchNormalization()(x)
  x = Dropout(0.5)(x)

  predictions = Dense(2, activation = 'softmax')(x)
  model = Model(vgg16_model.input,predictions)
  for layer in vgg16_model.layers:
      layer.trainable = False
  optimizer = optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
  model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

  model.summary()
  return model

# %%
model = build_VGG()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 64, 64, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 64, 64, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 32, 32, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 32, 32, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 32, 32, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 16, 16, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 16, 16, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 8, 8, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 8, 8, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 2, 2, 512)         0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 512)               0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 14,849,602
# Trainable params: 133,378
# Non-trainable params: 14,716,224
# _________________________________________________________________

# %%
datagen = ImageDataGenerator(rotation_range=360, # rotasyon
                        width_shift_range=0.2, # yatayda shift
                        height_shift_range=0.2, # dikeyde kayma
                        zoom_range=0.2, # büyültme
                        horizontal_flip=True, # yatayda çevirme
                        vertical_flip=True)  #dikeyde çevirme

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold, train_test_split, cross_val_predict, cross_val_score
from sklearn import metrics
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import median_absolute_error



annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
checkpoint = ModelCheckpoint('model_CNN2.h5', verbose=1, save_best_only=True)



datagen.fit(X_train)

hist = model.fit_generator(datagen.flow(X_train, y_train, batch_size=BATCH_SIZE),
               steps_per_epoch=X_train.shape[0] // BATCH_SIZE,
               epochs=EPOCHS,
               verbose=2,
               callbacks=[annealer, checkpoint],
               validation_data=(X_val, y_val))
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 27/27 - 11s - loss: 0.8786 - accuracy: 0.6124 - val_loss: 0.6198 - val_accuracy: 0.7221
#
# Epoch 00001: val_loss improved from inf to 0.61982, saving model to model_CNN2.h5
# Epoch 2/100
# 27/27 - 2s - loss: 0.6940 - accuracy: 0.6687 - val_loss: 0.6061 - val_accuracy: 0.7383
#
# Epoch 00002: val_loss improved from 0.61982 to 0.60607, saving model to model_CNN2.h5
# Epoch 3/100
# 27/27 - 2s - loss: 0.6134 - accuracy: 0.6932 - val_loss: 0.6048 - val_accuracy: 0.7074
#
# Epoch 00003: val_loss improved from 0.60607 to 0.60475, saving model to model_CNN2.h5
# Epoch 4/100
# 27/27 - 2s - loss: 0.5803 - accuracy: 0.6932 - val_loss: 0.5825 - val_accuracy: 0.7302
#
# Epoch 00004: val_loss improved from 0.60475 to 0.58246, saving model to model_CNN2.h5
# Epoch 5/100
# 27/27 - 2s - loss: 0.5779 - accuracy: 0.7045 - val_loss: 0.5843 - val_accuracy: 0.7315
#
# Epoch 00005: val_loss did not improve from 0.58246
# Epoch 6/100
# 27/27 - 2s - loss: 0.5784 - accuracy: 0.7093 - val_loss: 0.5881 - val_accuracy: 0.7208
#
# Epoch 00006: val_loss did not improve from 0.58246
# Epoch 7/100
# 27/27 - 2s - loss: 0.5718 - accuracy: 0.6998 - val_loss: 0.5676 - val_accuracy: 0.7396
#
# Epoch 00007: val_loss improved from 0.58246 to 0.56757, saving model to model_CNN2.h5
# Epoch 8/100
# 27/27 - 2s - loss: 0.5622 - accuracy: 0.7159 - val_loss: 0.5747 - val_accuracy: 0.7114
#
# Epoch 00008: val_loss did not improve from 0.56757
# Epoch 9/100
# 27/27 - 2s - loss: 0.5575 - accuracy: 0.7105 - val_loss: 0.5457 - val_accuracy: 0.7530
#
# Epoch 00009: val_loss improved from 0.56757 to 0.54574, saving model to model_CNN2.h5
# Epoch 10/100
# 27/27 - 2s - loss: 0.5657 - accuracy: 0.7033 - val_loss: 0.5468 - val_accuracy: 0.7517
#
# Epoch 00010: val_loss did not improve from 0.54574
# Epoch 11/100
# 27/27 - 2s - loss: 0.5746 - accuracy: 0.6854 - val_loss: 0.5457 - val_accuracy: 0.7611
#
# Epoch 00011: val_loss improved from 0.54574 to 0.54574, saving model to model_CNN2.h5
# Epoch 12/100
# 27/27 - 2s - loss: 0.5681 - accuracy: 0.7087 - val_loss: 0.5436 - val_accuracy: 0.7329
#
# Epoch 00012: val_loss improved from 0.54574 to 0.54359, saving model to model_CNN2.h5
# Epoch 13/100
# 27/27 - 2s - loss: 0.5366 - accuracy: 0.7368 - val_loss: 0.5610 - val_accuracy: 0.7074
#
# Epoch 00013: val_loss did not improve from 0.54359
# Epoch 14/100
# 27/27 - 2s - loss: 0.5684 - accuracy: 0.7141 - val_loss: 0.5556 - val_accuracy: 0.7168
#
# Epoch 00014: val_loss did not improve from 0.54359
# Epoch 15/100
# 27/27 - 2s - loss: 0.5618 - accuracy: 0.7057 - val_loss: 0.5537 - val_accuracy: 0.7141
#
# Epoch 00015: val_loss did not improve from 0.54359
# Epoch 16/100
# 27/27 - 2s - loss: 0.5540 - accuracy: 0.7117 - val_loss: 0.5239 - val_accuracy: 0.7369
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
#
# Epoch 00016: val_loss improved from 0.54359 to 0.52388, saving model to model_CNN2.h5
# Epoch 17/100
# 27/27 - 2s - loss: 0.5474 - accuracy: 0.7130 - val_loss: 0.5070 - val_accuracy: 0.7691
#
# Epoch 00017: val_loss improved from 0.52388 to 0.50703, saving model to model_CNN2.h5
# Epoch 18/100
# 27/27 - 2s - loss: 0.5513 - accuracy: 0.7249 - val_loss: 0.5005 - val_accuracy: 0.7799
#
# Epoch 00018: val_loss improved from 0.50703 to 0.50052, saving model to model_CNN2.h5
# Epoch 19/100
# 27/27 - 2s - loss: 0.5424 - accuracy: 0.7279 - val_loss: 0.5037 - val_accuracy: 0.7678
#
# Epoch 00019: val_loss did not improve from 0.50052
# Epoch 20/100
# 27/27 - 2s - loss: 0.5547 - accuracy: 0.7075 - val_loss: 0.5129 - val_accuracy: 0.7463
#
# Epoch 00020: val_loss did not improve from 0.50052
# Epoch 21/100
# 27/27 - 2s - loss: 0.5472 - accuracy: 0.7303 - val_loss: 0.5141 - val_accuracy: 0.7450
#
# Epoch 00021: val_loss did not improve from 0.50052
# Epoch 22/100
# 27/27 - 2s - loss: 0.5396 - accuracy: 0.7165 - val_loss: 0.5194 - val_accuracy: 0.7329
#
# Epoch 00022: val_loss did not improve from 0.50052
# Epoch 23/100
# 27/27 - 2s - loss: 0.5332 - accuracy: 0.7362 - val_loss: 0.5373 - val_accuracy: 0.7195
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
#
# Epoch 00023: val_loss did not improve from 0.50052
# Epoch 24/100
# 27/27 - 2s - loss: 0.5394 - accuracy: 0.7213 - val_loss: 0.5316 - val_accuracy: 0.7262
#
# Epoch 00024: val_loss did not improve from 0.50052
# Epoch 25/100
# 27/27 - 2s - loss: 0.5443 - accuracy: 0.7201 - val_loss: 0.5336 - val_accuracy: 0.7248
#
# Epoch 00025: val_loss did not improve from 0.50052
# Epoch 26/100
# 27/27 - 2s - loss: 0.5399 - accuracy: 0.7153 - val_loss: 0.5367 - val_accuracy: 0.7262
#
# Epoch 00026: val_loss did not improve from 0.50052
# Epoch 27/100
# 27/27 - 2s - loss: 0.5441 - accuracy: 0.7201 - val_loss: 0.5230 - val_accuracy: 0.7356
#
# Epoch 00027: val_loss did not improve from 0.50052
# Epoch 28/100
# 27/27 - 2s - loss: 0.5378 - accuracy: 0.7231 - val_loss: 0.5089 - val_accuracy: 0.7544
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
#
# Epoch 00028: val_loss did not improve from 0.50052
# Epoch 29/100
# 27/27 - 2s - loss: 0.5400 - accuracy: 0.7207 - val_loss: 0.5039 - val_accuracy: 0.7544
#
# Epoch 00029: val_loss did not improve from 0.50052
# Epoch 30/100
# 27/27 - 2s - loss: 0.5393 - accuracy: 0.7303 - val_loss: 0.5080 - val_accuracy: 0.7544
#
# Epoch 00030: val_loss did not improve from 0.50052
# Epoch 31/100
# 27/27 - 2s - loss: 0.5302 - accuracy: 0.7386 - val_loss: 0.5038 - val_accuracy: 0.7557
#
# Epoch 00031: val_loss did not improve from 0.50052
# Epoch 32/100
# 27/27 - 2s - loss: 0.5308 - accuracy: 0.7279 - val_loss: 0.5019 - val_accuracy: 0.7570
#
# Epoch 00032: val_loss did not improve from 0.50052
# Epoch 33/100
# 27/27 - 2s - loss: 0.5473 - accuracy: 0.7273 - val_loss: 0.5029 - val_accuracy: 0.7570
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00033: val_loss did not improve from 0.50052
# Epoch 34/100
# 27/27 - 2s - loss: 0.5412 - accuracy: 0.7177 - val_loss: 0.5003 - val_accuracy: 0.7584
#
# Epoch 00034: val_loss improved from 0.50052 to 0.50028, saving model to model_CNN2.h5
# Epoch 35/100
# 27/27 - 2s - loss: 0.5201 - accuracy: 0.7434 - val_loss: 0.5012 - val_accuracy: 0.7597
#
# Epoch 00035: val_loss did not improve from 0.50028
# Epoch 36/100
# 27/27 - 2s - loss: 0.5372 - accuracy: 0.7141 - val_loss: 0.5001 - val_accuracy: 0.7611
#
# Epoch 00036: val_loss improved from 0.50028 to 0.50011, saving model to model_CNN2.h5
# Epoch 37/100
# 27/27 - 2s - loss: 0.5435 - accuracy: 0.7228 - val_loss: 0.4987 - val_accuracy: 0.7597
#
# Epoch 00037: val_loss improved from 0.50011 to 0.49870, saving model to model_CNN2.h5
# Epoch 38/100
# 27/27 - 2s - loss: 0.5319 - accuracy: 0.7315 - val_loss: 0.4984 - val_accuracy: 0.7611
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00038: val_loss improved from 0.49870 to 0.49844, saving model to model_CNN2.h5
# Epoch 39/100
# 27/27 - 2s - loss: 0.5457 - accuracy: 0.7093 - val_loss: 0.4980 - val_accuracy: 0.7638
#
# Epoch 00039: val_loss improved from 0.49844 to 0.49801, saving model to model_CNN2.h5
# Epoch 40/100
# 27/27 - 2s - loss: 0.5303 - accuracy: 0.7243 - val_loss: 0.4959 - val_accuracy: 0.7611
#
# Epoch 00040: val_loss improved from 0.49801 to 0.49587, saving model to model_CNN2.h5
# Epoch 41/100
# 27/27 - 2s - loss: 0.5301 - accuracy: 0.7285 - val_loss: 0.4953 - val_accuracy: 0.7611
#
# Epoch 00041: val_loss improved from 0.49587 to 0.49529, saving model to model_CNN2.h5
# Epoch 42/100
# 27/27 - 2s - loss: 0.5237 - accuracy: 0.7279 - val_loss: 0.4931 - val_accuracy: 0.7584
#
# Epoch 00042: val_loss improved from 0.49529 to 0.49311, saving model to model_CNN2.h5
# Epoch 43/100
# 27/27 - 2s - loss: 0.5364 - accuracy: 0.7207 - val_loss: 0.4923 - val_accuracy: 0.7624
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00043: val_loss improved from 0.49311 to 0.49226, saving model to model_CNN2.h5
# Epoch 44/100
# 27/27 - 2s - loss: 0.5492 - accuracy: 0.7153 - val_loss: 0.4931 - val_accuracy: 0.7664
#
# Epoch 00044: val_loss did not improve from 0.49226
# Epoch 45/100
# 27/27 - 2s - loss: 0.5379 - accuracy: 0.7255 - val_loss: 0.4935 - val_accuracy: 0.7611
#
# Epoch 00045: val_loss did not improve from 0.49226
# Epoch 46/100
# 27/27 - 2s - loss: 0.5343 - accuracy: 0.7303 - val_loss: 0.4939 - val_accuracy: 0.7597
#
# Epoch 00046: val_loss did not improve from 0.49226
# Epoch 47/100
# 27/27 - 2s - loss: 0.5351 - accuracy: 0.7207 - val_loss: 0.4931 - val_accuracy: 0.7638
#
# Epoch 00047: val_loss did not improve from 0.49226
# Epoch 48/100
# 27/27 - 2s - loss: 0.5301 - accuracy: 0.7237 - val_loss: 0.4925 - val_accuracy: 0.7597
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00048: val_loss did not improve from 0.49226
# Epoch 49/100
# 27/27 - 2s - loss: 0.5361 - accuracy: 0.7171 - val_loss: 0.4919 - val_accuracy: 0.7651
#
# Epoch 00049: val_loss improved from 0.49226 to 0.49190, saving model to model_CNN2.h5
# Epoch 50/100
# 27/27 - 2s - loss: 0.5315 - accuracy: 0.7291 - val_loss: 0.4911 - val_accuracy: 0.7732
#
# Epoch 00050: val_loss improved from 0.49190 to 0.49115, saving model to model_CNN2.h5
# Epoch 51/100
# 27/27 - 2s - loss: 0.5312 - accuracy: 0.7434 - val_loss: 0.4920 - val_accuracy: 0.7718
#
# Epoch 00051: val_loss did not improve from 0.49115
# Epoch 52/100
# 27/27 - 2s - loss: 0.5324 - accuracy: 0.7237 - val_loss: 0.4929 - val_accuracy: 0.7691
#
# Epoch 00052: val_loss did not improve from 0.49115
# Epoch 53/100
# 27/27 - 2s - loss: 0.5208 - accuracy: 0.7428 - val_loss: 0.4938 - val_accuracy: 0.7678
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00053: val_loss did not improve from 0.49115
# Epoch 54/100
# 27/27 - 2s - loss: 0.5227 - accuracy: 0.7398 - val_loss: 0.4932 - val_accuracy: 0.7718
#
# Epoch 00054: val_loss did not improve from 0.49115
# Epoch 55/100
# 27/27 - 2s - loss: 0.5492 - accuracy: 0.7093 - val_loss: 0.4927 - val_accuracy: 0.7705
#
# Epoch 00055: val_loss did not improve from 0.49115
# Epoch 56/100
# 27/27 - 2s - loss: 0.5364 - accuracy: 0.7135 - val_loss: 0.4919 - val_accuracy: 0.7745
#
# Epoch 00056: val_loss did not improve from 0.49115
# Epoch 57/100
# 27/27 - 2s - loss: 0.5260 - accuracy: 0.7333 - val_loss: 0.4932 - val_accuracy: 0.7678
#
# Epoch 00057: val_loss did not improve from 0.49115
# Epoch 58/100
# 27/27 - 2s - loss: 0.5223 - accuracy: 0.7422 - val_loss: 0.4916 - val_accuracy: 0.7705
#
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00058: val_loss did not improve from 0.49115
# Epoch 59/100
# 27/27 - 2s - loss: 0.5307 - accuracy: 0.7303 - val_loss: 0.4932 - val_accuracy: 0.7691
#
# Epoch 00059: val_loss did not improve from 0.49115
# Epoch 60/100
# 27/27 - 2s - loss: 0.5304 - accuracy: 0.7327 - val_loss: 0.4920 - val_accuracy: 0.7705
#
# Epoch 00060: val_loss did not improve from 0.49115
# Epoch 61/100
# 27/27 - 2s - loss: 0.5338 - accuracy: 0.7195 - val_loss: 0.4907 - val_accuracy: 0.7691
#
# Epoch 00061: val_loss improved from 0.49115 to 0.49072, saving model to model_CNN2.h5
# Epoch 62/100
# 27/27 - 2s - loss: 0.5412 - accuracy: 0.7273 - val_loss: 0.4900 - val_accuracy: 0.7718
#
# Epoch 00062: val_loss improved from 0.49072 to 0.49001, saving model to model_CNN2.h5
# Epoch 63/100
# 27/27 - 2s - loss: 0.5116 - accuracy: 0.7410 - val_loss: 0.4911 - val_accuracy: 0.7705
#
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00063: val_loss did not improve from 0.49001
# Epoch 64/100
# 27/27 - 2s - loss: 0.5401 - accuracy: 0.7195 - val_loss: 0.4922 - val_accuracy: 0.7691
#
# Epoch 00064: val_loss did not improve from 0.49001
# Epoch 65/100
# 27/27 - 2s - loss: 0.5299 - accuracy: 0.7237 - val_loss: 0.4948 - val_accuracy: 0.7651
#
# Epoch 00065: val_loss did not improve from 0.49001
# Epoch 66/100
# 27/27 - 2s - loss: 0.5406 - accuracy: 0.7147 - val_loss: 0.4962 - val_accuracy: 0.7678
#
# Epoch 00066: val_loss did not improve from 0.49001
# Epoch 67/100
# 27/27 - 2s - loss: 0.5275 - accuracy: 0.7356 - val_loss: 0.4941 - val_accuracy: 0.7638
#
# Epoch 00067: val_loss did not improve from 0.49001
# Epoch 68/100
# 27/27 - 2s - loss: 0.5308 - accuracy: 0.7327 - val_loss: 0.4927 - val_accuracy: 0.7651
#
# Epoch 00068: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00068: val_loss did not improve from 0.49001
# Epoch 69/100
# 27/27 - 2s - loss: 0.5302 - accuracy: 0.7273 - val_loss: 0.4920 - val_accuracy: 0.7678
#
# Epoch 00069: val_loss did not improve from 0.49001
# Epoch 70/100
# 27/27 - 2s - loss: 0.5365 - accuracy: 0.7297 - val_loss: 0.4937 - val_accuracy: 0.7678
#
# Epoch 00070: val_loss did not improve from 0.49001
# Epoch 71/100
# 27/27 - 2s - loss: 0.5337 - accuracy: 0.7153 - val_loss: 0.4946 - val_accuracy: 0.7691
#
# Epoch 00071: val_loss did not improve from 0.49001
# Epoch 72/100
# 27/27 - 2s - loss: 0.5254 - accuracy: 0.7273 - val_loss: 0.4946 - val_accuracy: 0.7651
#
# Epoch 00072: val_loss did not improve from 0.49001
# Epoch 73/100
# 27/27 - 2s - loss: 0.5245 - accuracy: 0.7267 - val_loss: 0.4942 - val_accuracy: 0.7651
#
# Epoch 00073: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00073: val_loss did not improve from 0.49001
# Epoch 74/100
# 27/27 - 2s - loss: 0.5294 - accuracy: 0.7292 - val_loss: 0.4950 - val_accuracy: 0.7651
#
# Epoch 00074: val_loss did not improve from 0.49001
# Epoch 75/100
# 27/27 - 2s - loss: 0.5299 - accuracy: 0.7339 - val_loss: 0.4961 - val_accuracy: 0.7624
#
# Epoch 00075: val_loss did not improve from 0.49001
# Epoch 76/100
# 27/27 - 2s - loss: 0.5322 - accuracy: 0.7333 - val_loss: 0.4959 - val_accuracy: 0.7611
#
# Epoch 00076: val_loss did not improve from 0.49001
# Epoch 77/100
# 27/27 - 2s - loss: 0.5261 - accuracy: 0.7339 - val_loss: 0.4961 - val_accuracy: 0.7597
#
# Epoch 00077: val_loss did not improve from 0.49001
# Epoch 78/100
# 27/27 - 2s - loss: 0.5300 - accuracy: 0.7422 - val_loss: 0.4948 - val_accuracy: 0.7597
#
# Epoch 00078: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00078: val_loss did not improve from 0.49001
# Epoch 79/100
# 27/27 - 2s - loss: 0.5237 - accuracy: 0.7279 - val_loss: 0.4955 - val_accuracy: 0.7557
#
# Epoch 00079: val_loss did not improve from 0.49001
# Epoch 80/100
# 27/27 - 2s - loss: 0.5236 - accuracy: 0.7356 - val_loss: 0.4971 - val_accuracy: 0.7557
#
# Epoch 00080: val_loss did not improve from 0.49001
# Epoch 81/100
# 27/27 - 2s - loss: 0.5358 - accuracy: 0.7261 - val_loss: 0.4983 - val_accuracy: 0.7557
#
# Epoch 00081: val_loss did not improve from 0.49001
# Epoch 82/100
# 27/27 - 2s - loss: 0.5342 - accuracy: 0.7285 - val_loss: 0.4978 - val_accuracy: 0.7557
#
# Epoch 00082: val_loss did not improve from 0.49001
# Epoch 83/100
# 27/27 - 2s - loss: 0.5302 - accuracy: 0.7291 - val_loss: 0.4972 - val_accuracy: 0.7557
#
# Epoch 00083: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00083: val_loss did not improve from 0.49001
# Epoch 84/100
# 27/27 - 2s - loss: 0.5295 - accuracy: 0.7183 - val_loss: 0.4959 - val_accuracy: 0.7584
#
# Epoch 00084: val_loss did not improve from 0.49001
# Epoch 85/100
# 27/27 - 2s - loss: 0.5086 - accuracy: 0.7476 - val_loss: 0.4963 - val_accuracy: 0.7570
#
# Epoch 00085: val_loss did not improve from 0.49001
# Epoch 86/100
# 27/27 - 2s - loss: 0.5342 - accuracy: 0.7213 - val_loss: 0.4978 - val_accuracy: 0.7557
#
# Epoch 00086: val_loss did not improve from 0.49001
# Epoch 87/100
# 27/27 - 2s - loss: 0.5267 - accuracy: 0.7177 - val_loss: 0.4957 - val_accuracy: 0.7584
#
# Epoch 00087: val_loss did not improve from 0.49001
# Epoch 88/100
# 27/27 - 2s - loss: 0.5241 - accuracy: 0.7243 - val_loss: 0.4959 - val_accuracy: 0.7557
#
# Epoch 00088: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00088: val_loss did not improve from 0.49001
# Epoch 89/100
# 27/27 - 2s - loss: 0.5263 - accuracy: 0.7374 - val_loss: 0.4982 - val_accuracy: 0.7517
#
# Epoch 00089: val_loss did not improve from 0.49001
# Epoch 90/100
# 27/27 - 2s - loss: 0.5064 - accuracy: 0.7452 - val_loss: 0.4983 - val_accuracy: 0.7530
#
# Epoch 00090: val_loss did not improve from 0.49001
# Epoch 91/100
# 27/27 - 2s - loss: 0.5246 - accuracy: 0.7303 - val_loss: 0.4977 - val_accuracy: 0.7530
#
# Epoch 00091: val_loss did not improve from 0.49001
# Epoch 92/100
# 27/27 - 2s - loss: 0.5129 - accuracy: 0.7428 - val_loss: 0.4980 - val_accuracy: 0.7530
#
# Epoch 00092: val_loss did not improve from 0.49001
# Epoch 93/100
# 27/27 - 2s - loss: 0.5351 - accuracy: 0.7303 - val_loss: 0.4948 - val_accuracy: 0.7597
#
# Epoch 00093: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00093: val_loss did not improve from 0.49001
# Epoch 94/100
# 27/27 - 2s - loss: 0.5253 - accuracy: 0.7249 - val_loss: 0.4948 - val_accuracy: 0.7584
#
# Epoch 00094: val_loss did not improve from 0.49001
# Epoch 95/100
# 27/27 - 2s - loss: 0.5340 - accuracy: 0.7274 - val_loss: 0.4922 - val_accuracy: 0.7611
#
# Epoch 00095: val_loss did not improve from 0.49001
# Epoch 96/100
# 27/27 - 2s - loss: 0.5302 - accuracy: 0.7327 - val_loss: 0.4902 - val_accuracy: 0.7611
#
# Epoch 00096: val_loss did not improve from 0.49001
# Epoch 97/100
# 27/27 - 2s - loss: 0.5287 - accuracy: 0.7339 - val_loss: 0.4896 - val_accuracy: 0.7624
#
# Epoch 00097: val_loss improved from 0.49001 to 0.48960, saving model to model_CNN2.h5
# Epoch 98/100
# 27/27 - 2s - loss: 0.5338 - accuracy: 0.7243 - val_loss: 0.4900 - val_accuracy: 0.7611
#
# Epoch 00098: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00098: val_loss did not improve from 0.48960
# Epoch 99/100
# 27/27 - 2s - loss: 0.5389 - accuracy: 0.7177 - val_loss: 0.4889 - val_accuracy: 0.7664
#
# Epoch 00099: val_loss improved from 0.48960 to 0.48895, saving model to model_CNN2.h5
# Epoch 100/100
# 27/27 - 2s - loss: 0.5185 - accuracy: 0.7362 - val_loss: 0.4874 - val_accuracy: 0.7691
#
# Epoch 00100: val_loss improved from 0.48895 to 0.48739, saving model to model_CNN2.h5

# %%
print("training_accuracy   = ", hist.history['accuracy'][-1])
print("validation_accuracy = ", hist.history['val_accuracy'][-1])
print("training_loss   = ", hist.history['loss'][-1])
print("validation_loss = ", hist.history['val_loss'][-1])
# Out:
# training_accuracy   =  0.7362440228462219
# validation_accuracy =  0.7691274881362915
# training_loss   =  0.5185303092002869
# validation_loss =  0.48738643527030945

# %%
# Accuracy ve Loss değerlerinin görselleştirilmeleri

plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy ~ SGD')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss ~ SGD')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from keras.models import Sequential
from keras.layers import Dense

y_pred = np.argmax(model.predict(X_val), axis=-1)
y_test= np.argmax(y_val,axis=1)


# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy: %f' % accuracy)
# precision tp / (tp + fp)
precision = precision_score(y_test, y_pred)
print('Precision: %f' % precision)
# recall: tp / (tp + fn)
recall = recall_score(y_test, y_pred)
print('Recall: %f' % recall)
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(y_test, y_pred)
print('F1 score: %f' % f1)

#kappa
kappa = cohen_kappa_score(y_test, y_pred)
print('Cohens kappa: %f' % kappa)
# ROC AUC
auc = roc_auc_score(y_test, y_pred)
print('ROC AUC: %f' % auc)

# precision
pre=precision_score(y_test, y_pred)
print('Precision =  %.3f'%pre)

# confusion matrix
cf = confusion_matrix(y_test, y_pred)
print(cf)
# Out:
# Accuracy: 0.769128
# Precision: 0.701010
# Recall: 0.935310
# F1 score: 0.801386
# Cohens kappa: 0.538866
# ROC AUC: 0.769794
# Precision =  0.701
# [[226 148]
#  [ 24 347]]

# %%
# R2 & MSE

def scoreResults(model, x_train, x_test, y_train, y_test):

    y_train_predict = model.predict(x_train)
    y_test_predict = model.predict(x_test)

    r2_train = metrics.r2_score(y_train, y_train_predict)
    r2_test = metrics.r2_score(y_test, y_test_predict)

    mse_train = metrics.mean_squared_error(y_train, y_train_predict)
    mse_test = metrics.mean_squared_error(y_test, y_test_predict)



    return [r2_train, r2_test, mse_train, mse_test]

from sklearn import metrics

lr=model
result_lr = scoreResults(model = lr, x_train = X_train, x_test = X_val, y_train = y_train, y_test = y_val)

print(f"Train R2 Score: {result_lr[0]:.4f} MSE: {result_lr[2]:.4f}")
print(f"Test R2 Score: {result_lr[1]:9.4f} MSE: {result_lr[3]:.4f}")
# Out:
# Train R2 Score: 0.3016 MSE: 0.1746
# Test R2 Score:    0.3451 MSE: 0.1637

# %% [markdown]
# ### Karmaşıklık Matrisi

# %%
plt.matshow(cf)
plt.title('Confusion Matrix Plot')
plt.colorbar()
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
class_names = ["Covid","non-covid"]

from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(cm, classes, title='Confusion matrix', cmap=plt.cm.Blues):
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    plt.figure(figsize=(10,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="black" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    
# compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=2)

# plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, title='Normalized confusion matrix')
plt.show()

# %% [markdown]
# #### ROC AUC Score

# %%
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

fp1, tp1, threshold1 = roc_curve(y_test, y_pred)


def plotRoc():
    plt.subplots(1, figsize=(10,10))
    plt.title('Receiver Operating Characteristic - DecisionTree')
    plt.plot(fp1, tp1)
    plt.plot([0, 1], ls="--")
    plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()

print('roc_auc_score for Model: ', roc_auc_score(y_test, y_pred))

plotRoc()
# Out:
# roc_auc_score for Model:  0.7697940239560661
