# %% [markdown]
# # DenseNet 201

# %% [markdown]
# #### Google Colab Doğrulama
#
# 3 tane datasetimiz var. Onlara ulaşabilmek adına doğrulama işlemlerini gerçekleştiriyoruz.

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 145483 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.23-0ubuntu1~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.23-0ubuntu1~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.23-0ubuntu1~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# Bağlanıp bağlanmadığımız görmek amacıyla drive daki çalışma alanımızın içindekileri listele komutunu çalıştırıyoruz.

# %%
ls "/content/drive/My Drive/CT"
# Out:
# checkpoint    denseNet_model_78.h5               my_model_fra.h5  transfer/
# covid/        earlystop_model.h5                 non-covid/       works/
# COVID/        model.h5                           NonCOVID/
# CT_COVID/     model_weights.data-00000-of-00001  Normalize/
# CT_NonCOVID/  model_weights.index                saved_models/

# %% [markdown]
# #### Kütüphaneler

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import cv2
import os
from tqdm import tqdm
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from keras.models import Model,Sequential, Input, load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.applications import DenseNet121, MobileNetV2


from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import numpy as np

from keras.callbacks import ModelCheckpoint, EarlyStopping

# %% [markdown]
# Normalize edilmiş değerleri önceki ipynb dosyamızda npy olarak kaydetmiştik. Bu aşama, işlemlerimizi hızlandırmak için yapıldı. numpy kütüphanesinden load() metodunu çağırarak normalize olmuş datamızı kullanmaya başlayabiliriz.

# %%
a= "/content/drive/My Drive/CT/Normalize/"

#300 veri bulunan dataset
l1x=a+ "X_nparray300.npy"
l1y=a+ "y_nparray300.npy"

#1200 veri bulunan dataset
l2x=a+ "X_nparray1200.npy"
l2y=a+ "y_nparray1200.npy"

#3000 veri bulunan dataset
l3x=a+ "X_nparray3000.npy"
l3y=a+ "y_nparray3000.npy"

loaded_array_x1200 = np.load(l2x)
loaded_array_y1200 = np.load(l2y)

# %%
X=loaded_array_x1200
y=loaded_array_y1200

# %% [markdown]
# Datamızın doğru yüklendiğine emin olmak için shape metodunu kullanarak inceliyoruz.

# %%
print("Shape of input data: {} and shape of target variable: {}".format(X.shape, y.shape))
# Out:
# Shape of input data: (2481, 64, 64, 3) and shape of target variable: (2481, 2)

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3, random_state=SEED)

# %% [markdown]
# Verisetimiz üzerinde kaç tane forward ve backward propagation yapılacağını ayarladığımız apoch sayımızı 50,100 ve 200 vereceğiz.
#
# Tüm veri kümesini aynı anda sinir ağına veremeyeceğimiz için dataseti parçalara böleriz. Yani batch size olarak adlandırdığımız bu hiperparametre üzerinde çalışılacak bir parti örneğin miktarını bize söyler. Burada 64'er adet image lar halinde modelimize göndereceğiz.

# %%
EPOCHS = 100
# 50, 100, 200
SIZE=64
N_ch=3
BATCH_SIZE = 64
SEED= 42

IMG_W= 64
IMG_H= 64
CHANNELS = 3

INPUT_SHAPE=(IMG_W, IMG_H, CHANNELS)

# %% [markdown]
# # DenseNet 201

# %% [markdown]
# ### Adam

# %%
from keras.applications.densenet import DenseNet201, preprocess_input
import keras
import tensorflow as tf

def get_model_dense201():
    densenet = DenseNet201(weights='imagenet', include_top=False, input_shape=(64, 64, 3))

    input = Input(shape=(SIZE, SIZE, N_ch))
    x = Conv2D(3, (3, 3), padding='same')(input)
    
    x = densenet(x)
    
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # multi output
    output = Dense(2,activation = 'softmax', name='root')(x)
 

    # model
    model = Model(input,output)
    
    
    optimizer = tf.keras.optimizers.Adam(learning_rate=0.1)
 
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    model.summary()
    
    return model

# %%
model=get_model_dense201()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 3)         84
# _________________________________________________________________
# densenet201 (Functional)     (None, 2, 2, 1920)        18321984
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 1920)              0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 1920)              7680
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1920)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               491776
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# root (Dense)                 (None, 2)                 514
# =================================================================
# Total params: 18,823,062
# Trainable params: 18,589,654
# Non-trainable params: 233,408
# _________________________________________________________________

# %%
datagen = ImageDataGenerator(rotation_range=360, # rotasyon
                        width_shift_range=0.2, # yatayda shift
                        height_shift_range=0.2, # dikeyde kayma
                        zoom_range=0.2, # büyültme
                        horizontal_flip=True, # yatayda çevirme
                        vertical_flip=True)  #dikeyde çevirme

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold, train_test_split, cross_val_predict, cross_val_score
from sklearn import metrics
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import median_absolute_error



annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
checkpoint = ModelCheckpoint('model_CNN2.h5', verbose=1, save_best_only=True)



datagen.fit(X_train)

hist = model.fit_generator(datagen.flow(X_train, y_train, batch_size=BATCH_SIZE),
               steps_per_epoch=X_train.shape[0] // BATCH_SIZE,
               epochs=EPOCHS,
               verbose=2,
               callbacks=[annealer, checkpoint],
               validation_data=(X_val, y_val))
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 27/27 - 33s - loss: 1.3998 - accuracy: 0.6017 - val_loss: 289375033514973569096876032.0000 - val_accuracy: 0.5020
#
# Epoch 00001: val_loss improved from inf to 289375033514973569096876032.00000, saving model to model_CNN2.h5
# Epoch 2/100
# 27/27 - 3s - loss: 0.6361 - accuracy: 0.7213 - val_loss: 639941672960.0000 - val_accuracy: 0.5020
#
# Epoch 00002: val_loss improved from 289375033514973569096876032.00000 to 639941672960.00000, saving model to model_CNN2.h5
# Epoch 3/100
# 27/27 - 4s - loss: 0.4606 - accuracy: 0.7751 - val_loss: 7794328.5000 - val_accuracy: 0.5020
#
# Epoch 00003: val_loss improved from 639941672960.00000 to 7794328.50000, saving model to model_CNN2.h5
# Epoch 4/100
# 27/27 - 4s - loss: 0.6165 - accuracy: 0.7195 - val_loss: 16621892.0000 - val_accuracy: 0.5020
#
# Epoch 00004: val_loss did not improve from 7794328.50000
# Epoch 5/100
# 27/27 - 3s - loss: 0.5841 - accuracy: 0.7195 - val_loss: 125913.4297 - val_accuracy: 0.5020
#
# Epoch 00005: val_loss improved from 7794328.50000 to 125913.42969, saving model to model_CNN2.h5
# Epoch 6/100
# 27/27 - 3s - loss: 0.5555 - accuracy: 0.7404 - val_loss: 6698.3569 - val_accuracy: 0.5020
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.05000000074505806.
#
# Epoch 00006: val_loss improved from 125913.42969 to 6698.35693, saving model to model_CNN2.h5
# Epoch 7/100
# 27/27 - 4s - loss: 0.4612 - accuracy: 0.7835 - val_loss: 261.7982 - val_accuracy: 0.5020
#
# Epoch 00007: val_loss improved from 6698.35693 to 261.79816, saving model to model_CNN2.h5
# Epoch 8/100
# 27/27 - 3s - loss: 0.4410 - accuracy: 0.7949 - val_loss: 60.7377 - val_accuracy: 0.5020
#
# Epoch 00008: val_loss improved from 261.79816 to 60.73771, saving model to model_CNN2.h5
# Epoch 9/100
# 27/27 - 3s - loss: 0.4297 - accuracy: 0.7972 - val_loss: 23.4293 - val_accuracy: 0.5020
#
# Epoch 00009: val_loss improved from 60.73771 to 23.42930, saving model to model_CNN2.h5
# Epoch 10/100
# 27/27 - 4s - loss: 0.4212 - accuracy: 0.8026 - val_loss: 6.4336 - val_accuracy: 0.5128
#
# Epoch 00010: val_loss improved from 23.42930 to 6.43358, saving model to model_CNN2.h5
# Epoch 11/100
# 27/27 - 3s - loss: 0.4398 - accuracy: 0.7829 - val_loss: 9.8534 - val_accuracy: 0.5517
#
# Epoch 00011: val_loss did not improve from 6.43358
# Epoch 12/100
# 27/27 - 3s - loss: 0.4253 - accuracy: 0.7990 - val_loss: 3.8996 - val_accuracy: 0.5450
#
# Epoch 00012: val_loss improved from 6.43358 to 3.89963, saving model to model_CNN2.h5
# Epoch 13/100
# 27/27 - 3s - loss: 0.4053 - accuracy: 0.8068 - val_loss: 4.8364 - val_accuracy: 0.5356
#
# Epoch 00013: val_loss did not improve from 3.89963
# Epoch 14/100
# 27/27 - 3s - loss: 0.4075 - accuracy: 0.8050 - val_loss: 1.4709 - val_accuracy: 0.6362
#
# Epoch 00014: val_loss improved from 3.89963 to 1.47086, saving model to model_CNN2.h5
# Epoch 15/100
# 27/27 - 3s - loss: 0.4468 - accuracy: 0.7895 - val_loss: 1.6864 - val_accuracy: 0.6389
#
# Epoch 00015: val_loss did not improve from 1.47086
# Epoch 16/100
# 27/27 - 3s - loss: 0.4647 - accuracy: 0.7787 - val_loss: 0.9500 - val_accuracy: 0.7020
#
# Epoch 00016: val_loss improved from 1.47086 to 0.94999, saving model to model_CNN2.h5
# Epoch 17/100
# 27/27 - 3s - loss: 0.4600 - accuracy: 0.7775 - val_loss: 0.6857 - val_accuracy: 0.7128
#
# Epoch 00017: val_loss improved from 0.94999 to 0.68568, saving model to model_CNN2.h5
# Epoch 18/100
# 27/27 - 3s - loss: 0.4262 - accuracy: 0.7889 - val_loss: 0.7044 - val_accuracy: 0.7557
#
# Epoch 00018: val_loss did not improve from 0.68568
# Epoch 19/100
# 27/27 - 3s - loss: 0.4811 - accuracy: 0.7865 - val_loss: 1.3960 - val_accuracy: 0.7154
#
# Epoch 00019: val_loss did not improve from 0.68568
# Epoch 20/100
# 27/27 - 3s - loss: 0.4486 - accuracy: 0.7739 - val_loss: 2.4988 - val_accuracy: 0.6349
#
# Epoch 00020: val_loss did not improve from 0.68568
# Epoch 21/100
# 27/27 - 3s - loss: 0.4035 - accuracy: 0.8038 - val_loss: 0.9299 - val_accuracy: 0.5732
#
# Epoch 00021: val_loss did not improve from 0.68568
# Epoch 22/100
# 27/27 - 3s - loss: 0.3996 - accuracy: 0.8086 - val_loss: 0.6740 - val_accuracy: 0.8013
#
# Epoch 00022: val_loss improved from 0.68568 to 0.67397, saving model to model_CNN2.h5
# Epoch 23/100
# 27/27 - 3s - loss: 0.4050 - accuracy: 0.8038 - val_loss: 0.9038 - val_accuracy: 0.7383
#
# Epoch 00023: val_loss did not improve from 0.67397
# Epoch 24/100
# 27/27 - 3s - loss: 0.4200 - accuracy: 0.7967 - val_loss: 1.6375 - val_accuracy: 0.6832
#
# Epoch 00024: val_loss did not improve from 0.67397
# Epoch 25/100
# 27/27 - 3s - loss: 0.3929 - accuracy: 0.8134 - val_loss: 1.6723 - val_accuracy: 0.6228
#
# Epoch 00025: val_loss did not improve from 0.67397
# Epoch 26/100
# 27/27 - 4s - loss: 0.4332 - accuracy: 0.7949 - val_loss: 1.3490 - val_accuracy: 0.6899
#
# Epoch 00026: val_loss did not improve from 0.67397
# Epoch 27/100
# 27/27 - 3s - loss: 0.4037 - accuracy: 0.8116 - val_loss: 11.9750 - val_accuracy: 0.5020
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.02500000037252903.
#
# Epoch 00027: val_loss did not improve from 0.67397
# Epoch 28/100
# 27/27 - 3s - loss: 0.3785 - accuracy: 0.8200 - val_loss: 1.6896 - val_accuracy: 0.6456
#
# Epoch 00028: val_loss did not improve from 0.67397
# Epoch 29/100
# 27/27 - 3s - loss: 0.3575 - accuracy: 0.8319 - val_loss: 0.5675 - val_accuracy: 0.7987
#
# Epoch 00029: val_loss improved from 0.67397 to 0.56748, saving model to model_CNN2.h5
# Epoch 30/100
# 27/27 - 3s - loss: 0.3829 - accuracy: 0.8254 - val_loss: 1.5678 - val_accuracy: 0.4738
#
# Epoch 00030: val_loss did not improve from 0.56748
# Epoch 31/100
# 27/27 - 3s - loss: 0.4862 - accuracy: 0.7584 - val_loss: 1.7928 - val_accuracy: 0.7664
#
# Epoch 00031: val_loss did not improve from 0.56748
# Epoch 32/100
# 27/27 - 3s - loss: 0.4531 - accuracy: 0.7859 - val_loss: 2.4465 - val_accuracy: 0.5691
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.012500000186264515.
#
# Epoch 00032: val_loss did not improve from 0.56748
# Epoch 33/100
# 27/27 - 3s - loss: 0.3979 - accuracy: 0.8104 - val_loss: 1.7335 - val_accuracy: 0.6148
#
# Epoch 00033: val_loss did not improve from 0.56748
# Epoch 34/100
# 27/27 - 3s - loss: 0.3636 - accuracy: 0.8325 - val_loss: 0.8379 - val_accuracy: 0.7383
#
# Epoch 00034: val_loss did not improve from 0.56748
# Epoch 35/100
# 27/27 - 3s - loss: 0.3802 - accuracy: 0.8272 - val_loss: 0.7435 - val_accuracy: 0.7087
#
# Epoch 00035: val_loss did not improve from 0.56748
# Epoch 36/100
# 27/27 - 4s - loss: 0.3570 - accuracy: 0.8421 - val_loss: 0.5944 - val_accuracy: 0.7691
#
# Epoch 00036: val_loss did not improve from 0.56748
# Epoch 37/100
# 27/27 - 3s - loss: 0.3401 - accuracy: 0.8421 - val_loss: 0.8055 - val_accuracy: 0.6805
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 0.0062500000931322575.
#
# Epoch 00037: val_loss did not improve from 0.56748
# Epoch 38/100
# 27/27 - 3s - loss: 0.3569 - accuracy: 0.8379 - val_loss: 0.8503 - val_accuracy: 0.6322
#
# Epoch 00038: val_loss did not improve from 0.56748
# Epoch 39/100
# 27/27 - 3s - loss: 0.3335 - accuracy: 0.8487 - val_loss: 0.5495 - val_accuracy: 0.7866
#
# Epoch 00039: val_loss improved from 0.56748 to 0.54951, saving model to model_CNN2.h5
# Epoch 40/100
# 27/27 - 4s - loss: 0.3223 - accuracy: 0.8571 - val_loss: 0.4907 - val_accuracy: 0.8255
#
# Epoch 00040: val_loss improved from 0.54951 to 0.49066, saving model to model_CNN2.h5
# Epoch 41/100
# 27/27 - 4s - loss: 0.3260 - accuracy: 0.8541 - val_loss: 1.5595 - val_accuracy: 0.6040
#
# Epoch 00041: val_loss did not improve from 0.49066
# Epoch 42/100
# 27/27 - 4s - loss: 0.3109 - accuracy: 0.8606 - val_loss: 0.4795 - val_accuracy: 0.8336
#
# Epoch 00042: val_loss improved from 0.49066 to 0.47951, saving model to model_CNN2.h5
# Epoch 43/100
# 27/27 - 3s - loss: 0.3108 - accuracy: 0.8636 - val_loss: 0.4841 - val_accuracy: 0.8013
#
# Epoch 00043: val_loss did not improve from 0.47951
# Epoch 44/100
# 27/27 - 4s - loss: 0.3223 - accuracy: 0.8469 - val_loss: 0.5141 - val_accuracy: 0.8040
#
# Epoch 00044: val_loss did not improve from 0.47951
# Epoch 45/100
# 27/27 - 4s - loss: 0.3087 - accuracy: 0.8696 - val_loss: 1.4150 - val_accuracy: 0.5651
#
# Epoch 00045: val_loss did not improve from 0.47951
# Epoch 46/100
# 27/27 - 3s - loss: 0.3058 - accuracy: 0.8577 - val_loss: 1.4392 - val_accuracy: 0.5584
#
# Epoch 00046: val_loss did not improve from 0.47951
# Epoch 47/100
# 27/27 - 4s - loss: 0.2966 - accuracy: 0.8804 - val_loss: 1.1041 - val_accuracy: 0.6416
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 0.0031250000465661287.
#
# Epoch 00047: val_loss did not improve from 0.47951
# Epoch 48/100
# 27/27 - 3s - loss: 0.3007 - accuracy: 0.8583 - val_loss: 0.5710 - val_accuracy: 0.7799
#
# Epoch 00048: val_loss did not improve from 0.47951
# Epoch 49/100
# 27/27 - 3s - loss: 0.3190 - accuracy: 0.8535 - val_loss: 0.5308 - val_accuracy: 0.7651
#
# Epoch 00049: val_loss did not improve from 0.47951
# Epoch 50/100
# 27/27 - 4s - loss: 0.2877 - accuracy: 0.8696 - val_loss: 0.3853 - val_accuracy: 0.8617
#
# Epoch 00050: val_loss improved from 0.47951 to 0.38526, saving model to model_CNN2.h5
# Epoch 51/100
# 27/27 - 4s - loss: 0.2910 - accuracy: 0.8672 - val_loss: 0.4135 - val_accuracy: 0.8617
#
# Epoch 00051: val_loss did not improve from 0.38526
# Epoch 52/100
# 27/27 - 4s - loss: 0.3038 - accuracy: 0.8565 - val_loss: 0.4237 - val_accuracy: 0.8483
#
# Epoch 00052: val_loss did not improve from 0.38526
# Epoch 53/100
# 27/27 - 3s - loss: 0.2954 - accuracy: 0.8642 - val_loss: 0.6596 - val_accuracy: 0.7852
#
# Epoch 00053: val_loss did not improve from 0.38526
# Epoch 54/100
# 27/27 - 3s - loss: 0.2939 - accuracy: 0.8720 - val_loss: 0.4074 - val_accuracy: 0.8483
#
# Epoch 00054: val_loss did not improve from 0.38526
# Epoch 55/100
# 27/27 - 3s - loss: 0.2844 - accuracy: 0.8738 - val_loss: 0.3934 - val_accuracy: 0.8510
#
# Epoch 00055: ReduceLROnPlateau reducing learning rate to 0.0015625000232830644.
#
# Epoch 00055: val_loss did not improve from 0.38526
# Epoch 56/100
# 27/27 - 3s - loss: 0.2748 - accuracy: 0.8750 - val_loss: 0.3530 - val_accuracy: 0.8752
#
# Epoch 00056: val_loss improved from 0.38526 to 0.35297, saving model to model_CNN2.h5
# Epoch 57/100
# 27/27 - 4s - loss: 0.2822 - accuracy: 0.8690 - val_loss: 0.3545 - val_accuracy: 0.8779
#
# Epoch 00057: val_loss did not improve from 0.35297
# Epoch 58/100
# 27/27 - 4s - loss: 0.2758 - accuracy: 0.8780 - val_loss: 0.3364 - val_accuracy: 0.8872
#
# Epoch 00058: val_loss improved from 0.35297 to 0.33643, saving model to model_CNN2.h5
# Epoch 59/100
# 27/27 - 4s - loss: 0.2625 - accuracy: 0.8858 - val_loss: 0.4451 - val_accuracy: 0.8416
#
# Epoch 00059: val_loss did not improve from 0.33643
# Epoch 60/100
# 27/27 - 4s - loss: 0.2868 - accuracy: 0.8690 - val_loss: 0.3546 - val_accuracy: 0.8872
#
# Epoch 00060: val_loss did not improve from 0.33643
# Epoch 61/100
# 27/27 - 4s - loss: 0.2652 - accuracy: 0.8876 - val_loss: 0.3989 - val_accuracy: 0.8591
#
# Epoch 00061: val_loss did not improve from 0.33643
# Epoch 62/100
# 27/27 - 3s - loss: 0.2680 - accuracy: 0.8870 - val_loss: 0.3501 - val_accuracy: 0.8872
#
# Epoch 00062: val_loss did not improve from 0.33643
# Epoch 63/100
# 27/27 - 3s - loss: 0.2574 - accuracy: 0.8876 - val_loss: 0.4241 - val_accuracy: 0.8550
#
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00063: val_loss did not improve from 0.33643
# Epoch 64/100
# 27/27 - 4s - loss: 0.2662 - accuracy: 0.8840 - val_loss: 0.6113 - val_accuracy: 0.7973
#
# Epoch 00064: val_loss did not improve from 0.33643
# Epoch 65/100
# 27/27 - 4s - loss: 0.2686 - accuracy: 0.8822 - val_loss: 0.4140 - val_accuracy: 0.8497
#
# Epoch 00065: val_loss did not improve from 0.33643
# Epoch 66/100
# 27/27 - 4s - loss: 0.2877 - accuracy: 0.8750 - val_loss: 0.3373 - val_accuracy: 0.8953
#
# Epoch 00066: val_loss did not improve from 0.33643
# Epoch 67/100
# 27/27 - 4s - loss: 0.2736 - accuracy: 0.8780 - val_loss: 0.3585 - val_accuracy: 0.8819
#
# Epoch 00067: val_loss did not improve from 0.33643
# Epoch 68/100
# 27/27 - 4s - loss: 0.2580 - accuracy: 0.8900 - val_loss: 0.3440 - val_accuracy: 0.8886
#
# Epoch 00068: val_loss did not improve from 0.33643
# Epoch 69/100
# 27/27 - 4s - loss: 0.2641 - accuracy: 0.8894 - val_loss: 0.3404 - val_accuracy: 0.8832
#
# Epoch 00069: val_loss did not improve from 0.33643
# Epoch 70/100
# 27/27 - 4s - loss: 0.2633 - accuracy: 0.8762 - val_loss: 0.3282 - val_accuracy: 0.8980
#
# Epoch 00070: val_loss improved from 0.33643 to 0.32823, saving model to model_CNN2.h5
# Epoch 71/100
# 27/27 - 4s - loss: 0.2641 - accuracy: 0.8870 - val_loss: 0.3909 - val_accuracy: 0.8591
#
# Epoch 00071: val_loss did not improve from 0.32823
# Epoch 72/100
# 27/27 - 4s - loss: 0.2678 - accuracy: 0.8802 - val_loss: 0.3335 - val_accuracy: 0.9007
#
# Epoch 00072: val_loss did not improve from 0.32823
# Epoch 73/100
# 27/27 - 4s - loss: 0.2745 - accuracy: 0.8726 - val_loss: 0.3881 - val_accuracy: 0.8644
#
# Epoch 00073: val_loss did not improve from 0.32823
# Epoch 74/100
# 27/27 - 4s - loss: 0.2537 - accuracy: 0.8882 - val_loss: 0.3625 - val_accuracy: 0.8698
#
# Epoch 00074: val_loss did not improve from 0.32823
# Epoch 75/100
# 27/27 - 4s - loss: 0.2703 - accuracy: 0.8822 - val_loss: 0.4150 - val_accuracy: 0.8510
#
# Epoch 00075: val_loss did not improve from 0.32823
# Epoch 76/100
# 27/27 - 4s - loss: 0.2647 - accuracy: 0.8792 - val_loss: 0.3543 - val_accuracy: 0.8940
#
# Epoch 00076: val_loss did not improve from 0.32823
# Epoch 77/100
# 27/27 - 4s - loss: 0.2507 - accuracy: 0.8858 - val_loss: 0.3423 - val_accuracy: 0.8940
#
# Epoch 00077: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00077: val_loss did not improve from 0.32823
# Epoch 78/100
# 27/27 - 4s - loss: 0.2621 - accuracy: 0.8864 - val_loss: 0.3575 - val_accuracy: 0.8765
#
# Epoch 00078: val_loss did not improve from 0.32823
# Epoch 79/100
# 27/27 - 4s - loss: 0.2489 - accuracy: 0.8929 - val_loss: 0.3365 - val_accuracy: 0.8819
#
# Epoch 00079: val_loss did not improve from 0.32823
# Epoch 80/100
# 27/27 - 4s - loss: 0.2546 - accuracy: 0.8911 - val_loss: 0.3183 - val_accuracy: 0.9020
#
# Epoch 00080: val_loss improved from 0.32823 to 0.31834, saving model to model_CNN2.h5
# Epoch 81/100
# 27/27 - 4s - loss: 0.2560 - accuracy: 0.8888 - val_loss: 0.3139 - val_accuracy: 0.8993
#
# Epoch 00081: val_loss improved from 0.31834 to 0.31393, saving model to model_CNN2.h5
# Epoch 82/100
# 27/27 - 4s - loss: 0.2567 - accuracy: 0.8846 - val_loss: 0.3307 - val_accuracy: 0.8899
#
# Epoch 00082: val_loss did not improve from 0.31393
# Epoch 83/100
# 27/27 - 4s - loss: 0.2590 - accuracy: 0.8854 - val_loss: 0.3537 - val_accuracy: 0.8752
#
# Epoch 00083: val_loss did not improve from 0.31393
# Epoch 84/100
# 27/27 - 4s - loss: 0.2610 - accuracy: 0.8840 - val_loss: 0.3179 - val_accuracy: 0.9034
#
# Epoch 00084: val_loss did not improve from 0.31393
# Epoch 85/100
# 27/27 - 4s - loss: 0.2538 - accuracy: 0.8882 - val_loss: 0.3494 - val_accuracy: 0.8913
#
# Epoch 00085: val_loss did not improve from 0.31393
# Epoch 86/100
# 27/27 - 4s - loss: 0.2572 - accuracy: 0.8858 - val_loss: 0.3164 - val_accuracy: 0.9047
#
# Epoch 00086: val_loss did not improve from 0.31393
# Epoch 87/100
# 27/27 - 4s - loss: 0.2560 - accuracy: 0.8876 - val_loss: 0.3549 - val_accuracy: 0.9007
#
# Epoch 00087: val_loss did not improve from 0.31393
# Epoch 88/100
# 27/27 - 4s - loss: 0.2629 - accuracy: 0.8840 - val_loss: 0.3344 - val_accuracy: 0.8953
#
# Epoch 00088: val_loss did not improve from 0.31393
# Epoch 89/100
# 27/27 - 4s - loss: 0.2597 - accuracy: 0.8882 - val_loss: 0.3152 - val_accuracy: 0.9074
#
# Epoch 00089: val_loss did not improve from 0.31393
# Epoch 90/100
# 27/27 - 4s - loss: 0.2498 - accuracy: 0.8888 - val_loss: 0.3241 - val_accuracy: 0.9034
#
# Epoch 00090: val_loss did not improve from 0.31393
# Epoch 91/100
# 27/27 - 4s - loss: 0.2566 - accuracy: 0.8870 - val_loss: 0.3252 - val_accuracy: 0.9074
#
# Epoch 00091: val_loss did not improve from 0.31393
# Epoch 92/100
# 27/27 - 4s - loss: 0.2506 - accuracy: 0.8816 - val_loss: 0.3367 - val_accuracy: 0.8913
#
# Epoch 00092: val_loss did not improve from 0.31393
# Epoch 93/100
# 27/27 - 4s - loss: 0.2439 - accuracy: 0.8900 - val_loss: 0.3097 - val_accuracy: 0.9114
#
# Epoch 00093: val_loss improved from 0.31393 to 0.30968, saving model to model_CNN2.h5
# Epoch 94/100
# 27/27 - 4s - loss: 0.2473 - accuracy: 0.8882 - val_loss: 0.4918 - val_accuracy: 0.8349
#
# Epoch 00094: val_loss did not improve from 0.30968
# Epoch 95/100
# 27/27 - 4s - loss: 0.2357 - accuracy: 0.8929 - val_loss: 0.3043 - val_accuracy: 0.9101
#
# Epoch 00095: val_loss improved from 0.30968 to 0.30433, saving model to model_CNN2.h5
# Epoch 96/100
# 27/27 - 4s - loss: 0.2475 - accuracy: 0.8923 - val_loss: 0.3070 - val_accuracy: 0.9128
#
# Epoch 00096: val_loss did not improve from 0.30433
# Epoch 97/100
# 27/27 - 4s - loss: 0.2382 - accuracy: 0.9007 - val_loss: 0.3092 - val_accuracy: 0.9114
#
# Epoch 00097: val_loss did not improve from 0.30433
# Epoch 98/100
# 27/27 - 4s - loss: 0.2485 - accuracy: 0.8959 - val_loss: 0.3299 - val_accuracy: 0.8940
#
# Epoch 00098: val_loss did not improve from 0.30433
# Epoch 99/100
# 27/27 - 4s - loss: 0.2506 - accuracy: 0.8900 - val_loss: 0.3173 - val_accuracy: 0.8966
#
# Epoch 00099: val_loss did not improve from 0.30433
# Epoch 100/100
# 27/27 - 4s - loss: 0.2566 - accuracy: 0.8906 - val_loss: 0.4566 - val_accuracy: 0.8228
#
# Epoch 00100: val_loss did not improve from 0.30433

# %%
print("training_accuracy   = ", hist.history['accuracy'][-1])
print("validation_accuracy = ", hist.history['val_accuracy'][-1])
print("training_loss   = ", hist.history['loss'][-1])
print("validation_loss = ", hist.history['val_loss'][-1])
# Out:
# training_accuracy   =  0.8905502557754517
# validation_accuracy =  0.8228188157081604
# training_loss   =  0.256633460521698
# validation_loss =  0.45659375190734863

# %%
# Accuracy ve Loss değerlerinin görselleştirilmeleri

plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy ~Adam')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss ~Adam')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
from keras.applications.densenet import DenseNet201, preprocess_input
import keras
import tensorflow as tf

def get_model_dense201():
    densenet = DenseNet201(weights='imagenet', include_top=False, input_shape=(64, 64, 3))

    input = Input(shape=(SIZE, SIZE, N_ch))
    x = Conv2D(3, (3, 3), padding='same')(input)
    
    x = densenet(x)
    
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # multi output
    output = Dense(2,activation = 'softmax', name='root')(x)
 

    # model
    model = Model(input,output)
    
    
    optimizer = tf.keras.optimizers.Adagrad(learning_rate=0.001)
 
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    model.summary()
    
    return model

# %%
model=get_model_dense201()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 64, 64, 3)         84
# _________________________________________________________________
# densenet201 (Functional)     (None, 2, 2, 1920)        18321984
# _________________________________________________________________
# global_average_pooling2d_3 ( (None, 1920)              0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 1920)              7680
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1920)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               491776
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 256)               0
# _________________________________________________________________
# root (Dense)                 (None, 2)                 514
# =================================================================
# Total params: 18,823,062
# Trainable params: 18,589,654
# Non-trainable params: 233,408
# _________________________________________________________________

# %%
datagen = ImageDataGenerator(rotation_range=360, # rotasyon
                        width_shift_range=0.2, # yatayda shift
                        height_shift_range=0.2, # dikeyde kayma
                        zoom_range=0.2, # büyültme
                        horizontal_flip=True, # yatayda çevirme
                        vertical_flip=True)  #dikeyde çevirme

# %%
annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
checkpoint = ModelCheckpoint('model_CNN2.h5', verbose=1, save_best_only=True)



datagen.fit(X_train)

hist = model.fit_generator(datagen.flow(X_train, y_train, batch_size=BATCH_SIZE),
               steps_per_epoch=X_train.shape[0] // BATCH_SIZE,
               epochs=EPOCHS,
               verbose=2,
               callbacks=[annealer, checkpoint],
               validation_data=(X_val, y_val))
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 27/27 - 22s - loss: 0.9951 - accuracy: 0.5371 - val_loss: 0.8246 - val_accuracy: 0.5168
#
# Epoch 00001: val_loss improved from inf to 0.82460, saving model to model_CNN2.h5
# Epoch 2/100
# 27/27 - 4s - loss: 0.9239 - accuracy: 0.5867 - val_loss: 0.7335 - val_accuracy: 0.5315
#
# Epoch 00002: val_loss improved from 0.82460 to 0.73352, saving model to model_CNN2.h5
# Epoch 3/100
# 27/27 - 4s - loss: 0.8817 - accuracy: 0.6196 - val_loss: 0.6924 - val_accuracy: 0.5933
#
# Epoch 00003: val_loss improved from 0.73352 to 0.69244, saving model to model_CNN2.h5
# Epoch 4/100
# 27/27 - 4s - loss: 0.8368 - accuracy: 0.6489 - val_loss: 0.6257 - val_accuracy: 0.6792
#
# Epoch 00004: val_loss improved from 0.69244 to 0.62566, saving model to model_CNN2.h5
# Epoch 5/100
# 27/27 - 4s - loss: 0.7865 - accuracy: 0.6639 - val_loss: 0.6059 - val_accuracy: 0.6846
#
# Epoch 00005: val_loss improved from 0.62566 to 0.60593, saving model to model_CNN2.h5
# Epoch 6/100
# 27/27 - 4s - loss: 0.7721 - accuracy: 0.6740 - val_loss: 0.5779 - val_accuracy: 0.7181
#
# Epoch 00006: val_loss improved from 0.60593 to 0.57786, saving model to model_CNN2.h5
# Epoch 7/100
# 27/27 - 4s - loss: 0.7486 - accuracy: 0.6800 - val_loss: 0.5678 - val_accuracy: 0.7248
#
# Epoch 00007: val_loss improved from 0.57786 to 0.56779, saving model to model_CNN2.h5
# Epoch 8/100
# 27/27 - 4s - loss: 0.7112 - accuracy: 0.6962 - val_loss: 0.5617 - val_accuracy: 0.7248
#
# Epoch 00008: val_loss improved from 0.56779 to 0.56174, saving model to model_CNN2.h5
# Epoch 9/100
# 27/27 - 4s - loss: 0.7128 - accuracy: 0.7045 - val_loss: 0.5408 - val_accuracy: 0.7557
#
# Epoch 00009: val_loss improved from 0.56174 to 0.54080, saving model to model_CNN2.h5
# Epoch 10/100
# 27/27 - 4s - loss: 0.6957 - accuracy: 0.7207 - val_loss: 0.5223 - val_accuracy: 0.7570
#
# Epoch 00010: val_loss improved from 0.54080 to 0.52228, saving model to model_CNN2.h5
# Epoch 11/100
# 27/27 - 4s - loss: 0.6729 - accuracy: 0.7225 - val_loss: 0.5285 - val_accuracy: 0.7530
#
# Epoch 00011: val_loss did not improve from 0.52228
# Epoch 12/100
# 27/27 - 4s - loss: 0.6887 - accuracy: 0.7135 - val_loss: 0.5391 - val_accuracy: 0.7342
#
# Epoch 00012: val_loss did not improve from 0.52228
# Epoch 13/100
# 27/27 - 4s - loss: 0.6683 - accuracy: 0.7237 - val_loss: 0.5142 - val_accuracy: 0.7664
#
# Epoch 00013: val_loss improved from 0.52228 to 0.51423, saving model to model_CNN2.h5
# Epoch 14/100
# 27/27 - 4s - loss: 0.6545 - accuracy: 0.7285 - val_loss: 0.4841 - val_accuracy: 0.7852
#
# Epoch 00014: val_loss improved from 0.51423 to 0.48413, saving model to model_CNN2.h5
# Epoch 15/100
# 27/27 - 4s - loss: 0.6626 - accuracy: 0.7291 - val_loss: 0.4795 - val_accuracy: 0.7785
#
# Epoch 00015: val_loss improved from 0.48413 to 0.47954, saving model to model_CNN2.h5
# Epoch 16/100
# 27/27 - 4s - loss: 0.5988 - accuracy: 0.7566 - val_loss: 0.4767 - val_accuracy: 0.7879
#
# Epoch 00016: val_loss improved from 0.47954 to 0.47666, saving model to model_CNN2.h5
# Epoch 17/100
# 27/27 - 4s - loss: 0.6053 - accuracy: 0.7482 - val_loss: 0.4729 - val_accuracy: 0.7866
#
# Epoch 00017: val_loss improved from 0.47666 to 0.47294, saving model to model_CNN2.h5
# Epoch 18/100
# 27/27 - 4s - loss: 0.6128 - accuracy: 0.7650 - val_loss: 0.4529 - val_accuracy: 0.8107
#
# Epoch 00018: val_loss improved from 0.47294 to 0.45286, saving model to model_CNN2.h5
# Epoch 19/100
# 27/27 - 4s - loss: 0.5800 - accuracy: 0.7727 - val_loss: 0.4228 - val_accuracy: 0.8295
#
# Epoch 00019: val_loss improved from 0.45286 to 0.42275, saving model to model_CNN2.h5
# Epoch 20/100
# 27/27 - 4s - loss: 0.6058 - accuracy: 0.7608 - val_loss: 0.3996 - val_accuracy: 0.8443
#
# Epoch 00020: val_loss improved from 0.42275 to 0.39962, saving model to model_CNN2.h5
# Epoch 21/100
# 27/27 - 4s - loss: 0.5291 - accuracy: 0.7955 - val_loss: 0.3968 - val_accuracy: 0.8443
#
# Epoch 00021: val_loss improved from 0.39962 to 0.39676, saving model to model_CNN2.h5
# Epoch 22/100
# 27/27 - 4s - loss: 0.5599 - accuracy: 0.7817 - val_loss: 0.3864 - val_accuracy: 0.8483
#
# Epoch 00022: val_loss improved from 0.39676 to 0.38637, saving model to model_CNN2.h5
# Epoch 23/100
# 27/27 - 4s - loss: 0.5508 - accuracy: 0.7823 - val_loss: 0.3907 - val_accuracy: 0.8416
#
# Epoch 00023: val_loss did not improve from 0.38637
# Epoch 24/100
# 27/27 - 4s - loss: 0.5417 - accuracy: 0.7829 - val_loss: 0.3817 - val_accuracy: 0.8497
#
# Epoch 00024: val_loss improved from 0.38637 to 0.38166, saving model to model_CNN2.h5
# Epoch 25/100
# 27/27 - 4s - loss: 0.5082 - accuracy: 0.7877 - val_loss: 0.3684 - val_accuracy: 0.8604
#
# Epoch 00025: val_loss improved from 0.38166 to 0.36844, saving model to model_CNN2.h5
# Epoch 26/100
# 27/27 - 4s - loss: 0.5098 - accuracy: 0.8032 - val_loss: 0.3507 - val_accuracy: 0.8738
#
# Epoch 00026: val_loss improved from 0.36844 to 0.35070, saving model to model_CNN2.h5
# Epoch 27/100
# 27/27 - 4s - loss: 0.4990 - accuracy: 0.8008 - val_loss: 0.3472 - val_accuracy: 0.8725
#
# Epoch 00027: val_loss improved from 0.35070 to 0.34716, saving model to model_CNN2.h5
# Epoch 28/100
# 27/27 - 4s - loss: 0.4942 - accuracy: 0.8104 - val_loss: 0.3297 - val_accuracy: 0.8846
#
# Epoch 00028: val_loss improved from 0.34716 to 0.32967, saving model to model_CNN2.h5
# Epoch 29/100
# 27/27 - 4s - loss: 0.4861 - accuracy: 0.8086 - val_loss: 0.3302 - val_accuracy: 0.8685
#
# Epoch 00029: val_loss did not improve from 0.32967
# Epoch 30/100
# 27/27 - 4s - loss: 0.4852 - accuracy: 0.8044 - val_loss: 0.3371 - val_accuracy: 0.8644
#
# Epoch 00030: val_loss did not improve from 0.32967
# Epoch 31/100
# 27/27 - 4s - loss: 0.4755 - accuracy: 0.8110 - val_loss: 0.3250 - val_accuracy: 0.8644
#
# Epoch 00031: val_loss improved from 0.32967 to 0.32500, saving model to model_CNN2.h5
# Epoch 32/100
# 27/27 - 4s - loss: 0.4498 - accuracy: 0.8339 - val_loss: 0.3241 - val_accuracy: 0.8604
#
# Epoch 00032: val_loss improved from 0.32500 to 0.32409, saving model to model_CNN2.h5
# Epoch 33/100
# 27/27 - 4s - loss: 0.4382 - accuracy: 0.8307 - val_loss: 0.3116 - val_accuracy: 0.8779
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00033: val_loss improved from 0.32409 to 0.31164, saving model to model_CNN2.h5
# Epoch 34/100
# 27/27 - 4s - loss: 0.4493 - accuracy: 0.8230 - val_loss: 0.3133 - val_accuracy: 0.8805
#
# Epoch 00034: val_loss did not improve from 0.31164
# Epoch 35/100
# 27/27 - 4s - loss: 0.4285 - accuracy: 0.8343 - val_loss: 0.3174 - val_accuracy: 0.8765
#
# Epoch 00035: val_loss did not improve from 0.31164
# Epoch 36/100
# 27/27 - 4s - loss: 0.4278 - accuracy: 0.8260 - val_loss: 0.3199 - val_accuracy: 0.8725
#
# Epoch 00036: val_loss did not improve from 0.31164
# Epoch 37/100
# 27/27 - 4s - loss: 0.4264 - accuracy: 0.8242 - val_loss: 0.3240 - val_accuracy: 0.8550
#
# Epoch 00037: val_loss did not improve from 0.31164
# Epoch 38/100
# 27/27 - 4s - loss: 0.4187 - accuracy: 0.8463 - val_loss: 0.3277 - val_accuracy: 0.8550
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00038: val_loss did not improve from 0.31164
# Epoch 39/100
# 27/27 - 4s - loss: 0.4237 - accuracy: 0.8367 - val_loss: 0.3311 - val_accuracy: 0.8550
#
# Epoch 00039: val_loss did not improve from 0.31164
# Epoch 40/100
# 27/27 - 4s - loss: 0.3999 - accuracy: 0.8463 - val_loss: 0.3195 - val_accuracy: 0.8644
#
# Epoch 00040: val_loss did not improve from 0.31164
# Epoch 41/100
# 27/27 - 4s - loss: 0.4147 - accuracy: 0.8379 - val_loss: 0.3749 - val_accuracy: 0.8188
#
# Epoch 00041: val_loss did not improve from 0.31164
# Epoch 42/100
# 27/27 - 4s - loss: 0.3970 - accuracy: 0.8414 - val_loss: 0.4219 - val_accuracy: 0.7839
#
# Epoch 00042: val_loss did not improve from 0.31164
# Epoch 43/100
# 27/27 - 4s - loss: 0.4113 - accuracy: 0.8397 - val_loss: 0.3450 - val_accuracy: 0.8550
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00043: val_loss did not improve from 0.31164
# Epoch 44/100
# 27/27 - 4s - loss: 0.3984 - accuracy: 0.8472 - val_loss: 0.3332 - val_accuracy: 0.8550
#
# Epoch 00044: val_loss did not improve from 0.31164
# Epoch 45/100
# 27/27 - 4s - loss: 0.3909 - accuracy: 0.8445 - val_loss: 0.3419 - val_accuracy: 0.8483
#
# Epoch 00045: val_loss did not improve from 0.31164
# Epoch 46/100
# 27/27 - 4s - loss: 0.4114 - accuracy: 0.8421 - val_loss: 0.3510 - val_accuracy: 0.8362
#
# Epoch 00046: val_loss did not improve from 0.31164
# Epoch 47/100
# 27/27 - 4s - loss: 0.3759 - accuracy: 0.8553 - val_loss: 0.3674 - val_accuracy: 0.8228
#
# Epoch 00047: val_loss did not improve from 0.31164
# Epoch 48/100
# 27/27 - 4s - loss: 0.3972 - accuracy: 0.8481 - val_loss: 0.3404 - val_accuracy: 0.8416
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00048: val_loss did not improve from 0.31164
# Epoch 49/100
# 27/27 - 4s - loss: 0.3911 - accuracy: 0.8469 - val_loss: 0.3850 - val_accuracy: 0.8107
#
# Epoch 00049: val_loss did not improve from 0.31164
# Epoch 50/100
# 27/27 - 4s - loss: 0.3921 - accuracy: 0.8451 - val_loss: 0.4051 - val_accuracy: 0.8027
#
# Epoch 00050: val_loss did not improve from 0.31164
# Epoch 51/100
# 27/27 - 4s - loss: 0.3719 - accuracy: 0.8529 - val_loss: 0.3890 - val_accuracy: 0.8094
#
# Epoch 00051: val_loss did not improve from 0.31164
# Epoch 52/100
# 27/27 - 4s - loss: 0.3593 - accuracy: 0.8642 - val_loss: 0.4056 - val_accuracy: 0.7933
#
# Epoch 00052: val_loss did not improve from 0.31164
# Epoch 53/100
# 27/27 - 4s - loss: 0.3704 - accuracy: 0.8553 - val_loss: 0.4403 - val_accuracy: 0.7758
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00053: val_loss did not improve from 0.31164
# Epoch 54/100
# 27/27 - 4s - loss: 0.3800 - accuracy: 0.8499 - val_loss: 0.4193 - val_accuracy: 0.7893
#
# Epoch 00054: val_loss did not improve from 0.31164
# Epoch 55/100
# 27/27 - 4s - loss: 0.3491 - accuracy: 0.8696 - val_loss: 0.4168 - val_accuracy: 0.7906
#
# Epoch 00055: val_loss did not improve from 0.31164
# Epoch 56/100
# 27/27 - 4s - loss: 0.3726 - accuracy: 0.8541 - val_loss: 0.4180 - val_accuracy: 0.7919
#
# Epoch 00056: val_loss did not improve from 0.31164
# Epoch 57/100
# 27/27 - 4s - loss: 0.3742 - accuracy: 0.8505 - val_loss: 0.4007 - val_accuracy: 0.8000
#
# Epoch 00057: val_loss did not improve from 0.31164
# Epoch 58/100
# 27/27 - 4s - loss: 0.3555 - accuracy: 0.8648 - val_loss: 0.3701 - val_accuracy: 0.8242
#
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00058: val_loss did not improve from 0.31164
# Epoch 59/100
# 27/27 - 4s - loss: 0.3367 - accuracy: 0.8642 - val_loss: 0.3962 - val_accuracy: 0.8000
#
# Epoch 00059: val_loss did not improve from 0.31164
# Epoch 60/100
# 27/27 - 4s - loss: 0.3385 - accuracy: 0.8660 - val_loss: 0.3664 - val_accuracy: 0.8188
#
# Epoch 00060: val_loss did not improve from 0.31164
# Epoch 61/100
# 27/27 - 4s - loss: 0.3392 - accuracy: 0.8708 - val_loss: 0.3698 - val_accuracy: 0.8215
#
# Epoch 00061: val_loss did not improve from 0.31164
# Epoch 62/100
# 27/27 - 4s - loss: 0.3484 - accuracy: 0.8618 - val_loss: 0.3498 - val_accuracy: 0.8376
#
# Epoch 00062: val_loss did not improve from 0.31164
# Epoch 63/100
# 27/27 - 4s - loss: 0.3375 - accuracy: 0.8702 - val_loss: 0.3794 - val_accuracy: 0.8134
#
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00063: val_loss did not improve from 0.31164
# Epoch 64/100
# 27/27 - 4s - loss: 0.3453 - accuracy: 0.8684 - val_loss: 0.3838 - val_accuracy: 0.8161
#
# Epoch 00064: val_loss did not improve from 0.31164
# Epoch 65/100
# 27/27 - 4s - loss: 0.3345 - accuracy: 0.8708 - val_loss: 0.3850 - val_accuracy: 0.8134
#
# Epoch 00065: val_loss did not improve from 0.31164
# Epoch 66/100
# 27/27 - 4s - loss: 0.3381 - accuracy: 0.8702 - val_loss: 0.3575 - val_accuracy: 0.8268
#
# Epoch 00066: val_loss did not improve from 0.31164
# Epoch 67/100
# 27/27 - 4s - loss: 0.3312 - accuracy: 0.8702 - val_loss: 0.3586 - val_accuracy: 0.8188
#
# Epoch 00067: val_loss did not improve from 0.31164
# Epoch 68/100
# 27/27 - 4s - loss: 0.3383 - accuracy: 0.8624 - val_loss: 0.3463 - val_accuracy: 0.8362
#
# Epoch 00068: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00068: val_loss did not improve from 0.31164
# Epoch 69/100
# 27/27 - 4s - loss: 0.3237 - accuracy: 0.8780 - val_loss: 0.3151 - val_accuracy: 0.8564
#
# Epoch 00069: val_loss did not improve from 0.31164
# Epoch 70/100
# 27/27 - 4s - loss: 0.3267 - accuracy: 0.8738 - val_loss: 0.3587 - val_accuracy: 0.8336
#
# Epoch 00070: val_loss did not improve from 0.31164
# Epoch 71/100
# 27/27 - 4s - loss: 0.3411 - accuracy: 0.8606 - val_loss: 0.3393 - val_accuracy: 0.8523
#
# Epoch 00071: val_loss did not improve from 0.31164
# Epoch 72/100
# 27/27 - 4s - loss: 0.3392 - accuracy: 0.8768 - val_loss: 0.3600 - val_accuracy: 0.8255
#
# Epoch 00072: val_loss did not improve from 0.31164
# Epoch 73/100
# 27/27 - 4s - loss: 0.3337 - accuracy: 0.8786 - val_loss: 0.4052 - val_accuracy: 0.7987
#
# Epoch 00073: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00073: val_loss did not improve from 0.31164
# Epoch 74/100
# 27/27 - 4s - loss: 0.3303 - accuracy: 0.8720 - val_loss: 0.4067 - val_accuracy: 0.8013
#
# Epoch 00074: val_loss did not improve from 0.31164
# Epoch 75/100
# 27/27 - 4s - loss: 0.3420 - accuracy: 0.8630 - val_loss: 0.3982 - val_accuracy: 0.8081
#
# Epoch 00075: val_loss did not improve from 0.31164
# Epoch 76/100
# 27/27 - 4s - loss: 0.3170 - accuracy: 0.8792 - val_loss: 0.4034 - val_accuracy: 0.8000
#
# Epoch 00076: val_loss did not improve from 0.31164
# Epoch 77/100
# 27/27 - 4s - loss: 0.3148 - accuracy: 0.8792 - val_loss: 0.4169 - val_accuracy: 0.7973
#
# Epoch 00077: val_loss did not improve from 0.31164
# Epoch 78/100
# 27/27 - 4s - loss: 0.3118 - accuracy: 0.8798 - val_loss: 0.3846 - val_accuracy: 0.8148
#
# Epoch 00078: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00078: val_loss did not improve from 0.31164
# Epoch 79/100
# 27/27 - 4s - loss: 0.3267 - accuracy: 0.8648 - val_loss: 0.3620 - val_accuracy: 0.8242
#
# Epoch 00079: val_loss did not improve from 0.31164
# Epoch 80/100
# 27/27 - 4s - loss: 0.3191 - accuracy: 0.8792 - val_loss: 0.3990 - val_accuracy: 0.8027
#
# Epoch 00080: val_loss did not improve from 0.31164
# Epoch 81/100
# 27/27 - 4s - loss: 0.3078 - accuracy: 0.8848 - val_loss: 0.3898 - val_accuracy: 0.8134
#
# Epoch 00081: val_loss did not improve from 0.31164
# Epoch 82/100
# 27/27 - 4s - loss: 0.3167 - accuracy: 0.8774 - val_loss: 0.4023 - val_accuracy: 0.8040
#
# Epoch 00082: val_loss did not improve from 0.31164
# Epoch 83/100
# 27/27 - 4s - loss: 0.3024 - accuracy: 0.8852 - val_loss: 0.3821 - val_accuracy: 0.8188
#
# Epoch 00083: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00083: val_loss did not improve from 0.31164
# Epoch 84/100
# 27/27 - 4s - loss: 0.3177 - accuracy: 0.8744 - val_loss: 0.3794 - val_accuracy: 0.8161
#
# Epoch 00084: val_loss did not improve from 0.31164
# Epoch 85/100
# 27/27 - 4s - loss: 0.2961 - accuracy: 0.8804 - val_loss: 0.4200 - val_accuracy: 0.7960
#
# Epoch 00085: val_loss did not improve from 0.31164
# Epoch 86/100
# 27/27 - 4s - loss: 0.2984 - accuracy: 0.8822 - val_loss: 0.4731 - val_accuracy: 0.7745
#
# Epoch 00086: val_loss did not improve from 0.31164
# Epoch 87/100
# 27/27 - 4s - loss: 0.3046 - accuracy: 0.8792 - val_loss: 0.5622 - val_accuracy: 0.7208
#
# Epoch 00087: val_loss did not improve from 0.31164
# Epoch 88/100
# 27/27 - 4s - loss: 0.2812 - accuracy: 0.8947 - val_loss: 0.4866 - val_accuracy: 0.7664
#
# Epoch 00088: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00088: val_loss did not improve from 0.31164
# Epoch 89/100
# 27/27 - 4s - loss: 0.3036 - accuracy: 0.8816 - val_loss: 0.4110 - val_accuracy: 0.7987
#
# Epoch 00089: val_loss did not improve from 0.31164
# Epoch 90/100
# 27/27 - 4s - loss: 0.3025 - accuracy: 0.8822 - val_loss: 0.4059 - val_accuracy: 0.8027
#
# Epoch 00090: val_loss did not improve from 0.31164
# Epoch 91/100
# 27/27 - 4s - loss: 0.2833 - accuracy: 0.8798 - val_loss: 0.4218 - val_accuracy: 0.7987
#
# Epoch 00091: val_loss did not improve from 0.31164
# Epoch 92/100
# 27/27 - 4s - loss: 0.2758 - accuracy: 0.8894 - val_loss: 0.4537 - val_accuracy: 0.7879
#
# Epoch 00092: val_loss did not improve from 0.31164
# Epoch 93/100
# 27/27 - 4s - loss: 0.2940 - accuracy: 0.8882 - val_loss: 0.4023 - val_accuracy: 0.8107
#
# Epoch 00093: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00093: val_loss did not improve from 0.31164
# Epoch 94/100
# 27/27 - 4s - loss: 0.2911 - accuracy: 0.8888 - val_loss: 0.4463 - val_accuracy: 0.7879
#
# Epoch 00094: val_loss did not improve from 0.31164
# Epoch 95/100
# 27/27 - 4s - loss: 0.3034 - accuracy: 0.8768 - val_loss: 0.4306 - val_accuracy: 0.8000
#
# Epoch 00095: val_loss did not improve from 0.31164
# Epoch 96/100
# 27/27 - 4s - loss: 0.2872 - accuracy: 0.8798 - val_loss: 0.4047 - val_accuracy: 0.8094
#
# Epoch 00096: val_loss did not improve from 0.31164
# Epoch 97/100
# 27/27 - 4s - loss: 0.2970 - accuracy: 0.8804 - val_loss: 0.3794 - val_accuracy: 0.8148
#
# Epoch 00097: val_loss did not improve from 0.31164
# Epoch 98/100
# 27/27 - 4s - loss: 0.2977 - accuracy: 0.8816 - val_loss: 0.3764 - val_accuracy: 0.8228
#
# Epoch 00098: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00098: val_loss did not improve from 0.31164
# Epoch 99/100
# 27/27 - 4s - loss: 0.2661 - accuracy: 0.8912 - val_loss: 0.3928 - val_accuracy: 0.8148
#
# Epoch 00099: val_loss did not improve from 0.31164
# Epoch 100/100
# 27/27 - 4s - loss: 0.2940 - accuracy: 0.8858 - val_loss: 0.3716 - val_accuracy: 0.8174
#
# Epoch 00100: val_loss did not improve from 0.31164

# %%
print("training_accuracy   = ", hist.history['accuracy'][-1])
print("validation_accuracy = ", hist.history['val_accuracy'][-1])
print("training_loss   = ", hist.history['loss'][-1])
print("validation_loss = ", hist.history['val_loss'][-1])
# Out:
# training_accuracy   =  0.885765552520752
# validation_accuracy =  0.817449688911438
# training_loss   =  0.2939693033695221
# validation_loss =  0.3715880513191223

# %%
# Accuracy ve Loss değerlerinin görselleştirilmeleri

plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy ~ Adagrad')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss ~ Adagrad')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# # Metrik Sonuçları

# %% [markdown]
# **Accuracy**:
# **Precision**: Yanlış Pozitifin maliyetinin ne kadar yüksek olduğunu belirlemek için kullanılır.<br>
# ![Untitled.png](data:image/png;base64,...) <br>
# **Recall**: Pozitif olarak etiketleyerek kaç tane Gerçek Pozitif yakalandığını hesaplar.<br>
# ![Untitled(1).png](data:image/png;base64,...)<br>
#
# **F1-score**: Hassasiyet(Precision) ve Recall'un ağırlıklı ortalamasıdır.<br>
# F1 = 2 × (precision × recall) / (precision + recall)
#
# **Cohen's Kappa**:
#
# **ROC AUC**: ROC eğrisinin altında kalan alan olan AUC tahminler doğrulaştıkça 1 noktasına doğru gitme eğilimindedir.
#
# **R2**:

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from keras.models import Sequential
from keras.layers import Dense

y_pred = np.argmax(model.predict(X_val), axis=-1)
y_test= np.argmax(y_val,axis=1)


# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy: %f' % accuracy)
# precision tp / (tp + fp)
precision = precision_score(y_test, y_pred)
print('Precision: %f' % precision)
# recall: tp / (tp + fn)
recall = recall_score(y_test, y_pred)
print('Recall: %f' % recall)
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(y_test, y_pred)
print('F1 score: %f' % f1)

#kappa
kappa = cohen_kappa_score(y_test, y_pred)
print('Cohens kappa: %f' % kappa)
# ROC AUC
auc = roc_auc_score(y_test, y_pred)
print('ROC AUC: %f' % auc)

# precision
pre=precision_score(y_test, y_pred)
print('Precision =  %.3f'%pre)

# confusion matrix
cf = confusion_matrix(y_test, y_pred)
print(cf)
# Out:
# Accuracy: 0.817450
# Precision: 0.930403
# Recall: 0.684636
# F1 score: 0.788820
# Cohens kappa: 0.634506
# ROC AUC: 0.816917
# Precision =  0.930
# [[355  19]
#  [117 254]]

# %%
# R2 & MSE

def scoreResults(model, x_train, x_test, y_train, y_test):

    y_train_predict = model.predict(x_train)
    y_test_predict = model.predict(x_test)

    r2_train = metrics.r2_score(y_train, y_train_predict)
    r2_test = metrics.r2_score(y_test, y_test_predict)

    mse_train = metrics.mean_squared_error(y_train, y_train_predict)
    mse_test = metrics.mean_squared_error(y_test, y_test_predict)



    return [r2_train, r2_test, mse_train, mse_test]

from sklearn import metrics

lr=model
result_lr = scoreResults(model = lr, x_train = X_train, x_test = X_val, y_train = y_train, y_test = y_val)

print(f"Train R2 Score: {result_lr[0]:.4f} MSE: {result_lr[2]:.4f}")
print(f"Test R2 Score: {result_lr[1]:9.4f} MSE: {result_lr[3]:.4f}")
# Out:
# Train R2 Score: 0.5301 MSE: 0.1175
# Test R2 Score:    0.4554 MSE: 0.1361

# %% [markdown]
# ### Karmaşıklık Matrisi

# %%
plt.matshow(cf)
plt.title('Confusion Matrix DenseNet201')
plt.colorbar()
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
class_names = ["Covid","non-covid"]

from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(cm, classes, title='Confusion matrix', cmap=plt.cm.Blues):
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    plt.figure(figsize=(10,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="black" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    
# compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=2)

# plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, title='Normalized confusion matrix of DenseNet201')
plt.show()

# %% [markdown]
# #### ROC AUC Score

# %%
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

fp1, tp1, threshold1 = roc_curve(y_test, y_pred)


def plotRoc():
    plt.subplots(1, figsize=(10,10))
    plt.title('Receiver Operating Characteristic - DecisionTree')
    plt.plot(fp1, tp1)
    plt.plot([0, 1], ls="--")
    plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()

print('roc_auc_score for Model: ', roc_auc_score(y_test, y_pred))

plotRoc()
# Out:
# roc_auc_score for Model:  0.8169169897804749

# %%
from keras.applications.densenet import DenseNet201, preprocess_input
import keras
import tensorflow as tf

def get_model_dense201():
    densenet = DenseNet201(weights='imagenet', include_top=False, input_shape=(64, 64, 3))

    input = Input(shape=(SIZE, SIZE, N_ch))
    x = Conv2D(3, (3, 3), padding='same')(input)
    
    x = densenet(x)
    
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # multi output
    output = Dense(2,activation = 'softmax', name='root')(x)
 

    # model
    model = Model(input,output)
    
    
    optimizer =  tf.keras.optimizers.SGD( learning_rate=0.01, momentum=0.0, nesterov=False, name="SGD")
 
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    model.summary()
    
    return model

# %%
model=get_model_dense201()
# Out:
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        [(None, 64, 64, 3)]       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 64, 64, 3)         84
# _________________________________________________________________
# densenet201 (Functional)     (None, 2, 2, 1920)        18321984
# _________________________________________________________________
# global_average_pooling2d_4 ( (None, 1920)              0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 1920)              7680
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 1920)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               491776
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 256)               0
# _________________________________________________________________
# root (Dense)                 (None, 2)                 514
# =================================================================
# Total params: 18,823,062
# Trainable params: 18,589,654
# Non-trainable params: 233,408
# _________________________________________________________________

# %%
datagen = ImageDataGenerator(rotation_range=360, # rotasyon
                        width_shift_range=0.2, # yatayda shift
                        height_shift_range=0.2, # dikeyde kayma
                        zoom_range=0.2, # büyültme
                        horizontal_flip=True, # yatayda çevirme
                        vertical_flip=True)  #dikeyde çevirme

# %%
annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
checkpoint = ModelCheckpoint('model_CNN2.h5', verbose=1, save_best_only=True)



datagen.fit(X_train)

hist = model.fit_generator(datagen.flow(X_train, y_train, batch_size=BATCH_SIZE),
               steps_per_epoch=X_train.shape[0] // BATCH_SIZE,
               epochs=EPOCHS,
               verbose=2,
               callbacks=[annealer, checkpoint],
               validation_data=(X_val, y_val))
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 27/27 - 20s - loss: 0.9676 - accuracy: 0.5520 - val_loss: 1.1474 - val_accuracy: 0.5020
#
# Epoch 00001: val_loss improved from inf to 1.14738, saving model to model_CNN2.h5
# Epoch 2/100
# 27/27 - 4s - loss: 0.8346 - accuracy: 0.6465 - val_loss: 0.8229 - val_accuracy: 0.5624
#
# Epoch 00002: val_loss improved from 1.14738 to 0.82289, saving model to model_CNN2.h5
# Epoch 3/100
# 27/27 - 4s - loss: 0.7092 - accuracy: 0.6926 - val_loss: 1.3312 - val_accuracy: 0.4980
#
# Epoch 00003: val_loss did not improve from 0.82289
# Epoch 4/100
# 27/27 - 3s - loss: 0.6645 - accuracy: 0.7195 - val_loss: 1.4441 - val_accuracy: 0.4980
#
# Epoch 00004: val_loss did not improve from 0.82289
# Epoch 5/100
# 27/27 - 3s - loss: 0.6441 - accuracy: 0.7362 - val_loss: 0.8177 - val_accuracy: 0.6174
#
# Epoch 00005: val_loss improved from 0.82289 to 0.81765, saving model to model_CNN2.h5
# Epoch 6/100
# 27/27 - 4s - loss: 0.6011 - accuracy: 0.7512 - val_loss: 0.8291 - val_accuracy: 0.6362
#
# Epoch 00006: val_loss did not improve from 0.81765
# Epoch 7/100
# 27/27 - 3s - loss: 0.5511 - accuracy: 0.7679 - val_loss: 0.8637 - val_accuracy: 0.6201
#
# Epoch 00007: val_loss did not improve from 0.81765
# Epoch 8/100
# 27/27 - 4s - loss: 0.5262 - accuracy: 0.7781 - val_loss: 1.0178 - val_accuracy: 0.6040
#
# Epoch 00008: val_loss did not improve from 0.81765
# Epoch 9/100
# 27/27 - 4s - loss: 0.4936 - accuracy: 0.8014 - val_loss: 0.9027 - val_accuracy: 0.6255
#
# Epoch 00009: val_loss did not improve from 0.81765
# Epoch 10/100
# 27/27 - 3s - loss: 0.4751 - accuracy: 0.8092 - val_loss: 0.9829 - val_accuracy: 0.6336
#
# Epoch 00010: val_loss did not improve from 0.81765
# Epoch 11/100
# 27/27 - 3s - loss: 0.4786 - accuracy: 0.8140 - val_loss: 1.0366 - val_accuracy: 0.6228
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
#
# Epoch 00011: val_loss did not improve from 0.81765
# Epoch 12/100
# 27/27 - 4s - loss: 0.4589 - accuracy: 0.8044 - val_loss: 1.1895 - val_accuracy: 0.6013
#
# Epoch 00012: val_loss did not improve from 0.81765
# Epoch 13/100
# 27/27 - 4s - loss: 0.4500 - accuracy: 0.8230 - val_loss: 0.9403 - val_accuracy: 0.6497
#
# Epoch 00013: val_loss did not improve from 0.81765
# Epoch 14/100
# 27/27 - 3s - loss: 0.4232 - accuracy: 0.8355 - val_loss: 0.5299 - val_accuracy: 0.7651
#
# Epoch 00014: val_loss improved from 0.81765 to 0.52993, saving model to model_CNN2.h5
# Epoch 15/100
# 27/27 - 4s - loss: 0.3982 - accuracy: 0.8278 - val_loss: 0.3670 - val_accuracy: 0.8591
#
# Epoch 00015: val_loss improved from 0.52993 to 0.36696, saving model to model_CNN2.h5
# Epoch 16/100
# 27/27 - 4s - loss: 0.4112 - accuracy: 0.8409 - val_loss: 0.4518 - val_accuracy: 0.7611
#
# Epoch 00016: val_loss did not improve from 0.36696
# Epoch 17/100
# 27/27 - 4s - loss: 0.3661 - accuracy: 0.8547 - val_loss: 0.3887 - val_accuracy: 0.8054
#
# Epoch 00017: val_loss did not improve from 0.36696
# Epoch 18/100
# 27/27 - 4s - loss: 0.3903 - accuracy: 0.8529 - val_loss: 0.4506 - val_accuracy: 0.7544
#
# Epoch 00018: val_loss did not improve from 0.36696
# Epoch 19/100
# 27/27 - 4s - loss: 0.3737 - accuracy: 0.8529 - val_loss: 0.7162 - val_accuracy: 0.6094
#
# Epoch 00019: val_loss did not improve from 0.36696
# Epoch 20/100
# 27/27 - 4s - loss: 0.3719 - accuracy: 0.8523 - val_loss: 0.4802 - val_accuracy: 0.7369
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
#
# Epoch 00020: val_loss did not improve from 0.36696
# Epoch 21/100
# 27/27 - 4s - loss: 0.3603 - accuracy: 0.8457 - val_loss: 0.5840 - val_accuracy: 0.6926
#
# Epoch 00021: val_loss did not improve from 0.36696
# Epoch 22/100
# 27/27 - 4s - loss: 0.3524 - accuracy: 0.8612 - val_loss: 0.4455 - val_accuracy: 0.7745
#
# Epoch 00022: val_loss did not improve from 0.36696
# Epoch 23/100
# 27/27 - 4s - loss: 0.3332 - accuracy: 0.8708 - val_loss: 0.5864 - val_accuracy: 0.6966
#
# Epoch 00023: val_loss did not improve from 0.36696
# Epoch 24/100
# 27/27 - 3s - loss: 0.3443 - accuracy: 0.8666 - val_loss: 0.4713 - val_accuracy: 0.7557
#
# Epoch 00024: val_loss did not improve from 0.36696
# Epoch 25/100
# 27/27 - 3s - loss: 0.3403 - accuracy: 0.8690 - val_loss: 0.3847 - val_accuracy: 0.8013
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
#
# Epoch 00025: val_loss did not improve from 0.36696
# Epoch 26/100
# 27/27 - 4s - loss: 0.3394 - accuracy: 0.8750 - val_loss: 0.3680 - val_accuracy: 0.8148
#
# Epoch 00026: val_loss did not improve from 0.36696
# Epoch 27/100
# 27/27 - 4s - loss: 0.3410 - accuracy: 0.8612 - val_loss: 0.3990 - val_accuracy: 0.7973
#
# Epoch 00027: val_loss did not improve from 0.36696
# Epoch 28/100
# 27/27 - 3s - loss: 0.3294 - accuracy: 0.8726 - val_loss: 0.4161 - val_accuracy: 0.7946
#
# Epoch 00028: val_loss did not improve from 0.36696
# Epoch 29/100
# 27/27 - 4s - loss: 0.3569 - accuracy: 0.8589 - val_loss: 0.4960 - val_accuracy: 0.7503
#
# Epoch 00029: val_loss did not improve from 0.36696
# Epoch 30/100
# 27/27 - 4s - loss: 0.3358 - accuracy: 0.8624 - val_loss: 0.3820 - val_accuracy: 0.8081
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00030: val_loss did not improve from 0.36696
# Epoch 31/100
# 27/27 - 4s - loss: 0.3343 - accuracy: 0.8678 - val_loss: 0.3572 - val_accuracy: 0.8282
#
# Epoch 00031: val_loss improved from 0.36696 to 0.35720, saving model to model_CNN2.h5
# Epoch 32/100
# 27/27 - 4s - loss: 0.3565 - accuracy: 0.8523 - val_loss: 0.3687 - val_accuracy: 0.8201
#
# Epoch 00032: val_loss did not improve from 0.35720
# Epoch 33/100
# 27/27 - 4s - loss: 0.3390 - accuracy: 0.8696 - val_loss: 0.3681 - val_accuracy: 0.8174
#
# Epoch 00033: val_loss did not improve from 0.35720
# Epoch 34/100
# 27/27 - 4s - loss: 0.3430 - accuracy: 0.8648 - val_loss: 0.4183 - val_accuracy: 0.7879
#
# Epoch 00034: val_loss did not improve from 0.35720
# Epoch 35/100
# 27/27 - 4s - loss: 0.3534 - accuracy: 0.8559 - val_loss: 0.4175 - val_accuracy: 0.7893
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00035: val_loss did not improve from 0.35720
# Epoch 36/100
# 27/27 - 4s - loss: 0.3307 - accuracy: 0.8660 - val_loss: 0.4564 - val_accuracy: 0.7732
#
# Epoch 00036: val_loss did not improve from 0.35720
# Epoch 37/100
# 27/27 - 4s - loss: 0.3505 - accuracy: 0.8624 - val_loss: 0.3962 - val_accuracy: 0.8040
#
# Epoch 00037: val_loss did not improve from 0.35720
# Epoch 38/100
# 27/27 - 4s - loss: 0.3571 - accuracy: 0.8672 - val_loss: 0.4649 - val_accuracy: 0.7745
#
# Epoch 00038: val_loss did not improve from 0.35720
# Epoch 39/100
# 27/27 - 4s - loss: 0.3301 - accuracy: 0.8640 - val_loss: 0.4319 - val_accuracy: 0.7812
#
# Epoch 00039: val_loss did not improve from 0.35720
# Epoch 40/100
# 27/27 - 4s - loss: 0.3273 - accuracy: 0.8709 - val_loss: 0.4466 - val_accuracy: 0.7772
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00040: val_loss did not improve from 0.35720
# Epoch 41/100
# 27/27 - 4s - loss: 0.3363 - accuracy: 0.8750 - val_loss: 0.4691 - val_accuracy: 0.7664
#
# Epoch 00041: val_loss did not improve from 0.35720
# Epoch 42/100
# 27/27 - 4s - loss: 0.3107 - accuracy: 0.8810 - val_loss: 0.3900 - val_accuracy: 0.8054
#
# Epoch 00042: val_loss did not improve from 0.35720
# Epoch 43/100
# 27/27 - 4s - loss: 0.3215 - accuracy: 0.8708 - val_loss: 0.3874 - val_accuracy: 0.8067
#
# Epoch 00043: val_loss did not improve from 0.35720
# Epoch 44/100
# 27/27 - 4s - loss: 0.3378 - accuracy: 0.8684 - val_loss: 0.3529 - val_accuracy: 0.8336
#
# Epoch 00044: val_loss improved from 0.35720 to 0.35293, saving model to model_CNN2.h5
# Epoch 45/100
# 27/27 - 4s - loss: 0.3397 - accuracy: 0.8702 - val_loss: 0.3094 - val_accuracy: 0.8765
#
# Epoch 00045: val_loss improved from 0.35293 to 0.30944, saving model to model_CNN2.h5
# Epoch 46/100
# 27/27 - 4s - loss: 0.3264 - accuracy: 0.8792 - val_loss: 0.3598 - val_accuracy: 0.8255
#
# Epoch 00046: val_loss did not improve from 0.30944
# Epoch 47/100
# 27/27 - 4s - loss: 0.3250 - accuracy: 0.8696 - val_loss: 0.3578 - val_accuracy: 0.8282
#
# Epoch 00047: val_loss did not improve from 0.30944
# Epoch 48/100
# 27/27 - 4s - loss: 0.3317 - accuracy: 0.8678 - val_loss: 0.3283 - val_accuracy: 0.8537
#
# Epoch 00048: val_loss did not improve from 0.30944
# Epoch 49/100
# 27/27 - 3s - loss: 0.3104 - accuracy: 0.8774 - val_loss: 0.3214 - val_accuracy: 0.8523
#
# Epoch 00049: val_loss did not improve from 0.30944
# Epoch 50/100
# 27/27 - 4s - loss: 0.2989 - accuracy: 0.8866 - val_loss: 0.3351 - val_accuracy: 0.8523
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00050: val_loss did not improve from 0.30944
# Epoch 51/100
# 27/27 - 4s - loss: 0.3349 - accuracy: 0.8690 - val_loss: 0.3824 - val_accuracy: 0.8121
#
# Epoch 00051: val_loss did not improve from 0.30944
# Epoch 52/100
# 27/27 - 4s - loss: 0.3331 - accuracy: 0.8623 - val_loss: 0.3284 - val_accuracy: 0.8537
#
# Epoch 00052: val_loss did not improve from 0.30944
# Epoch 53/100
# 27/27 - 4s - loss: 0.3018 - accuracy: 0.8864 - val_loss: 0.3060 - val_accuracy: 0.8644
#
# Epoch 00053: val_loss improved from 0.30944 to 0.30595, saving model to model_CNN2.h5
# Epoch 54/100
# 27/27 - 4s - loss: 0.2932 - accuracy: 0.8917 - val_loss: 0.2713 - val_accuracy: 0.9034
#
# Epoch 00054: val_loss improved from 0.30595 to 0.27126, saving model to model_CNN2.h5
# Epoch 55/100
# 27/27 - 4s - loss: 0.3324 - accuracy: 0.8654 - val_loss: 0.2783 - val_accuracy: 0.8966
#
# Epoch 00055: val_loss did not improve from 0.27126
# Epoch 56/100
# 27/27 - 4s - loss: 0.3110 - accuracy: 0.8744 - val_loss: 0.3191 - val_accuracy: 0.8537
#
# Epoch 00056: val_loss did not improve from 0.27126
# Epoch 57/100
# 27/27 - 4s - loss: 0.3220 - accuracy: 0.8738 - val_loss: 0.3261 - val_accuracy: 0.8537
#
# Epoch 00057: val_loss did not improve from 0.27126
# Epoch 58/100
# 27/27 - 4s - loss: 0.3063 - accuracy: 0.8780 - val_loss: 0.3506 - val_accuracy: 0.8255
#
# Epoch 00058: val_loss did not improve from 0.27126
# Epoch 59/100
# 27/27 - 4s - loss: 0.3006 - accuracy: 0.8810 - val_loss: 0.3982 - val_accuracy: 0.8000
#
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00059: val_loss did not improve from 0.27126
# Epoch 60/100
# 27/27 - 4s - loss: 0.3246 - accuracy: 0.8714 - val_loss: 0.3289 - val_accuracy: 0.8430
#
# Epoch 00060: val_loss did not improve from 0.27126
# Epoch 61/100
# 27/27 - 4s - loss: 0.3064 - accuracy: 0.8810 - val_loss: 0.3111 - val_accuracy: 0.8537
#
# Epoch 00061: val_loss did not improve from 0.27126
# Epoch 62/100
# 27/27 - 4s - loss: 0.3111 - accuracy: 0.8774 - val_loss: 0.3099 - val_accuracy: 0.8604
#
# Epoch 00062: val_loss did not improve from 0.27126
# Epoch 63/100
# 27/27 - 4s - loss: 0.3041 - accuracy: 0.8846 - val_loss: 0.3017 - val_accuracy: 0.8658
#
# Epoch 00063: val_loss did not improve from 0.27126
# Epoch 64/100
# 27/27 - 4s - loss: 0.2997 - accuracy: 0.8816 - val_loss: 0.3954 - val_accuracy: 0.7987
#
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00064: val_loss did not improve from 0.27126
# Epoch 65/100
# 27/27 - 4s - loss: 0.3134 - accuracy: 0.8768 - val_loss: 0.3728 - val_accuracy: 0.8107
#
# Epoch 00065: val_loss did not improve from 0.27126
# Epoch 66/100
# 27/27 - 4s - loss: 0.3137 - accuracy: 0.8750 - val_loss: 0.3885 - val_accuracy: 0.7987
#
# Epoch 00066: val_loss did not improve from 0.27126
# Epoch 67/100
# 27/27 - 4s - loss: 0.3031 - accuracy: 0.8822 - val_loss: 0.3063 - val_accuracy: 0.8537
#
# Epoch 00067: val_loss did not improve from 0.27126
# Epoch 68/100
# 27/27 - 4s - loss: 0.3289 - accuracy: 0.8738 - val_loss: 0.3080 - val_accuracy: 0.8604
#
# Epoch 00068: val_loss did not improve from 0.27126
# Epoch 69/100
# 27/27 - 4s - loss: 0.3110 - accuracy: 0.8834 - val_loss: 0.2834 - val_accuracy: 0.8872
#
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00069: val_loss did not improve from 0.27126
# Epoch 70/100
# 27/27 - 4s - loss: 0.2910 - accuracy: 0.8834 - val_loss: 0.3101 - val_accuracy: 0.8497
#
# Epoch 00070: val_loss did not improve from 0.27126
# Epoch 71/100
# 27/27 - 4s - loss: 0.3122 - accuracy: 0.8768 - val_loss: 0.3259 - val_accuracy: 0.8443
#
# Epoch 00071: val_loss did not improve from 0.27126
# Epoch 72/100
# 27/27 - 3s - loss: 0.3045 - accuracy: 0.8852 - val_loss: 0.3396 - val_accuracy: 0.8282
#
# Epoch 00072: val_loss did not improve from 0.27126
# Epoch 73/100
# 27/27 - 4s - loss: 0.3044 - accuracy: 0.8774 - val_loss: 0.4019 - val_accuracy: 0.7893
#
# Epoch 00073: val_loss did not improve from 0.27126
# Epoch 74/100
# 27/27 - 4s - loss: 0.3067 - accuracy: 0.8738 - val_loss: 0.3936 - val_accuracy: 0.8000
#
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00074: val_loss did not improve from 0.27126
# Epoch 75/100
# 27/27 - 4s - loss: 0.2929 - accuracy: 0.8876 - val_loss: 0.3285 - val_accuracy: 0.8376
#
# Epoch 00075: val_loss did not improve from 0.27126
# Epoch 76/100
# 27/27 - 3s - loss: 0.2978 - accuracy: 0.8744 - val_loss: 0.3780 - val_accuracy: 0.8067
#
# Epoch 00076: val_loss did not improve from 0.27126
# Epoch 77/100
# 27/27 - 3s - loss: 0.3027 - accuracy: 0.8828 - val_loss: 0.3464 - val_accuracy: 0.8349
#
# Epoch 00077: val_loss did not improve from 0.27126
# Epoch 78/100
# 27/27 - 3s - loss: 0.2861 - accuracy: 0.8923 - val_loss: 0.3173 - val_accuracy: 0.8564
#
# Epoch 00078: val_loss did not improve from 0.27126
# Epoch 79/100
# 27/27 - 4s - loss: 0.2857 - accuracy: 0.8858 - val_loss: 0.3363 - val_accuracy: 0.8389
#
# Epoch 00079: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00079: val_loss did not improve from 0.27126
# Epoch 80/100
# 27/27 - 4s - loss: 0.2927 - accuracy: 0.8888 - val_loss: 0.4038 - val_accuracy: 0.7919
#
# Epoch 00080: val_loss did not improve from 0.27126
# Epoch 81/100
# 27/27 - 4s - loss: 0.3007 - accuracy: 0.8810 - val_loss: 0.4900 - val_accuracy: 0.7597
#
# Epoch 00081: val_loss did not improve from 0.27126
# Epoch 82/100
# 27/27 - 4s - loss: 0.2936 - accuracy: 0.8798 - val_loss: 0.3828 - val_accuracy: 0.7973
#
# Epoch 00082: val_loss did not improve from 0.27126
# Epoch 83/100
# 27/27 - 4s - loss: 0.2856 - accuracy: 0.8876 - val_loss: 0.3370 - val_accuracy: 0.8282
#
# Epoch 00083: val_loss did not improve from 0.27126
# Epoch 84/100
# 27/27 - 4s - loss: 0.2849 - accuracy: 0.8900 - val_loss: 0.2637 - val_accuracy: 0.8966
#
# Epoch 00084: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00084: val_loss improved from 0.27126 to 0.26375, saving model to model_CNN2.h5
# Epoch 85/100
# 27/27 - 4s - loss: 0.2895 - accuracy: 0.8935 - val_loss: 0.2834 - val_accuracy: 0.8832
#
# Epoch 00085: val_loss did not improve from 0.26375
# Epoch 86/100
# 27/27 - 4s - loss: 0.3121 - accuracy: 0.8774 - val_loss: 0.3046 - val_accuracy: 0.8537
#
# Epoch 00086: val_loss did not improve from 0.26375
# Epoch 87/100
# 27/27 - 4s - loss: 0.2912 - accuracy: 0.8864 - val_loss: 0.3041 - val_accuracy: 0.8658
#
# Epoch 00087: val_loss did not improve from 0.26375
# Epoch 88/100
# 27/27 - 4s - loss: 0.2681 - accuracy: 0.8999 - val_loss: 0.2732 - val_accuracy: 0.8886
#
# Epoch 00088: val_loss did not improve from 0.26375
# Epoch 89/100
# 27/27 - 3s - loss: 0.3026 - accuracy: 0.8846 - val_loss: 0.2673 - val_accuracy: 0.8926
#
# Epoch 00089: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00089: val_loss did not improve from 0.26375
# Epoch 90/100
# 27/27 - 4s - loss: 0.2898 - accuracy: 0.8798 - val_loss: 0.2795 - val_accuracy: 0.8899
#
# Epoch 00090: val_loss did not improve from 0.26375
# Epoch 91/100
# 27/27 - 4s - loss: 0.2787 - accuracy: 0.8917 - val_loss: 0.3064 - val_accuracy: 0.8604
#
# Epoch 00091: val_loss did not improve from 0.26375
# Epoch 92/100
# 27/27 - 3s - loss: 0.2823 - accuracy: 0.8888 - val_loss: 0.2619 - val_accuracy: 0.8926
#
# Epoch 00092: val_loss improved from 0.26375 to 0.26187, saving model to model_CNN2.h5
# Epoch 93/100
# 27/27 - 4s - loss: 0.2662 - accuracy: 0.8959 - val_loss: 0.2876 - val_accuracy: 0.8859
#
# Epoch 00093: val_loss did not improve from 0.26187
# Epoch 94/100
# 27/27 - 4s - loss: 0.2873 - accuracy: 0.8828 - val_loss: 0.3368 - val_accuracy: 0.8295
#
# Epoch 00094: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00094: val_loss did not improve from 0.26187
# Epoch 95/100
# 27/27 - 4s - loss: 0.3233 - accuracy: 0.8732 - val_loss: 0.3318 - val_accuracy: 0.8349
#
# Epoch 00095: val_loss did not improve from 0.26187
# Epoch 96/100
# 27/27 - 4s - loss: 0.3027 - accuracy: 0.8888 - val_loss: 0.3338 - val_accuracy: 0.8295
#
# Epoch 00096: val_loss did not improve from 0.26187
# Epoch 97/100
# 27/27 - 3s - loss: 0.2980 - accuracy: 0.8840 - val_loss: 0.3036 - val_accuracy: 0.8685
#
# Epoch 00097: val_loss did not improve from 0.26187
# Epoch 98/100
# 27/27 - 4s - loss: 0.2848 - accuracy: 0.8870 - val_loss: 0.3045 - val_accuracy: 0.8671
#
# Epoch 00098: val_loss did not improve from 0.26187
# Epoch 99/100
# 27/27 - 4s - loss: 0.2834 - accuracy: 0.8917 - val_loss: 0.3527 - val_accuracy: 0.8215
#
# Epoch 00099: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00099: val_loss did not improve from 0.26187
# Epoch 100/100
# 27/27 - 4s - loss: 0.2955 - accuracy: 0.8804 - val_loss: 0.3304 - val_accuracy: 0.8309
#
# Epoch 00100: val_loss did not improve from 0.26187

# %%
print("training_accuracy   = ", hist.history['accuracy'][-1])
print("validation_accuracy = ", hist.history['val_accuracy'][-1])
print("training_loss   = ", hist.history['loss'][-1])
print("validation_loss = ", hist.history['val_loss'][-1])
# Out:
# training_accuracy   =  0.880382776260376
# validation_accuracy =  0.8308724761009216
# training_loss   =  0.29549795389175415
# validation_loss =  0.33039581775665283

# %%
# Accuracy ve Loss değerlerinin görselleştirilmeleri

plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy ~ SGD')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss ~ SGD')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from keras.models import Sequential
from keras.layers import Dense

y_pred = np.argmax(model.predict(X_val), axis=-1)
y_test= np.argmax(y_val,axis=1)


# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy: %f' % accuracy)
# precision tp / (tp + fp)
precision = precision_score(y_test, y_pred)
print('Precision: %f' % precision)
# recall: tp / (tp + fn)
recall = recall_score(y_test, y_pred)
print('Recall: %f' % recall)
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(y_test, y_pred)
print('F1 score: %f' % f1)

#kappa
kappa = cohen_kappa_score(y_test, y_pred)
print('Cohens kappa: %f' % kappa)
# ROC AUC
auc = roc_auc_score(y_test, y_pred)
print('ROC AUC: %f' % auc)

# precision
pre=precision_score(y_test, y_pred)
print('Precision =  %.3f'%pre)

# confusion matrix
cf = confusion_matrix(y_test, y_pred)
print(cf)
# Out:
# Accuracy: 0.830872
# Precision: 0.929825
# Recall: 0.714286
# F1 score: 0.807927
# Cohens kappa: 0.661425
# ROC AUC: 0.830405
# Precision =  0.930
# [[354  20]
#  [106 265]]

# %%
# R2 & MSE

def scoreResults(model, x_train, x_test, y_train, y_test):

    y_train_predict = model.predict(x_train)
    y_test_predict = model.predict(x_test)

    r2_train = metrics.r2_score(y_train, y_train_predict)
    r2_test = metrics.r2_score(y_test, y_test_predict)

    mse_train = metrics.mean_squared_error(y_train, y_train_predict)
    mse_test = metrics.mean_squared_error(y_test, y_test_predict)



    return [r2_train, r2_test, mse_train, mse_test]

from sklearn import metrics

lr=model
result_lr = scoreResults(model = lr, x_train = X_train, x_test = X_val, y_train = y_train, y_test = y_val)

print(f"Train R2 Score: {result_lr[0]:.4f} MSE: {result_lr[2]:.4f}")
print(f"Test R2 Score: {result_lr[1]:9.4f} MSE: {result_lr[3]:.4f}")
# Out:
# Train R2 Score: 0.5809 MSE: 0.1047
# Test R2 Score:    0.5188 MSE: 0.1203

# %%
plt.matshow(cf)
plt.title('Confusion Matrix Plot')
plt.colorbar()
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
class_names = ["Covid","non-covid"]

from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(cm, classes, title='Confusion matrix', cmap=plt.cm.Blues):
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    plt.figure(figsize=(10,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="black" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    
# compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=2)

# plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, title='Normalized confusion matrix')
plt.show()

# %%
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

fp1, tp1, threshold1 = roc_curve(y_test, y_pred)


def plotRoc():
    plt.subplots(1, figsize=(10,10))
    plt.title('Receiver Operating Characteristic - DecisionTree')
    plt.plot(fp1, tp1)
    plt.plot([0, 1], ls="--")
    plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()

print('roc_auc_score for Model: ', roc_auc_score(y_test, y_pred))

plotRoc()
# Out:
# roc_auc_score for Model:  0.8304048892284187
