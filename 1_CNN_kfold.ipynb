# %% [markdown]
# # CNN
# Basit bir CNN yapısı uygulayacağız ilk olarak.

# %% [markdown]
# #### Google Colab Doğrulama
#
# 3 tane datasetimiz var. Onlara ulaşabilmek adına doğrulama işlemlerini gerçekleştiriyoruz.

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 145483 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.23-0ubuntu1~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.23-0ubuntu1~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.23-0ubuntu1~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# Bağlanıp bağlanmadığımız görmek amacıyla drive daki çalışma alanımızın içindekileri listele komutunu çalıştırıyoruz.

# %%
ls "/content/drive/My Drive/CT"
# Out:
# checkpoint    denseNet_model_78.h5               my_model_fra.h5  transfer/
# covid/        earlystop_model.h5                 non-covid/       works/
# COVID/        model.h5                           NonCOVID/
# CT_COVID/     model_weights.data-00000-of-00001  Normalize/
# CT_NonCOVID/  model_weights.index                saved_models/

# %% [markdown]
# #### Kütüphaneler

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import cv2
import os
from tqdm import tqdm
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from keras.models import Model,Sequential, Input, load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.applications import DenseNet121, MobileNetV2


from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import numpy as np

from keras.callbacks import ModelCheckpoint, EarlyStopping

# %% [markdown]
# Normalize edilmiş değerleri önceki ipynb dosyamızda npy olarak kaydetmiştik. Bu aşama, işlemlerimizi hızlandırmak için yapıldı. numpy kütüphanesinden load() metodunu çağırarak normalize olmuş datamızı kullanmaya başlayabiliriz.

# %%
a= "/content/drive/My Drive/CT/Normalize/"

#300 veri bulunan dataset
l1x=a+ "X_nparray300.npy"
l1y=a+ "y_nparray300.npy"

#1200 veri bulunan dataset
l2x=a+ "X_nparray1200.npy"
l2y=a+ "y_nparray1200.npy"

#3000 veri bulunan dataset
l3x=a+ "X_nparray3000.npy"
l3y=a+ "y_nparray3000.npy"

loaded_array_x1200 = np.load(l2x)
loaded_array_y1200 = np.load(l2y)

# %%
X=loaded_array_x1200
y=loaded_array_y1200

# %% [markdown]
# Datamızın doğru yüklendiğine emin olmak için shape metodunu kullanarak inceliyoruz.

# %%
print("Shape of input data: {} and shape of target variable: {}".format(X.shape, y.shape))
# Out:
# Shape of input data: (2481, 64, 64, 3) and shape of target variable: (2481, 2)

# %% [markdown]
# Verisetimiz üzerinde kaç tane forward ve backward propagation yapılacağını ayarladığımız apoch sayımızı 50,100 ve 200 vereceğiz.
#
# Tüm veri kümesini aynı anda sinir ağına veremeyeceğimiz için dataseti parçalara böleriz. Yani batch size olarak adlandırdığımız bu hiperparametre üzerinde çalışılacak bir parti örneğin miktarını bize söyler. Burada 64'er adet image lar halinde modelimize göndereceğiz.

# %%
EPOCHS = 50
# 50, 100, 200
SIZE=64
N_ch=3
BATCH_SIZE = 64
SEED= 42

IMG_W= 64
IMG_H= 64
CHANNELS = 3

INPUT_SHAPE=(IMG_W, IMG_H, CHANNELS)

# %% [markdown]
# # CNN Modelimiz

# %%
def build_CNN():
  model = Sequential()



  model.add(Conv2D(input_shape= INPUT_SHAPE,filters=64,kernel_size=(3,3),padding="same", activation="relu"))
  model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
  model.add(Conv2D(filters=256,kernel_size=(3,3),padding="same", activation="relu"))
  model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
  model.add(Dropout(0.5)) 
  model.add(Conv2D(filters=256,kernel_size=(3,3),padding="same", activation="relu"))
  model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
  model.add(Conv2D(filters=256,kernel_size=(3,3),padding="same", activation="relu"))
  model.add(Dropout(0.5)) 
  model.add(Conv2D(filters=528,kernel_size=(3,3),padding="same", activation="relu"))
  model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))


  model.add(Flatten())
  model.add(Dense(units=128,activation="relu"))
  model.add(Dense(units=64,activation="relu"))
  model.add(Dense(units=32,activation="relu"))
  model.add(Dense(units=2, activation="softmax"))

  # optimizer = Adam(lr=0.03, beta_1=0.9, beta_2=0.999, epsilon=0.1, decay=0.0)
  optimizer= "adam"
  model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
  model.summary()
  
  return model

# %%
model=build_CNN()
# Modelimizi görselleştirelim
from keras.utils import plot_model

plot_model(model, 
           show_shapes = True, 
           show_layer_names = True, 
           rankdir = 'TB', 
           expand_nested = False, 
           dpi = 60)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 64, 64, 64)        1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 256)       147712
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 256)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 256)       590080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 528)         1217040
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 528)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8448)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               1081472
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 66
# =================================================================
# Total params: 3,638,578
# Trainable params: 3,638,578
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # k-fold

# %%
datagen = ImageDataGenerator(rotation_range=360, # rotasyon
                        width_shift_range=0.2, # yatayda shift
                        height_shift_range=0.2, # dikeyde kayma
                        zoom_range=0.2, # büyültme
                        horizontal_flip=True, # yatayda çevirme
                        vertical_flip=True)  #dikeyde çevirme

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold, train_test_split, cross_val_predict, cross_val_score
from sklearn import metrics
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import median_absolute_error

fprs, tprs, scores = [], [], []
toplamAcc=[]
toplamAccV=[]
toplamLoss=[]
toplamLossV=[]



k = 5
iter = 1 # düzgün gözükmesi için yapıyoruz
# datamızı 5 farklı şekilde bölüyoruz.
cv = KFold(n_splits=k, random_state = 0, shuffle=True)

for train_index, test_index in cv.split(X):
    
    X_train, X_val, y_train, y_val = X[train_index], X[test_index], y[train_index], y[test_index]


    annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
    checkpoint = ModelCheckpoint('model_CNN_kfold.h5', verbose=1, save_best_only=True)

    datagen.fit(X_train)
    
    # Modeli gerçek zamanlı artırılan datalarla eğitiyoruz.
    history = model.fit_generator(datagen.flow(X_train, y_train, batch_size=BATCH_SIZE),
                  steps_per_epoch=X_train.shape[0] // BATCH_SIZE,
                  epochs=EPOCHS,
                  verbose=2,
                  callbacks=[annealer, checkpoint],
                  validation_data=(X_val, y_val))


    print(f"{iter}. veri kesiti")
    iter += 1


    a=history.history['accuracy'][-1]
    vA=history.history['val_accuracy'][-1]
    l=history.history['loss'][-1]
    vL=history.history['val_loss'][-1]

    toplamAcc.append(a)
    toplamAccV.append(vA)
    toplamLoss.append(l)
    toplamLossV.append(vL)
    
    
    plt.show()
    print(f"training_accuracy  : {a}" )
    print(f"validation_accuracy: {vA}")

    print(f"training_loss:   {l}")
    print(f"validation_loss: {vL}")

    print('____________________________________________________________________')
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/50
# 31/31 - 3s - loss: 0.6931 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00001: val_loss improved from inf to 0.69319, saving model to model_CNN_kfold.h5
# Epoch 2/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00002: val_loss did not improve from 0.69319
# Epoch 3/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00003: val_loss improved from 0.69319 to 0.69318, saving model to model_CNN_kfold.h5
# Epoch 4/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00004: val_loss improved from 0.69318 to 0.69317, saving model to model_CNN_kfold.h5
# Epoch 5/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00005: val_loss did not improve from 0.69317
# Epoch 6/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00006: val_loss did not improve from 0.69317
# Epoch 7/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00007: val_loss did not improve from 0.69317
# Epoch 8/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00008: val_loss did not improve from 0.69317
# Epoch 9/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00009: val_loss did not improve from 0.69317
# Epoch 10/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00010: val_loss improved from 0.69317 to 0.69316, saving model to model_CNN_kfold.h5
# Epoch 11/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00011: val_loss did not improve from 0.69316
# Epoch 12/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00012: val_loss did not improve from 0.69316
# Epoch 13/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00013: val_loss did not improve from 0.69316
# Epoch 14/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00014: val_loss did not improve from 0.69316
# Epoch 15/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00015: val_loss did not improve from 0.69316
# Epoch 16/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00016: val_loss did not improve from 0.69316
# Epoch 17/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00017: val_loss did not improve from 0.69316
# Epoch 18/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00018: val_loss did not improve from 0.69316
# Epoch 19/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00019: val_loss did not improve from 0.69316
# Epoch 20/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00020: val_loss did not improve from 0.69316
# Epoch 21/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00021: val_loss did not improve from 0.69316
# Epoch 22/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00022: val_loss did not improve from 0.69316
# Epoch 23/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00023: val_loss did not improve from 0.69316
# Epoch 24/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00024: val_loss did not improve from 0.69316
# Epoch 25/50
# 31/31 - 2s - loss: 0.6933 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00025: val_loss improved from 0.69316 to 0.69316, saving model to model_CNN_kfold.h5
# Epoch 26/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00026: val_loss did not improve from 0.69316
# Epoch 27/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00027: val_loss did not improve from 0.69316
# Epoch 28/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00028: val_loss did not improve from 0.69316
# Epoch 29/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00029: val_loss did not improve from 0.69316
# Epoch 30/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00030: val_loss did not improve from 0.69316
# Epoch 31/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00031: val_loss did not improve from 0.69316
# Epoch 32/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00032: val_loss did not improve from 0.69316
# Epoch 33/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00033: val_loss did not improve from 0.69316
# Epoch 34/50
# 31/31 - 3s - loss: 0.6931 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00034: val_loss did not improve from 0.69316
# Epoch 35/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00035: val_loss did not improve from 0.69316
# Epoch 36/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00036: val_loss did not improve from 0.69316
# Epoch 37/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00037: val_loss did not improve from 0.69316
# Epoch 38/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00038: val_loss did not improve from 0.69316
# Epoch 39/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00039: val_loss did not improve from 0.69316
# Epoch 40/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00040: val_loss improved from 0.69316 to 0.69315, saving model to model_CNN_kfold.h5
# Epoch 41/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00041: val_loss did not improve from 0.69315
# Epoch 42/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00042: val_loss did not improve from 0.69315
# Epoch 43/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00043: val_loss did not improve from 0.69315
# Epoch 44/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00044: val_loss did not improve from 0.69315
# Epoch 45/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00045: val_loss did not improve from 0.69315
# Epoch 46/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00046: val_loss did not improve from 0.69315
# Epoch 47/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00047: val_loss did not improve from 0.69315
# Epoch 48/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00048: val_loss did not improve from 0.69315
# Epoch 49/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00049: val_loss did not improve from 0.69315
# Epoch 50/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5055 - val_loss: 0.6932 - val_accuracy: 0.5010
#
# Epoch 00050: val_loss did not improve from 0.69315
# 1. veri kesiti
# training_accuracy  : 0.5055443644523621
# validation_accuracy: 0.501006007194519
# training_loss:   0.6931214332580566
# validation_loss: 0.6931648850440979
# ____________________________________________________________________
# Epoch 1/50
# 31/31 - 3s - loss: 0.6932 - accuracy: 0.4966 - val_loss: 0.6932 - val_accuracy: 0.4899
#
# Epoch 00001: val_loss improved from inf to 0.69321, saving model to model_CNN_kfold.h5
# Epoch 2/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4961 - val_loss: 0.6933 - val_accuracy: 0.4899
#
# Epoch 00002: val_loss did not improve from 0.69321
# Epoch 3/50
# 31/31 - 2s - loss: 0.6933 - accuracy: 0.4846 - val_loss: 0.6931 - val_accuracy: 0.5101
#
# Epoch 00003: val_loss improved from 0.69321 to 0.69309, saving model to model_CNN_kfold.h5
# Epoch 4/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5039 - val_loss: 0.6931 - val_accuracy: 0.5101
#
# Epoch 00004: val_loss improved from 0.69309 to 0.69306, saving model to model_CNN_kfold.h5
# Epoch 5/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5013 - val_loss: 0.6931 - val_accuracy: 0.5101
#
# Epoch 00005: val_loss did not improve from 0.69306
# Epoch 6/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5034 - val_loss: 0.6930 - val_accuracy: 0.5101
#
# Epoch 00006: val_loss improved from 0.69306 to 0.69298, saving model to model_CNN_kfold.h5
# Epoch 7/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5039 - val_loss: 0.6930 - val_accuracy: 0.5101
#
# Epoch 00007: val_loss improved from 0.69298 to 0.69297, saving model to model_CNN_kfold.h5
# Epoch 8/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5029 - val_loss: 0.6930 - val_accuracy: 0.5101
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00008: val_loss improved from 0.69297 to 0.69296, saving model to model_CNN_kfold.h5
# Epoch 9/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5013 - val_loss: 0.6930 - val_accuracy: 0.5101
#
# Epoch 00009: val_loss did not improve from 0.69296
# Epoch 10/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5039 - val_loss: 0.6930 - val_accuracy: 0.5101
#
# Epoch 00010: val_loss did not improve from 0.69296
# Epoch 11/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5049 - val_loss: 0.6931 - val_accuracy: 0.5101
#
# Epoch 00011: val_loss did not improve from 0.69296
# Epoch 12/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5029 - val_loss: 0.6931 - val_accuracy: 0.5101
#
# Epoch 00012: val_loss did not improve from 0.69296
# Epoch 13/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5055 - val_loss: 0.6931 - val_accuracy: 0.5101
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00013: val_loss did not improve from 0.69296
# Epoch 14/50
# 31/31 - 2s - loss: 0.6933 - accuracy: 0.4742 - val_loss: 0.6932 - val_accuracy: 0.4899
#
# Epoch 00014: val_loss did not improve from 0.69296
# Epoch 15/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4935 - val_loss: 0.6932 - val_accuracy: 0.4899
#
# Epoch 00015: val_loss did not improve from 0.69296
# Epoch 16/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5091 - val_loss: 0.6931 - val_accuracy: 0.5101
#
# Epoch 00016: val_loss did not improve from 0.69296
# Epoch 17/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5008 - val_loss: 0.6931 - val_accuracy: 0.5101
#
# Epoch 00017: val_loss did not improve from 0.69296
# Epoch 18/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5070 - val_loss: 0.6931 - val_accuracy: 0.5101
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00018: val_loss did not improve from 0.69296
# Epoch 19/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5055 - val_loss: 0.6931 - val_accuracy: 0.5101
#
# Epoch 00019: val_loss did not improve from 0.69296
# Epoch 20/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5049 - val_loss: 0.6931 - val_accuracy: 0.5101
#
# Epoch 00020: val_loss did not improve from 0.69296
# Epoch 21/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.4992 - val_loss: 0.6932 - val_accuracy: 0.4899
#
# Epoch 00021: val_loss did not improve from 0.69296
# Epoch 22/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4965 - val_loss: 0.6933 - val_accuracy: 0.4899
#
# Epoch 00022: val_loss did not improve from 0.69296
# Epoch 23/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4971 - val_loss: 0.6932 - val_accuracy: 0.4899
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00023: val_loss did not improve from 0.69296
# Epoch 24/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.4987 - val_loss: 0.6931 - val_accuracy: 0.5101
#
# Epoch 00024: val_loss did not improve from 0.69296
# Epoch 25/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5075 - val_loss: 0.6931 - val_accuracy: 0.5101
#
# Epoch 00025: val_loss did not improve from 0.69296
# Epoch 26/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5055 - val_loss: 0.6931 - val_accuracy: 0.5101
#
# Epoch 00026: val_loss did not improve from 0.69296
# Epoch 27/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5023 - val_loss: 0.6932 - val_accuracy: 0.4899
#
# Epoch 00027: val_loss did not improve from 0.69296
# Epoch 28/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4977 - val_loss: 0.6933 - val_accuracy: 0.4899
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00028: val_loss did not improve from 0.69296
# Epoch 29/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4971 - val_loss: 0.6934 - val_accuracy: 0.4899
#
# Epoch 00029: val_loss did not improve from 0.69296
# Epoch 30/50
# 31/31 - 2s - loss: 0.6933 - accuracy: 0.4971 - val_loss: 0.6934 - val_accuracy: 0.4899
#
# Epoch 00030: val_loss did not improve from 0.69296
# Epoch 31/50
# 31/31 - 2s - loss: 0.6933 - accuracy: 0.4956 - val_loss: 0.6933 - val_accuracy: 0.4899
#
# Epoch 00031: val_loss did not improve from 0.69296
# Epoch 32/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4971 - val_loss: 0.6933 - val_accuracy: 0.4899
#
# Epoch 00032: val_loss did not improve from 0.69296
# Epoch 33/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4961 - val_loss: 0.6932 - val_accuracy: 0.4899
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00033: val_loss did not improve from 0.69296
# Epoch 34/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4966 - val_loss: 0.6933 - val_accuracy: 0.4899
#
# Epoch 00034: val_loss did not improve from 0.69296
# Epoch 35/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4930 - val_loss: 0.6932 - val_accuracy: 0.4899
#
# Epoch 00035: val_loss did not improve from 0.69296
# Epoch 36/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5003 - val_loss: 0.6932 - val_accuracy: 0.4899
#
# Epoch 00036: val_loss did not improve from 0.69296
# Epoch 37/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4951 - val_loss: 0.6932 - val_accuracy: 0.4899
#
# Epoch 00037: val_loss did not improve from 0.69296
# Epoch 38/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5044 - val_loss: 0.6931 - val_accuracy: 0.5101
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00038: val_loss did not improve from 0.69296
# Epoch 39/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5029 - val_loss: 0.6930 - val_accuracy: 0.5101
#
# Epoch 00039: val_loss did not improve from 0.69296
# Epoch 40/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5034 - val_loss: 0.6930 - val_accuracy: 0.5101
#
# Epoch 00040: val_loss did not improve from 0.69296
# Epoch 41/50
# 31/31 - 2s - loss: 0.6933 - accuracy: 0.4997 - val_loss: 0.6930 - val_accuracy: 0.5101
#
# Epoch 00041: val_loss did not improve from 0.69296
# Epoch 42/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5029 - val_loss: 0.6930 - val_accuracy: 0.5101
#
# Epoch 00042: val_loss did not improve from 0.69296
# Epoch 43/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5013 - val_loss: 0.6930 - val_accuracy: 0.5101
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00043: val_loss did not improve from 0.69296
# Epoch 44/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5023 - val_loss: 0.6930 - val_accuracy: 0.5101
#
# Epoch 00044: val_loss did not improve from 0.69296
# Epoch 45/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5049 - val_loss: 0.6930 - val_accuracy: 0.5101
#
# Epoch 00045: val_loss did not improve from 0.69296
# Epoch 46/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5013 - val_loss: 0.6931 - val_accuracy: 0.5101
#
# Epoch 00046: val_loss did not improve from 0.69296
# Epoch 47/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5034 - val_loss: 0.6931 - val_accuracy: 0.5101
#
# Epoch 00047: val_loss did not improve from 0.69296
# Epoch 48/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5044 - val_loss: 0.6931 - val_accuracy: 0.5101
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00048: val_loss did not improve from 0.69296
# Epoch 49/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5018 - val_loss: 0.6930 - val_accuracy: 0.5101
#
# Epoch 00049: val_loss did not improve from 0.69296
# Epoch 50/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5044 - val_loss: 0.6930 - val_accuracy: 0.5101
#
# Epoch 00050: val_loss did not improve from 0.69296
# 2. veri kesiti
# training_accuracy  : 0.5044247508049011
# validation_accuracy: 0.5100806355476379
# training_loss:   0.6931220889091492
# validation_loss: 0.6930066347122192
# ____________________________________________________________________
# Epoch 1/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4992 - val_loss: 0.6927 - val_accuracy: 0.5242
#
# Epoch 00001: val_loss improved from inf to 0.69270, saving model to model_CNN_kfold.h5
# Epoch 2/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5008 - val_loss: 0.6928 - val_accuracy: 0.5242
#
# Epoch 00002: val_loss did not improve from 0.69270
# Epoch 3/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4987 - val_loss: 0.6928 - val_accuracy: 0.5242
#
# Epoch 00003: val_loss did not improve from 0.69270
# Epoch 4/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5003 - val_loss: 0.6927 - val_accuracy: 0.5242
#
# Epoch 00004: val_loss did not improve from 0.69270
# Epoch 5/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4987 - val_loss: 0.6927 - val_accuracy: 0.5242
#
# Epoch 00005: val_loss improved from 0.69270 to 0.69269, saving model to model_CNN_kfold.h5
# Epoch 6/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5013 - val_loss: 0.6928 - val_accuracy: 0.5242
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00006: val_loss did not improve from 0.69269
# Epoch 7/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4992 - val_loss: 0.6927 - val_accuracy: 0.5242
#
# Epoch 00007: val_loss did not improve from 0.69269
# Epoch 8/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4995 - val_loss: 0.6927 - val_accuracy: 0.5242
#
# Epoch 00008: val_loss improved from 0.69269 to 0.69268, saving model to model_CNN_kfold.h5
# Epoch 9/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5023 - val_loss: 0.6927 - val_accuracy: 0.5242
#
# Epoch 00009: val_loss improved from 0.69268 to 0.69266, saving model to model_CNN_kfold.h5
# Epoch 10/50
# 31/31 - 2s - loss: 0.6933 - accuracy: 0.4966 - val_loss: 0.6927 - val_accuracy: 0.5242
#
# Epoch 00010: val_loss did not improve from 0.69266
# Epoch 11/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4992 - val_loss: 0.6929 - val_accuracy: 0.5242
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00011: val_loss did not improve from 0.69266
# Epoch 12/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5008 - val_loss: 0.6930 - val_accuracy: 0.5242
#
# Epoch 00012: val_loss did not improve from 0.69266
# Epoch 13/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4961 - val_loss: 0.6931 - val_accuracy: 0.5242
#
# Epoch 00013: val_loss did not improve from 0.69266
# Epoch 14/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5003 - val_loss: 0.6929 - val_accuracy: 0.5242
#
# Epoch 00014: val_loss did not improve from 0.69266
# Epoch 15/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5008 - val_loss: 0.6930 - val_accuracy: 0.5242
#
# Epoch 00015: val_loss did not improve from 0.69266
# Epoch 16/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6930 - val_accuracy: 0.5242
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00016: val_loss did not improve from 0.69266
# Epoch 17/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4987 - val_loss: 0.6931 - val_accuracy: 0.5242
#
# Epoch 00017: val_loss did not improve from 0.69266
# Epoch 18/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4992 - val_loss: 0.6930 - val_accuracy: 0.5242
#
# Epoch 00018: val_loss did not improve from 0.69266
# Epoch 19/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4961 - val_loss: 0.6931 - val_accuracy: 0.5242
#
# Epoch 00019: val_loss did not improve from 0.69266
# Epoch 20/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4966 - val_loss: 0.6933 - val_accuracy: 0.4758
#
# Epoch 00020: val_loss did not improve from 0.69266
# Epoch 21/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5003 - val_loss: 0.6932 - val_accuracy: 0.4758
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00021: val_loss did not improve from 0.69266
# Epoch 22/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5018 - val_loss: 0.6931 - val_accuracy: 0.5242
#
# Epoch 00022: val_loss did not improve from 0.69266
# Epoch 23/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4945 - val_loss: 0.6932 - val_accuracy: 0.4758
#
# Epoch 00023: val_loss did not improve from 0.69266
# Epoch 24/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.4951 - val_loss: 0.6933 - val_accuracy: 0.4758
#
# Epoch 00024: val_loss did not improve from 0.69266
# Epoch 25/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4992 - val_loss: 0.6934 - val_accuracy: 0.4758
#
# Epoch 00025: val_loss did not improve from 0.69266
# Epoch 26/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5008 - val_loss: 0.6933 - val_accuracy: 0.4758
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00026: val_loss did not improve from 0.69266
# Epoch 27/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5034 - val_loss: 0.6932 - val_accuracy: 0.4758
#
# Epoch 00027: val_loss did not improve from 0.69266
# Epoch 28/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4794 - val_loss: 0.6931 - val_accuracy: 0.5242
#
# Epoch 00028: val_loss did not improve from 0.69266
# Epoch 29/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5023 - val_loss: 0.6931 - val_accuracy: 0.5242
#
# Epoch 00029: val_loss did not improve from 0.69266
# Epoch 30/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5112 - val_loss: 0.6932 - val_accuracy: 0.4758
#
# Epoch 00030: val_loss did not improve from 0.69266
# Epoch 31/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5003 - val_loss: 0.6934 - val_accuracy: 0.4758
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00031: val_loss did not improve from 0.69266
# Epoch 32/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5039 - val_loss: 0.6933 - val_accuracy: 0.4758
#
# Epoch 00032: val_loss did not improve from 0.69266
# Epoch 33/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4997 - val_loss: 0.6932 - val_accuracy: 0.4758
#
# Epoch 00033: val_loss did not improve from 0.69266
# Epoch 34/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5003 - val_loss: 0.6933 - val_accuracy: 0.4758
#
# Epoch 00034: val_loss did not improve from 0.69266
# Epoch 35/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4997 - val_loss: 0.6932 - val_accuracy: 0.4758
#
# Epoch 00035: val_loss did not improve from 0.69266
# Epoch 36/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5008 - val_loss: 0.6933 - val_accuracy: 0.4758
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00036: val_loss did not improve from 0.69266
# Epoch 37/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4945 - val_loss: 0.6931 - val_accuracy: 0.5242
#
# Epoch 00037: val_loss did not improve from 0.69266
# Epoch 38/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5065 - val_loss: 0.6932 - val_accuracy: 0.4758
#
# Epoch 00038: val_loss did not improve from 0.69266
# Epoch 39/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4997 - val_loss: 0.6932 - val_accuracy: 0.4758
#
# Epoch 00039: val_loss did not improve from 0.69266
# Epoch 40/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5008 - val_loss: 0.6933 - val_accuracy: 0.4758
#
# Epoch 00040: val_loss did not improve from 0.69266
# Epoch 41/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.4987 - val_loss: 0.6932 - val_accuracy: 0.4758
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00041: val_loss did not improve from 0.69266
# Epoch 42/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4898 - val_loss: 0.6931 - val_accuracy: 0.5242
#
# Epoch 00042: val_loss did not improve from 0.69266
# Epoch 43/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4997 - val_loss: 0.6930 - val_accuracy: 0.5242
#
# Epoch 00043: val_loss did not improve from 0.69266
# Epoch 44/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5049 - val_loss: 0.6933 - val_accuracy: 0.4758
#
# Epoch 00044: val_loss did not improve from 0.69266
# Epoch 45/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5013 - val_loss: 0.6933 - val_accuracy: 0.4758
#
# Epoch 00045: val_loss did not improve from 0.69266
# Epoch 46/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4951 - val_loss: 0.6932 - val_accuracy: 0.4758
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00046: val_loss did not improve from 0.69266
# Epoch 47/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4935 - val_loss: 0.6931 - val_accuracy: 0.5242
#
# Epoch 00047: val_loss did not improve from 0.69266
# Epoch 48/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.4997 - val_loss: 0.6931 - val_accuracy: 0.5242
#
# Epoch 00048: val_loss did not improve from 0.69266
# Epoch 49/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5003 - val_loss: 0.6929 - val_accuracy: 0.5242
#
# Epoch 00049: val_loss did not improve from 0.69266
# Epoch 50/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4987 - val_loss: 0.6930 - val_accuracy: 0.5242
#
# Epoch 00050: val_loss did not improve from 0.69266
# 3. veri kesiti
# training_accuracy  : 0.4986985921859741
# validation_accuracy: 0.524193525314331
# training_loss:   0.6931865215301514
# validation_loss: 0.6929938793182373
# ____________________________________________________________________
# Epoch 1/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5039 - val_loss: 0.6931 - val_accuracy: 0.5081
#
# Epoch 00001: val_loss improved from inf to 0.69312, saving model to model_CNN_kfold.h5
# Epoch 2/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5008 - val_loss: 0.6931 - val_accuracy: 0.5081
#
# Epoch 00002: val_loss did not improve from 0.69312
# Epoch 3/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5003 - val_loss: 0.6931 - val_accuracy: 0.5081
#
# Epoch 00003: val_loss improved from 0.69312 to 0.69308, saving model to model_CNN_kfold.h5
# Epoch 4/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5039 - val_loss: 0.6931 - val_accuracy: 0.5081
#
# Epoch 00004: val_loss did not improve from 0.69308
# Epoch 5/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4982 - val_loss: 0.6931 - val_accuracy: 0.5081
#
# Epoch 00005: val_loss did not improve from 0.69308
# Epoch 6/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4925 - val_loss: 0.6932 - val_accuracy: 0.4919
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00006: val_loss did not improve from 0.69308
# Epoch 7/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4961 - val_loss: 0.6932 - val_accuracy: 0.4919
#
# Epoch 00007: val_loss did not improve from 0.69308
# Epoch 8/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5013 - val_loss: 0.6933 - val_accuracy: 0.4919
#
# Epoch 00008: val_loss did not improve from 0.69308
# Epoch 9/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4992 - val_loss: 0.6933 - val_accuracy: 0.4919
#
# Epoch 00009: val_loss did not improve from 0.69308
# Epoch 10/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4961 - val_loss: 0.6932 - val_accuracy: 0.4919
#
# Epoch 00010: val_loss did not improve from 0.69308
# Epoch 11/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4977 - val_loss: 0.6933 - val_accuracy: 0.4919
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00011: val_loss did not improve from 0.69308
# Epoch 12/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4930 - val_loss: 0.6932 - val_accuracy: 0.4919
#
# Epoch 00012: val_loss did not improve from 0.69308
# Epoch 13/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4956 - val_loss: 0.6932 - val_accuracy: 0.4919
#
# Epoch 00013: val_loss did not improve from 0.69308
# Epoch 14/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4997 - val_loss: 0.6932 - val_accuracy: 0.4919
#
# Epoch 00014: val_loss did not improve from 0.69308
# Epoch 15/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4971 - val_loss: 0.6932 - val_accuracy: 0.4919
#
# Epoch 00015: val_loss did not improve from 0.69308
# Epoch 16/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4898 - val_loss: 0.6931 - val_accuracy: 0.5081
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00016: val_loss did not improve from 0.69308
# Epoch 17/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4961 - val_loss: 0.6932 - val_accuracy: 0.4919
#
# Epoch 00017: val_loss did not improve from 0.69308
# Epoch 18/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4935 - val_loss: 0.6931 - val_accuracy: 0.5081
#
# Epoch 00018: val_loss did not improve from 0.69308
# Epoch 19/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4997 - val_loss: 0.6931 - val_accuracy: 0.5081
#
# Epoch 00019: val_loss did not improve from 0.69308
# Epoch 20/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5049 - val_loss: 0.6931 - val_accuracy: 0.5081
#
# Epoch 00020: val_loss improved from 0.69308 to 0.69308, saving model to model_CNN_kfold.h5
# Epoch 21/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5039 - val_loss: 0.6931 - val_accuracy: 0.5081
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00021: val_loss improved from 0.69308 to 0.69308, saving model to model_CNN_kfold.h5
# Epoch 22/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5034 - val_loss: 0.6931 - val_accuracy: 0.5081
#
# Epoch 00022: val_loss did not improve from 0.69308
# Epoch 23/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5044 - val_loss: 0.6931 - val_accuracy: 0.5081
#
# Epoch 00023: val_loss did not improve from 0.69308
# Epoch 24/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5065 - val_loss: 0.6931 - val_accuracy: 0.5081
#
# Epoch 00024: val_loss did not improve from 0.69308
# Epoch 25/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5034 - val_loss: 0.6931 - val_accuracy: 0.5081
#
# Epoch 00025: val_loss did not improve from 0.69308
# Epoch 26/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.4992 - val_loss: 0.6931 - val_accuracy: 0.5081
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00026: val_loss did not improve from 0.69308
# Epoch 27/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5049 - val_loss: 0.6931 - val_accuracy: 0.5081
#
# Epoch 00027: val_loss improved from 0.69308 to 0.69308, saving model to model_CNN_kfold.h5
# Epoch 28/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5029 - val_loss: 0.6931 - val_accuracy: 0.5081
#
# Epoch 00028: val_loss improved from 0.69308 to 0.69305, saving model to model_CNN_kfold.h5
# Epoch 29/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5049 - val_loss: 0.6931 - val_accuracy: 0.5081
#
# Epoch 00029: val_loss did not improve from 0.69305
# Epoch 30/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5044 - val_loss: 0.6931 - val_accuracy: 0.5081
#
# Epoch 00030: val_loss improved from 0.69305 to 0.69305, saving model to model_CNN_kfold.h5
# Epoch 31/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5013 - val_loss: 0.6930 - val_accuracy: 0.5081
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00031: val_loss improved from 0.69305 to 0.69304, saving model to model_CNN_kfold.h5
# Epoch 32/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5039 - val_loss: 0.6930 - val_accuracy: 0.5081
#
# Epoch 00032: val_loss improved from 0.69304 to 0.69303, saving model to model_CNN_kfold.h5
# Epoch 33/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5040 - val_loss: 0.6930 - val_accuracy: 0.5081
#
# Epoch 00033: val_loss did not improve from 0.69303
# Epoch 34/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5034 - val_loss: 0.6930 - val_accuracy: 0.5081
#
# Epoch 00034: val_loss did not improve from 0.69303
# Epoch 35/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5018 - val_loss: 0.6931 - val_accuracy: 0.5081
#
# Epoch 00035: val_loss did not improve from 0.69303
# Epoch 36/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5060 - val_loss: 0.6930 - val_accuracy: 0.5081
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00036: val_loss did not improve from 0.69303
# Epoch 37/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5049 - val_loss: 0.6930 - val_accuracy: 0.5081
#
# Epoch 00037: val_loss did not improve from 0.69303
# Epoch 38/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5039 - val_loss: 0.6930 - val_accuracy: 0.5081
#
# Epoch 00038: val_loss improved from 0.69303 to 0.69302, saving model to model_CNN_kfold.h5
# Epoch 39/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5018 - val_loss: 0.6930 - val_accuracy: 0.5081
#
# Epoch 00039: val_loss improved from 0.69302 to 0.69302, saving model to model_CNN_kfold.h5
# Epoch 40/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5039 - val_loss: 0.6930 - val_accuracy: 0.5081
#
# Epoch 00040: val_loss did not improve from 0.69302
# Epoch 41/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5013 - val_loss: 0.6930 - val_accuracy: 0.5081
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00041: val_loss did not improve from 0.69302
# Epoch 42/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5018 - val_loss: 0.6930 - val_accuracy: 0.5081
#
# Epoch 00042: val_loss did not improve from 0.69302
# Epoch 43/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5023 - val_loss: 0.6930 - val_accuracy: 0.5081
#
# Epoch 00043: val_loss did not improve from 0.69302
# Epoch 44/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5039 - val_loss: 0.6930 - val_accuracy: 0.5081
#
# Epoch 00044: val_loss did not improve from 0.69302
# Epoch 45/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5034 - val_loss: 0.6930 - val_accuracy: 0.5081
#
# Epoch 00045: val_loss improved from 0.69302 to 0.69302, saving model to model_CNN_kfold.h5
# Epoch 46/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5023 - val_loss: 0.6930 - val_accuracy: 0.5081
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00046: val_loss did not improve from 0.69302
# Epoch 47/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5055 - val_loss: 0.6930 - val_accuracy: 0.5081
#
# Epoch 00047: val_loss improved from 0.69302 to 0.69302, saving model to model_CNN_kfold.h5
# Epoch 48/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5013 - val_loss: 0.6930 - val_accuracy: 0.5081
#
# Epoch 00048: val_loss did not improve from 0.69302
# Epoch 49/50
# 31/31 - 2s - loss: 0.6932 - accuracy: 0.5034 - val_loss: 0.6930 - val_accuracy: 0.5081
#
# Epoch 00049: val_loss did not improve from 0.69302
# Epoch 50/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5049 - val_loss: 0.6930 - val_accuracy: 0.5081
#
# Epoch 00050: val_loss did not improve from 0.69302
# 4. veri kesiti
# training_accuracy  : 0.5049453377723694
# validation_accuracy: 0.5080645084381104
# training_loss:   0.6931076645851135
# validation_loss: 0.6930280923843384
# ____________________________________________________________________
# Epoch 1/50
# 31/31 - 2s - loss: 0.6930 - accuracy: 0.5081 - val_loss: 0.6936 - val_accuracy: 0.4798
#
# Epoch 00001: val_loss improved from inf to 0.69360, saving model to model_CNN_kfold.h5
# Epoch 2/50
# 31/31 - 2s - loss: 0.6930 - accuracy: 0.5096 - val_loss: 0.6935 - val_accuracy: 0.4798
#
# Epoch 00002: val_loss improved from 0.69360 to 0.69350, saving model to model_CNN_kfold.h5
# Epoch 3/50
# 31/31 - 2s - loss: 0.6929 - accuracy: 0.5174 - val_loss: 0.6936 - val_accuracy: 0.4798
#
# Epoch 00003: val_loss did not improve from 0.69350
# Epoch 4/50
# 31/31 - 2s - loss: 0.6930 - accuracy: 0.5086 - val_loss: 0.6938 - val_accuracy: 0.4798
#
# Epoch 00004: val_loss did not improve from 0.69350
# Epoch 5/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5065 - val_loss: 0.6939 - val_accuracy: 0.4798
#
# Epoch 00005: val_loss did not improve from 0.69350
# Epoch 6/50
# 31/31 - 2s - loss: 0.6929 - accuracy: 0.5128 - val_loss: 0.6938 - val_accuracy: 0.4798
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00006: val_loss did not improve from 0.69350
# Epoch 7/50
# 31/31 - 2s - loss: 0.6929 - accuracy: 0.5117 - val_loss: 0.6940 - val_accuracy: 0.4798
#
# Epoch 00007: val_loss did not improve from 0.69350
# Epoch 8/50
# 31/31 - 2s - loss: 0.6930 - accuracy: 0.5081 - val_loss: 0.6941 - val_accuracy: 0.4798
#
# Epoch 00008: val_loss did not improve from 0.69350
# Epoch 9/50
# 31/31 - 2s - loss: 0.6930 - accuracy: 0.5096 - val_loss: 0.6942 - val_accuracy: 0.4798
#
# Epoch 00009: val_loss did not improve from 0.69350
# Epoch 10/50
# 31/31 - 2s - loss: 0.6928 - accuracy: 0.5133 - val_loss: 0.6944 - val_accuracy: 0.4798
#
# Epoch 00010: val_loss did not improve from 0.69350
# Epoch 11/50
# 31/31 - 2s - loss: 0.6930 - accuracy: 0.5091 - val_loss: 0.6945 - val_accuracy: 0.4798
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00011: val_loss did not improve from 0.69350
# Epoch 12/50
# 31/31 - 2s - loss: 0.6929 - accuracy: 0.5122 - val_loss: 0.6944 - val_accuracy: 0.4798
#
# Epoch 00012: val_loss did not improve from 0.69350
# Epoch 13/50
# 31/31 - 2s - loss: 0.6929 - accuracy: 0.5107 - val_loss: 0.6946 - val_accuracy: 0.4798
#
# Epoch 00013: val_loss did not improve from 0.69350
# Epoch 14/50
# 31/31 - 2s - loss: 0.6930 - accuracy: 0.5107 - val_loss: 0.6944 - val_accuracy: 0.4798
#
# Epoch 00014: val_loss did not improve from 0.69350
# Epoch 15/50
# 31/31 - 2s - loss: 0.6929 - accuracy: 0.5122 - val_loss: 0.6942 - val_accuracy: 0.4798
#
# Epoch 00015: val_loss did not improve from 0.69350
# Epoch 16/50
# 31/31 - 2s - loss: 0.6930 - accuracy: 0.5096 - val_loss: 0.6942 - val_accuracy: 0.4798
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00016: val_loss did not improve from 0.69350
# Epoch 17/50
# 31/31 - 2s - loss: 0.6927 - accuracy: 0.5154 - val_loss: 0.6942 - val_accuracy: 0.4798
#
# Epoch 00017: val_loss did not improve from 0.69350
# Epoch 18/50
# 31/31 - 2s - loss: 0.6930 - accuracy: 0.5102 - val_loss: 0.6941 - val_accuracy: 0.4798
#
# Epoch 00018: val_loss did not improve from 0.69350
# Epoch 19/50
# 31/31 - 2s - loss: 0.6929 - accuracy: 0.5107 - val_loss: 0.6940 - val_accuracy: 0.4798
#
# Epoch 00019: val_loss did not improve from 0.69350
# Epoch 20/50
# 31/31 - 2s - loss: 0.6929 - accuracy: 0.5122 - val_loss: 0.6941 - val_accuracy: 0.4798
#
# Epoch 00020: val_loss did not improve from 0.69350
# Epoch 21/50
# 31/31 - 2s - loss: 0.6929 - accuracy: 0.5122 - val_loss: 0.6943 - val_accuracy: 0.4798
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00021: val_loss did not improve from 0.69350
# Epoch 22/50
# 31/31 - 2s - loss: 0.6928 - accuracy: 0.5128 - val_loss: 0.6945 - val_accuracy: 0.4798
#
# Epoch 00022: val_loss did not improve from 0.69350
# Epoch 23/50
# 31/31 - 2s - loss: 0.6930 - accuracy: 0.5086 - val_loss: 0.6946 - val_accuracy: 0.4798
#
# Epoch 00023: val_loss did not improve from 0.69350
# Epoch 24/50
# 31/31 - 2s - loss: 0.6929 - accuracy: 0.5122 - val_loss: 0.6944 - val_accuracy: 0.4798
#
# Epoch 00024: val_loss did not improve from 0.69350
# Epoch 25/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5070 - val_loss: 0.6945 - val_accuracy: 0.4798
#
# Epoch 00025: val_loss did not improve from 0.69350
# Epoch 26/50
# 31/31 - 2s - loss: 0.6929 - accuracy: 0.5112 - val_loss: 0.6944 - val_accuracy: 0.4798
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00026: val_loss did not improve from 0.69350
# Epoch 27/50
# 31/31 - 2s - loss: 0.6930 - accuracy: 0.5086 - val_loss: 0.6944 - val_accuracy: 0.4798
#
# Epoch 00027: val_loss did not improve from 0.69350
# Epoch 28/50
# 31/31 - 2s - loss: 0.6929 - accuracy: 0.5102 - val_loss: 0.6946 - val_accuracy: 0.4798
#
# Epoch 00028: val_loss did not improve from 0.69350
# Epoch 29/50
# 31/31 - 2s - loss: 0.6929 - accuracy: 0.5122 - val_loss: 0.6947 - val_accuracy: 0.4798
#
# Epoch 00029: val_loss did not improve from 0.69350
# Epoch 30/50
# 31/31 - 2s - loss: 0.6927 - accuracy: 0.5143 - val_loss: 0.6948 - val_accuracy: 0.4798
#
# Epoch 00030: val_loss did not improve from 0.69350
# Epoch 31/50
# 31/31 - 2s - loss: 0.6929 - accuracy: 0.5117 - val_loss: 0.6950 - val_accuracy: 0.4798
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00031: val_loss did not improve from 0.69350
# Epoch 32/50
# 31/31 - 2s - loss: 0.6930 - accuracy: 0.5102 - val_loss: 0.6951 - val_accuracy: 0.4798
#
# Epoch 00032: val_loss did not improve from 0.69350
# Epoch 33/50
# 31/31 - 2s - loss: 0.6930 - accuracy: 0.5112 - val_loss: 0.6952 - val_accuracy: 0.4798
#
# Epoch 00033: val_loss did not improve from 0.69350
# Epoch 34/50
# 31/31 - 2s - loss: 0.6929 - accuracy: 0.5122 - val_loss: 0.6951 - val_accuracy: 0.4798
#
# Epoch 00034: val_loss did not improve from 0.69350
# Epoch 35/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5091 - val_loss: 0.6951 - val_accuracy: 0.4798
#
# Epoch 00035: val_loss did not improve from 0.69350
# Epoch 36/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5096 - val_loss: 0.6949 - val_accuracy: 0.4798
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00036: val_loss did not improve from 0.69350
# Epoch 37/50
# 31/31 - 2s - loss: 0.6929 - accuracy: 0.5117 - val_loss: 0.6946 - val_accuracy: 0.4798
#
# Epoch 00037: val_loss did not improve from 0.69350
# Epoch 38/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5086 - val_loss: 0.6948 - val_accuracy: 0.4798
#
# Epoch 00038: val_loss did not improve from 0.69350
# Epoch 39/50
# 31/31 - 2s - loss: 0.6930 - accuracy: 0.5102 - val_loss: 0.6947 - val_accuracy: 0.4798
#
# Epoch 00039: val_loss did not improve from 0.69350
# Epoch 40/50
# 31/31 - 2s - loss: 0.6929 - accuracy: 0.5122 - val_loss: 0.6946 - val_accuracy: 0.4798
#
# Epoch 00040: val_loss did not improve from 0.69350
# Epoch 41/50
# 31/31 - 2s - loss: 0.6929 - accuracy: 0.5128 - val_loss: 0.6948 - val_accuracy: 0.4798
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00041: val_loss did not improve from 0.69350
# Epoch 42/50
# 31/31 - 2s - loss: 0.6931 - accuracy: 0.5075 - val_loss: 0.6946 - val_accuracy: 0.4798
#
# Epoch 00042: val_loss did not improve from 0.69350
# Epoch 43/50
# 31/31 - 2s - loss: 0.6929 - accuracy: 0.5112 - val_loss: 0.6945 - val_accuracy: 0.4798
#
# Epoch 00043: val_loss did not improve from 0.69350
# Epoch 44/50
# 31/31 - 2s - loss: 0.6930 - accuracy: 0.5107 - val_loss: 0.6945 - val_accuracy: 0.4798
#
# Epoch 00044: val_loss did not improve from 0.69350
# Epoch 45/50
# 31/31 - 2s - loss: 0.6929 - accuracy: 0.5112 - val_loss: 0.6944 - val_accuracy: 0.4798
#
# Epoch 00045: val_loss did not improve from 0.69350
# Epoch 46/50
# 31/31 - 2s - loss: 0.6928 - accuracy: 0.5128 - val_loss: 0.6944 - val_accuracy: 0.4798
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00046: val_loss did not improve from 0.69350
# Epoch 47/50
# 31/31 - 2s - loss: 0.6929 - accuracy: 0.5107 - val_loss: 0.6944 - val_accuracy: 0.4798
#
# Epoch 00047: val_loss did not improve from 0.69350
# Epoch 48/50
# 31/31 - 2s - loss: 0.6930 - accuracy: 0.5102 - val_loss: 0.6942 - val_accuracy: 0.4798
#
# Epoch 00048: val_loss did not improve from 0.69350
# Epoch 49/50
# 31/31 - 2s - loss: 0.6929 - accuracy: 0.5117 - val_loss: 0.6941 - val_accuracy: 0.4798
#
# Epoch 00049: val_loss did not improve from 0.69350
# Epoch 50/50
# 31/31 - 2s - loss: 0.6930 - accuracy: 0.5081 - val_loss: 0.6942 - val_accuracy: 0.4798
#
# Epoch 00050: val_loss did not improve from 0.69350
# 5. veri kesiti
# training_accuracy  : 0.5080687403678894
# validation_accuracy: 0.47983869910240173
# training_loss:   0.693035900592804
# validation_loss: 0.69419926404953
# ____________________________________________________________________

# %% [markdown]
# # K-cross Validation Sonuçlar

# %% [markdown]
# ```
# __________________________________________1. veri kesiti
# training_accuracy  : 0.5055443644523621
# validation_accuracy: 0.501006007194519
# training_loss:   0.6931214332580566
# validation_loss: 0.6931648850440979
# __________________________________________2. veri kesiti
#
# training_accuracy  : 0.5044247508049011
# validation_accuracy: 0.5100806355476379
# training_loss:   0.6931220889091492
# validation_loss: 0.6930066347122192
# __________________________________________3. veri kesiti
#
# training_accuracy  : 0.4986985921859741
# validation_accuracy: 0.524193525314331
# training_loss:   0.6931865215301514
# validation_loss: 0.6929938793182373
# __________________________________________4. veri kesiti
#
# training_accuracy  : 0.5049453377723694
# validation_accuracy: 0.5080645084381104
# training_loss:   0.6931076645851135
# validation_loss: 0.6930280923843384
# __________________________________________5. veri kesiti
#
# training_accuracy  : 0.5080687403678894
# validation_accuracy: 0.47983869910240173
# training_loss:   0.693035900592804
# validation_loss: 0.69419926404953```

# %%
def averages():
  print(f"Average training accuracy  : {np.mean(toplamAcc)}" )
  print(f"Average validation accuracy: {np.mean(toplamAccV)}")

  print(f"Average training loss:   {np.mean(toplamLoss)}")
  print(f"Average validation loss: {np.mean(toplamLossV)}")

averages()
# Out:
# Average training accuracy  : 0.5043363571166992
# Average validation accuracy: 0.5046366751194
# Average training loss:   0.693114721775055
# Average validation loss: 0.6932785511016846

# %%
print("training acc: %.2f%% (+/- %.3f%%)" % (np.mean(toplamAcc), np.std(toplamAcc)))
print("validati acc: %.2f%% (+/- %.3f%%)" % (np.mean(toplamAccV), np.std(toplamAccV)))
print("training loss: %.2f%% (+/- %.3f%%)" % (np.mean(toplamLoss), np.std(toplamLoss)))
print("validati loss: %.2f%% (+/- %.3f%%)" % (np.mean(toplamLossV), np.std(toplamLossV)))
# Out:
# training acc: 0.50% (+/- 0.003%)
# validati acc: 0.50% (+/- 0.015%)
# training loss: 0.69% (+/- 0.000%)
# validati loss: 0.69% (+/- 0.000%)

# %% [markdown]
# ## Accuracy ve Loss değerlerinin görselleştirilmeleri

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# # Sonuçlar

# %% [markdown]
# **Accuracy**:
# **Precision**: Yanlış Pozitifin maliyetinin ne kadar yüksek olduğunu belirlemek için kullanılır.<br>
# ![Untitled.png](data:image/png;base64,...) <br>
# **Recall**: Pozitif olarak etiketleyerek kaç tane Gerçek Pozitif yakalandığını hesaplar.<br>
# ![Untitled(1).png](data:image/png;base64,...)<br>
#
# **F1-score**: Hassasiyet(Precision) ve Recall'un ağırlıklı ortalamasıdır.<br>
# F1 = 2 × (precision × recall) / (precision + recall)
#
# **Cohen's Kappa**:
#
# **ROC AUC**: ROC eğrisinin altında kalan alan olan AUC tahminler doğrulaştıkça 1 noktasına doğru gitme eğilimindedir.
#
# **R2**:

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from keras.models import Sequential
from keras.layers import Dense

y_pred = np.argmax(model.predict(X_val), axis=-1)
y_test= np.argmax(y_val,axis=1)


# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy: %f' % accuracy)
# precision tp / (tp + fp)
precision = precision_score(y_test, y_pred)
print('Precision: %f' % precision)
# recall: tp / (tp + fn)
recall = recall_score(y_test, y_pred)
print('Recall: %f' % recall)
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(y_test, y_pred)
print('F1 score: %f' % f1)

#kappa
kappa = cohen_kappa_score(y_test, y_pred)
print('Cohens kappa: %f' % kappa)
# ROC AUC
auc = roc_auc_score(y_test, y_pred)
print('ROC AUC: %f' % auc)

# precision
pre=precision_score(y_test, y_pred)
print('Precision =  %.3f'%pre)

# confusion matrix
cf = confusion_matrix(y_test, y_pred)
print(cf)
# Out:
# Accuracy: 0.479839
# Precision: 0.000000
# Recall: 0.000000
# F1 score: 0.000000
# Cohens kappa: 0.000000
# ROC AUC: 0.500000
# Precision =  0.000
# [[238   0]
#  [258   0]]
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Karmaşıklık Matrisi

# %%
plt.matshow(cf)
plt.title('Confusion Matrix Plot')
plt.colorbar()
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
class_names = ["Covid","non-covid"]

from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(cm, classes, title='Confusion matrix', cmap=plt.cm.Blues):
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    plt.figure(figsize=(10,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="black" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    
# compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=2)

# plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, title='Normalized confusion matrix')
plt.show()

# %% [markdown]
# #### ROC AUC Score

# %%
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

fp1, tp1, threshold1 = roc_curve(y_test, y_pred)


def plotRoc():
    plt.subplots(1, figsize=(10,10))
    plt.title('Receiver Operating Characteristic - DecisionTree')
    plt.plot(fp1, tp1)
    plt.plot([0, 1], ls="--")
    plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()

print('roc_auc_score for Model: ', roc_auc_score(y_test, y_pred))

plotRoc()
# Out:
# roc_auc_score for Model:  0.5
