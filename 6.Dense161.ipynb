# %% [markdown]
# # DenseNet 161

# %% [markdown]
# #### Google Colab Doğrulama
#
# 3 tane datasetimiz var. Onlara ulaşabilmek adına doğrulama işlemlerini gerçekleştiriyoruz.

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 145483 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.23-0ubuntu1~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.23-0ubuntu1~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.23-0ubuntu1~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# Bağlanıp bağlanmadığımız görmek amacıyla drive daki çalışma alanımızın içindekileri listele komutunu çalıştırıyoruz.

# %%
ls "/content/drive/My Drive/CT"
# Out:
# checkpoint    denseNet_model_78.h5               my_model_fra.h5  transfer/
# covid/        earlystop_model.h5                 non-covid/       works/
# COVID/        model.h5                           NonCOVID/
# CT_COVID/     model_weights.data-00000-of-00001  Normalize/
# CT_NonCOVID/  model_weights.index                saved_models/

# %% [markdown]
# #### Kütüphaneler

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import cv2
import os
from tqdm import tqdm
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from keras.models import Model,Sequential, Input, load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.applications import DenseNet121, MobileNetV2


from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import numpy as np

from keras.callbacks import ModelCheckpoint, EarlyStopping

# %% [markdown]
# Normalize edilmiş değerleri önceki ipynb dosyamızda npy olarak kaydetmiştik. Bu aşama, işlemlerimizi hızlandırmak için yapıldı. numpy kütüphanesinden load() metodunu çağırarak normalize olmuş datamızı kullanmaya başlayabiliriz.

# %%
a= "/content/drive/My Drive/CT/Normalize/"

#300 veri bulunan dataset
l1x=a+ "X_nparray300.npy"
l1y=a+ "y_nparray300.npy"

#1200 veri bulunan dataset
l2x=a+ "X_nparray1200.npy"
l2y=a+ "y_nparray1200.npy"

#3000 veri bulunan dataset
l3x=a+ "X_nparray3000.npy"
l3y=a+ "y_nparray3000.npy"

loaded_array_x1200 = np.load(l2x)
loaded_array_y1200 = np.load(l2y)

# %%
X=loaded_array_x1200
y=loaded_array_y1200

# %% [markdown]
# Datamızın doğru yüklendiğine emin olmak için shape metodunu kullanarak inceliyoruz.

# %%
print("Shape of input data: {} and shape of target variable: {}".format(X.shape, y.shape))
# Out:
# Shape of input data: (2481, 64, 64, 3) and shape of target variable: (2481, 2)

# %%
SEED= 42

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3, random_state=SEED)

# %% [markdown]
# Verisetimiz üzerinde kaç tane forward ve backward propagation yapılacağını ayarladığımız apoch sayımızı 50,100 ve 200 vereceğiz.
#
# Tüm veri kümesini aynı anda sinir ağına veremeyeceğimiz için dataseti parçalara böleriz. Yani batch size olarak adlandırdığımız bu hiperparametre üzerinde çalışılacak bir parti örneğin miktarını bize söyler. Burada 64'er adet image lar halinde modelimize göndereceğiz.

# %%
EPOCHS = 100
# 50, 100, 200
SIZE=64
N_ch=3
BATCH_SIZE = 64
SEED= 42

IMG_W= 64
IMG_H= 64
CHANNELS = 3

INPUT_SHAPE=(IMG_W, IMG_H, CHANNELS)

# %%
from keras.applications.densenet import DenseNet169, preprocess_input
import keras
import tensorflow as tf

def get_model_dense169():
    densenet = DenseNet169(weights='imagenet', include_top=False, input_shape=(64, 64, 3))

    input = Input(shape=(SIZE, SIZE, N_ch))
    x = Conv2D(3, (3, 3), padding='same')(input)
    
    x = densenet(x)
    
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # multi output
    output = Dense(2,activation = 'softmax', name='root')(x)
 

    # model
    model = Model(input,output)
    
    
    optimizer = tf.keras.optimizers.Adagrad(learning_rate=0.001)
 
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    model.summary()
    
    return model

# %%
model=get_model_dense169()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 3)         84
# _________________________________________________________________
# densenet169 (Functional)     (None, 2, 2, 1664)        12642880
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 1664)              0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 1664)              6656
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1664)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               426240
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# root (Dense)                 (None, 2)                 514
# =================================================================
# Total params: 13,077,398
# Trainable params: 12,915,158
# Non-trainable params: 162,240
# _________________________________________________________________

# %%
datagen = ImageDataGenerator(rotation_range=360, # rotasyon
                        width_shift_range=0.2, # yatayda shift
                        height_shift_range=0.2, # dikeyde kayma
                        zoom_range=0.2, # büyültme
                        horizontal_flip=True, # yatayda çevirme
                        vertical_flip=True)  #dikeyde çevirme

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold, train_test_split, cross_val_predict, cross_val_score
from sklearn import metrics
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import median_absolute_error



annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
checkpoint = ModelCheckpoint('model_CNN2.h5', verbose=1, save_best_only=True)



datagen.fit(X_train)

hist = model.fit_generator(datagen.flow(X_train, y_train, batch_size=BATCH_SIZE),
               steps_per_epoch=X_train.shape[0] // BATCH_SIZE,
               epochs=EPOCHS,
               verbose=2,
               callbacks=[annealer, checkpoint],
               validation_data=(X_val, y_val))
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 27/27 - 29s - loss: 1.0078 - accuracy: 0.5215 - val_loss: 0.7181 - val_accuracy: 0.5799
#
# Epoch 00001: val_loss improved from inf to 0.71812, saving model to model_CNN2.h5
# Epoch 2/100
# 27/27 - 3s - loss: 0.9375 - accuracy: 0.5676 - val_loss: 0.7124 - val_accuracy: 0.5933
#
# Epoch 00002: val_loss improved from 0.71812 to 0.71239, saving model to model_CNN2.h5
# Epoch 3/100
# 27/27 - 3s - loss: 0.8968 - accuracy: 0.5897 - val_loss: 0.7058 - val_accuracy: 0.6161
#
# Epoch 00003: val_loss improved from 0.71239 to 0.70584, saving model to model_CNN2.h5
# Epoch 4/100
# 27/27 - 3s - loss: 0.8318 - accuracy: 0.6250 - val_loss: 0.6659 - val_accuracy: 0.6376
#
# Epoch 00004: val_loss improved from 0.70584 to 0.66594, saving model to model_CNN2.h5
# Epoch 5/100
# 27/27 - 3s - loss: 0.8220 - accuracy: 0.6298 - val_loss: 0.6347 - val_accuracy: 0.6698
#
# Epoch 00005: val_loss improved from 0.66594 to 0.63469, saving model to model_CNN2.h5
# Epoch 6/100
# 27/27 - 3s - loss: 0.7866 - accuracy: 0.6567 - val_loss: 0.6086 - val_accuracy: 0.7047
#
# Epoch 00006: val_loss improved from 0.63469 to 0.60863, saving model to model_CNN2.h5
# Epoch 7/100
# 27/27 - 3s - loss: 0.7389 - accuracy: 0.6759 - val_loss: 0.5877 - val_accuracy: 0.7007
#
# Epoch 00007: val_loss improved from 0.60863 to 0.58775, saving model to model_CNN2.h5
# Epoch 8/100
# 27/27 - 3s - loss: 0.7443 - accuracy: 0.6687 - val_loss: 0.5838 - val_accuracy: 0.7087
#
# Epoch 00008: val_loss improved from 0.58775 to 0.58384, saving model to model_CNN2.h5
# Epoch 9/100
# 27/27 - 3s - loss: 0.7215 - accuracy: 0.6902 - val_loss: 0.5508 - val_accuracy: 0.7248
#
# Epoch 00009: val_loss improved from 0.58384 to 0.55076, saving model to model_CNN2.h5
# Epoch 10/100
# 27/27 - 3s - loss: 0.6950 - accuracy: 0.6956 - val_loss: 0.5432 - val_accuracy: 0.7329
#
# Epoch 00010: val_loss improved from 0.55076 to 0.54316, saving model to model_CNN2.h5
# Epoch 11/100
# 27/27 - 3s - loss: 0.6659 - accuracy: 0.7147 - val_loss: 0.5341 - val_accuracy: 0.7503
#
# Epoch 00011: val_loss improved from 0.54316 to 0.53406, saving model to model_CNN2.h5
# Epoch 12/100
# 27/27 - 3s - loss: 0.6756 - accuracy: 0.6980 - val_loss: 0.5193 - val_accuracy: 0.7544
#
# Epoch 00012: val_loss improved from 0.53406 to 0.51928, saving model to model_CNN2.h5
# Epoch 13/100
# 27/27 - 3s - loss: 0.6841 - accuracy: 0.6998 - val_loss: 0.5024 - val_accuracy: 0.7651
#
# Epoch 00013: val_loss improved from 0.51928 to 0.50240, saving model to model_CNN2.h5
# Epoch 14/100
# 27/27 - 3s - loss: 0.6776 - accuracy: 0.7051 - val_loss: 0.4901 - val_accuracy: 0.7758
#
# Epoch 00014: val_loss improved from 0.50240 to 0.49011, saving model to model_CNN2.h5
# Epoch 15/100
# 27/27 - 3s - loss: 0.6426 - accuracy: 0.7333 - val_loss: 0.4833 - val_accuracy: 0.7812
#
# Epoch 00015: val_loss improved from 0.49011 to 0.48326, saving model to model_CNN2.h5
# Epoch 16/100
# 27/27 - 3s - loss: 0.6012 - accuracy: 0.7506 - val_loss: 0.4816 - val_accuracy: 0.7812
#
# Epoch 00016: val_loss improved from 0.48326 to 0.48162, saving model to model_CNN2.h5
# Epoch 17/100
# 27/27 - 3s - loss: 0.6151 - accuracy: 0.7392 - val_loss: 0.4684 - val_accuracy: 0.7826
#
# Epoch 00017: val_loss improved from 0.48162 to 0.46838, saving model to model_CNN2.h5
# Epoch 18/100
# 27/27 - 3s - loss: 0.6067 - accuracy: 0.7476 - val_loss: 0.4599 - val_accuracy: 0.7946
#
# Epoch 00018: val_loss improved from 0.46838 to 0.45989, saving model to model_CNN2.h5
# Epoch 19/100
# 27/27 - 3s - loss: 0.5803 - accuracy: 0.7590 - val_loss: 0.4631 - val_accuracy: 0.8000
#
# Epoch 00019: val_loss did not improve from 0.45989
# Epoch 20/100
# 27/27 - 3s - loss: 0.6038 - accuracy: 0.7297 - val_loss: 0.4548 - val_accuracy: 0.8054
#
# Epoch 00020: val_loss improved from 0.45989 to 0.45482, saving model to model_CNN2.h5
# Epoch 21/100
# 27/27 - 3s - loss: 0.5942 - accuracy: 0.7638 - val_loss: 0.4388 - val_accuracy: 0.8067
#
# Epoch 00021: val_loss improved from 0.45482 to 0.43885, saving model to model_CNN2.h5
# Epoch 22/100
# 27/27 - 3s - loss: 0.5543 - accuracy: 0.7566 - val_loss: 0.4420 - val_accuracy: 0.8121
#
# Epoch 00022: val_loss did not improve from 0.43885
# Epoch 23/100
# 27/27 - 3s - loss: 0.5953 - accuracy: 0.7524 - val_loss: 0.4438 - val_accuracy: 0.8094
#
# Epoch 00023: val_loss did not improve from 0.43885
# Epoch 24/100
# 27/27 - 3s - loss: 0.5712 - accuracy: 0.7697 - val_loss: 0.4426 - val_accuracy: 0.8134
#
# Epoch 00024: val_loss did not improve from 0.43885
# Epoch 25/100
# 27/27 - 3s - loss: 0.5903 - accuracy: 0.7446 - val_loss: 0.4399 - val_accuracy: 0.8121
#
# Epoch 00025: val_loss did not improve from 0.43885
# Epoch 26/100
# 27/27 - 3s - loss: 0.5498 - accuracy: 0.7721 - val_loss: 0.4376 - val_accuracy: 0.8134
#
# Epoch 00026: val_loss improved from 0.43885 to 0.43760, saving model to model_CNN2.h5
# Epoch 27/100
# 27/27 - 3s - loss: 0.5475 - accuracy: 0.7745 - val_loss: 0.4299 - val_accuracy: 0.8336
#
# Epoch 00027: val_loss improved from 0.43760 to 0.42985, saving model to model_CNN2.h5
# Epoch 28/100
# 27/27 - 3s - loss: 0.5342 - accuracy: 0.7673 - val_loss: 0.4197 - val_accuracy: 0.8295
#
# Epoch 00028: val_loss improved from 0.42985 to 0.41969, saving model to model_CNN2.h5
# Epoch 29/100
# 27/27 - 3s - loss: 0.5349 - accuracy: 0.7817 - val_loss: 0.4188 - val_accuracy: 0.8309
#
# Epoch 00029: val_loss improved from 0.41969 to 0.41879, saving model to model_CNN2.h5
# Epoch 30/100
# 27/27 - 3s - loss: 0.5452 - accuracy: 0.7727 - val_loss: 0.4102 - val_accuracy: 0.8349
#
# Epoch 00030: val_loss improved from 0.41879 to 0.41023, saving model to model_CNN2.h5
# Epoch 31/100
# 27/27 - 3s - loss: 0.5094 - accuracy: 0.7996 - val_loss: 0.4103 - val_accuracy: 0.8349
#
# Epoch 00031: val_loss did not improve from 0.41023
# Epoch 32/100
# 27/27 - 3s - loss: 0.5189 - accuracy: 0.7925 - val_loss: 0.3913 - val_accuracy: 0.8443
#
# Epoch 00032: val_loss improved from 0.41023 to 0.39133, saving model to model_CNN2.h5
# Epoch 33/100
# 27/27 - 3s - loss: 0.4992 - accuracy: 0.7919 - val_loss: 0.3958 - val_accuracy: 0.8403
#
# Epoch 00033: val_loss did not improve from 0.39133
# Epoch 34/100
# 27/27 - 3s - loss: 0.5017 - accuracy: 0.7919 - val_loss: 0.4011 - val_accuracy: 0.8282
#
# Epoch 00034: val_loss did not improve from 0.39133
# Epoch 35/100
# 27/27 - 3s - loss: 0.4921 - accuracy: 0.8050 - val_loss: 0.3960 - val_accuracy: 0.8282
#
# Epoch 00035: val_loss did not improve from 0.39133
# Epoch 36/100
# 27/27 - 3s - loss: 0.4839 - accuracy: 0.8122 - val_loss: 0.4169 - val_accuracy: 0.8121
#
# Epoch 00036: val_loss did not improve from 0.39133
# Epoch 37/100
# 27/27 - 3s - loss: 0.4678 - accuracy: 0.8110 - val_loss: 0.4185 - val_accuracy: 0.8121
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00037: val_loss did not improve from 0.39133
# Epoch 38/100
# 27/27 - 3s - loss: 0.4905 - accuracy: 0.7882 - val_loss: 0.4044 - val_accuracy: 0.8107
#
# Epoch 00038: val_loss did not improve from 0.39133
# Epoch 39/100
# 27/27 - 3s - loss: 0.4567 - accuracy: 0.8098 - val_loss: 0.3986 - val_accuracy: 0.8228
#
# Epoch 00039: val_loss did not improve from 0.39133
# Epoch 40/100
# 27/27 - 3s - loss: 0.4648 - accuracy: 0.8176 - val_loss: 0.4103 - val_accuracy: 0.8161
#
# Epoch 00040: val_loss did not improve from 0.39133
# Epoch 41/100
# 27/27 - 3s - loss: 0.4472 - accuracy: 0.8134 - val_loss: 0.3922 - val_accuracy: 0.8322
#
# Epoch 00041: val_loss did not improve from 0.39133
# Epoch 42/100
# 27/27 - 3s - loss: 0.4395 - accuracy: 0.8289 - val_loss: 0.3850 - val_accuracy: 0.8322
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00042: val_loss improved from 0.39133 to 0.38502, saving model to model_CNN2.h5
# Epoch 43/100
# 27/27 - 3s - loss: 0.4559 - accuracy: 0.8140 - val_loss: 0.3924 - val_accuracy: 0.8309
#
# Epoch 00043: val_loss did not improve from 0.38502
# Epoch 44/100
# 27/27 - 3s - loss: 0.4477 - accuracy: 0.8212 - val_loss: 0.4523 - val_accuracy: 0.7893
#
# Epoch 00044: val_loss did not improve from 0.38502
# Epoch 45/100
# 27/27 - 3s - loss: 0.4476 - accuracy: 0.8171 - val_loss: 0.4116 - val_accuracy: 0.8161
#
# Epoch 00045: val_loss did not improve from 0.38502
# Epoch 46/100
# 27/27 - 3s - loss: 0.3952 - accuracy: 0.8451 - val_loss: 0.3859 - val_accuracy: 0.8336
#
# Epoch 00046: val_loss did not improve from 0.38502
# Epoch 47/100
# 27/27 - 3s - loss: 0.4478 - accuracy: 0.8236 - val_loss: 0.3910 - val_accuracy: 0.8336
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00047: val_loss did not improve from 0.38502
# Epoch 48/100
# 27/27 - 3s - loss: 0.4316 - accuracy: 0.8283 - val_loss: 0.3666 - val_accuracy: 0.8376
#
# Epoch 00048: val_loss improved from 0.38502 to 0.36658, saving model to model_CNN2.h5
# Epoch 49/100
# 27/27 - 3s - loss: 0.4337 - accuracy: 0.8301 - val_loss: 0.3845 - val_accuracy: 0.8309
#
# Epoch 00049: val_loss did not improve from 0.36658
# Epoch 50/100
# 27/27 - 3s - loss: 0.4345 - accuracy: 0.8170 - val_loss: 0.4197 - val_accuracy: 0.8107
#
# Epoch 00050: val_loss did not improve from 0.36658
# Epoch 51/100
# 27/27 - 3s - loss: 0.4312 - accuracy: 0.8236 - val_loss: 0.4211 - val_accuracy: 0.8054
#
# Epoch 00051: val_loss did not improve from 0.36658
# Epoch 52/100
# 27/27 - 3s - loss: 0.4217 - accuracy: 0.8355 - val_loss: 0.4377 - val_accuracy: 0.7906
#
# Epoch 00052: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00052: val_loss did not improve from 0.36658
# Epoch 53/100
# 27/27 - 3s - loss: 0.4079 - accuracy: 0.8206 - val_loss: 0.4323 - val_accuracy: 0.8000
#
# Epoch 00053: val_loss did not improve from 0.36658
# Epoch 54/100
# 27/27 - 3s - loss: 0.4098 - accuracy: 0.8301 - val_loss: 0.4811 - val_accuracy: 0.7517
#
# Epoch 00054: val_loss did not improve from 0.36658
# Epoch 55/100
# 27/27 - 3s - loss: 0.4168 - accuracy: 0.8307 - val_loss: 0.4283 - val_accuracy: 0.7973
#
# Epoch 00055: val_loss did not improve from 0.36658
# Epoch 56/100
# 27/27 - 3s - loss: 0.4204 - accuracy: 0.8343 - val_loss: 0.4625 - val_accuracy: 0.7799
#
# Epoch 00056: val_loss did not improve from 0.36658
# Epoch 57/100
# 27/27 - 3s - loss: 0.3943 - accuracy: 0.8397 - val_loss: 0.4056 - val_accuracy: 0.8121
#
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00057: val_loss did not improve from 0.36658
# Epoch 58/100
# 27/27 - 3s - loss: 0.3770 - accuracy: 0.8355 - val_loss: 0.3979 - val_accuracy: 0.8201
#
# Epoch 00058: val_loss did not improve from 0.36658
# Epoch 59/100
# 27/27 - 3s - loss: 0.3946 - accuracy: 0.8361 - val_loss: 0.4268 - val_accuracy: 0.8000
#
# Epoch 00059: val_loss did not improve from 0.36658
# Epoch 60/100
# 27/27 - 3s - loss: 0.4024 - accuracy: 0.8337 - val_loss: 0.4211 - val_accuracy: 0.8040
#
# Epoch 00060: val_loss did not improve from 0.36658
# Epoch 61/100
# 27/27 - 3s - loss: 0.3988 - accuracy: 0.8403 - val_loss: 0.4185 - val_accuracy: 0.8081
#
# Epoch 00061: val_loss did not improve from 0.36658
# Epoch 62/100
# 27/27 - 3s - loss: 0.3882 - accuracy: 0.8445 - val_loss: 0.3890 - val_accuracy: 0.8282
#
# Epoch 00062: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00062: val_loss did not improve from 0.36658
# Epoch 63/100
# 27/27 - 3s - loss: 0.3782 - accuracy: 0.8618 - val_loss: 0.3930 - val_accuracy: 0.8228
#
# Epoch 00063: val_loss did not improve from 0.36658
# Epoch 64/100
# 27/27 - 3s - loss: 0.3944 - accuracy: 0.8337 - val_loss: 0.4591 - val_accuracy: 0.7812
#
# Epoch 00064: val_loss did not improve from 0.36658
# Epoch 65/100
# 27/27 - 3s - loss: 0.3697 - accuracy: 0.8445 - val_loss: 0.4587 - val_accuracy: 0.7826
#
# Epoch 00065: val_loss did not improve from 0.36658
# Epoch 66/100
# 27/27 - 3s - loss: 0.3853 - accuracy: 0.8421 - val_loss: 0.4988 - val_accuracy: 0.7584
#
# Epoch 00066: val_loss did not improve from 0.36658
# Epoch 67/100
# 27/27 - 3s - loss: 0.3650 - accuracy: 0.8523 - val_loss: 0.5256 - val_accuracy: 0.7356
#
# Epoch 00067: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00067: val_loss did not improve from 0.36658
# Epoch 68/100
# 27/27 - 3s - loss: 0.3687 - accuracy: 0.8535 - val_loss: 0.4953 - val_accuracy: 0.7544
#
# Epoch 00068: val_loss did not improve from 0.36658
# Epoch 69/100
# 27/27 - 3s - loss: 0.3885 - accuracy: 0.8367 - val_loss: 0.3904 - val_accuracy: 0.8242
#
# Epoch 00069: val_loss did not improve from 0.36658
# Epoch 70/100
# 27/27 - 3s - loss: 0.3712 - accuracy: 0.8535 - val_loss: 0.4164 - val_accuracy: 0.8148
#
# Epoch 00070: val_loss did not improve from 0.36658
# Epoch 71/100
# 27/27 - 3s - loss: 0.3612 - accuracy: 0.8589 - val_loss: 0.4470 - val_accuracy: 0.7906
#
# Epoch 00071: val_loss did not improve from 0.36658
# Epoch 72/100
# 27/27 - 3s - loss: 0.3825 - accuracy: 0.8505 - val_loss: 0.4033 - val_accuracy: 0.8201
#
# Epoch 00072: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00072: val_loss did not improve from 0.36658
# Epoch 73/100
# 27/27 - 3s - loss: 0.3750 - accuracy: 0.8618 - val_loss: 0.4581 - val_accuracy: 0.7839
#
# Epoch 00073: val_loss did not improve from 0.36658
# Epoch 74/100
# 27/27 - 3s - loss: 0.3829 - accuracy: 0.8481 - val_loss: 0.3475 - val_accuracy: 0.8510
#
# Epoch 00074: val_loss improved from 0.36658 to 0.34746, saving model to model_CNN2.h5
# Epoch 75/100
# 27/27 - 3s - loss: 0.3607 - accuracy: 0.8684 - val_loss: 0.3486 - val_accuracy: 0.8497
#
# Epoch 00075: val_loss did not improve from 0.34746
# Epoch 76/100
# 27/27 - 3s - loss: 0.3598 - accuracy: 0.8600 - val_loss: 0.3477 - val_accuracy: 0.8497
#
# Epoch 00076: val_loss did not improve from 0.34746
# Epoch 77/100
# 27/27 - 3s - loss: 0.3747 - accuracy: 0.8445 - val_loss: 0.4199 - val_accuracy: 0.8134
#
# Epoch 00077: val_loss did not improve from 0.34746
# Epoch 78/100
# 27/27 - 3s - loss: 0.3690 - accuracy: 0.8487 - val_loss: 0.4068 - val_accuracy: 0.8121
#
# Epoch 00078: val_loss did not improve from 0.34746
# Epoch 79/100
# 27/27 - 3s - loss: 0.3668 - accuracy: 0.8529 - val_loss: 0.3893 - val_accuracy: 0.8228
#
# Epoch 00079: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00079: val_loss did not improve from 0.34746
# Epoch 80/100
# 27/27 - 3s - loss: 0.3681 - accuracy: 0.8475 - val_loss: 0.4000 - val_accuracy: 0.8174
#
# Epoch 00080: val_loss did not improve from 0.34746
# Epoch 81/100
# 27/27 - 3s - loss: 0.3412 - accuracy: 0.8666 - val_loss: 0.4185 - val_accuracy: 0.8040
#
# Epoch 00081: val_loss did not improve from 0.34746
# Epoch 82/100
# 27/27 - 3s - loss: 0.3546 - accuracy: 0.8547 - val_loss: 0.3897 - val_accuracy: 0.8215
#
# Epoch 00082: val_loss did not improve from 0.34746
# Epoch 83/100
# 27/27 - 3s - loss: 0.3577 - accuracy: 0.8559 - val_loss: 0.4685 - val_accuracy: 0.7651
#
# Epoch 00083: val_loss did not improve from 0.34746
# Epoch 84/100
# 27/27 - 3s - loss: 0.3385 - accuracy: 0.8618 - val_loss: 0.4662 - val_accuracy: 0.7651
#
# Epoch 00084: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00084: val_loss did not improve from 0.34746
# Epoch 85/100
# 27/27 - 3s - loss: 0.3332 - accuracy: 0.8690 - val_loss: 0.4478 - val_accuracy: 0.7839
#
# Epoch 00085: val_loss did not improve from 0.34746
# Epoch 86/100
# 27/27 - 3s - loss: 0.3293 - accuracy: 0.8684 - val_loss: 0.3733 - val_accuracy: 0.8309
#
# Epoch 00086: val_loss did not improve from 0.34746
# Epoch 87/100
# 27/27 - 3s - loss: 0.3451 - accuracy: 0.8708 - val_loss: 0.4013 - val_accuracy: 0.8121
#
# Epoch 00087: val_loss did not improve from 0.34746
# Epoch 88/100
# 27/27 - 3s - loss: 0.3483 - accuracy: 0.8565 - val_loss: 0.4079 - val_accuracy: 0.8121
#
# Epoch 00088: val_loss did not improve from 0.34746
# Epoch 89/100
# 27/27 - 3s - loss: 0.3370 - accuracy: 0.8672 - val_loss: 0.3897 - val_accuracy: 0.8161
#
# Epoch 00089: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00089: val_loss did not improve from 0.34746
# Epoch 90/100
# 27/27 - 3s - loss: 0.3256 - accuracy: 0.8756 - val_loss: 0.3530 - val_accuracy: 0.8443
#
# Epoch 00090: val_loss did not improve from 0.34746
# Epoch 91/100
# 27/27 - 3s - loss: 0.3464 - accuracy: 0.8630 - val_loss: 0.3945 - val_accuracy: 0.8134
#
# Epoch 00091: val_loss did not improve from 0.34746
# Epoch 92/100
# 27/27 - 3s - loss: 0.3234 - accuracy: 0.8768 - val_loss: 0.3929 - val_accuracy: 0.8148
#
# Epoch 00092: val_loss did not improve from 0.34746
# Epoch 93/100
# 27/27 - 3s - loss: 0.3097 - accuracy: 0.8756 - val_loss: 0.4071 - val_accuracy: 0.8054
#
# Epoch 00093: val_loss did not improve from 0.34746
# Epoch 94/100
# 27/27 - 3s - loss: 0.3405 - accuracy: 0.8678 - val_loss: 0.4568 - val_accuracy: 0.7745
#
# Epoch 00094: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00094: val_loss did not improve from 0.34746
# Epoch 95/100
# 27/27 - 3s - loss: 0.3311 - accuracy: 0.8696 - val_loss: 0.4003 - val_accuracy: 0.8094
#
# Epoch 00095: val_loss did not improve from 0.34746
# Epoch 96/100
# 27/27 - 3s - loss: 0.3597 - accuracy: 0.8636 - val_loss: 0.4431 - val_accuracy: 0.7826
#
# Epoch 00096: val_loss did not improve from 0.34746
# Epoch 97/100
# 27/27 - 3s - loss: 0.3170 - accuracy: 0.8750 - val_loss: 0.3940 - val_accuracy: 0.8134
#
# Epoch 00097: val_loss did not improve from 0.34746
# Epoch 98/100
# 27/27 - 3s - loss: 0.3137 - accuracy: 0.8672 - val_loss: 0.4530 - val_accuracy: 0.7758
#
# Epoch 00098: val_loss did not improve from 0.34746
# Epoch 99/100
# 27/27 - 3s - loss: 0.3273 - accuracy: 0.8756 - val_loss: 0.4202 - val_accuracy: 0.8027
#
# Epoch 00099: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00099: val_loss did not improve from 0.34746
# Epoch 100/100
# 27/27 - 3s - loss: 0.3337 - accuracy: 0.8732 - val_loss: 0.4023 - val_accuracy: 0.8107
#
# Epoch 00100: val_loss did not improve from 0.34746

# %%
print("training_accuracy   = ", hist.history['accuracy'][-1])
print("validation_accuracy = ", hist.history['val_accuracy'][-1])
print("training_loss   = ", hist.history['loss'][-1])
print("validation_loss = ", hist.history['val_loss'][-1])
# Out:
# training_accuracy   =  0.8732057213783264
# validation_accuracy =  0.8107382655143738
# training_loss   =  0.33370548486709595
# validation_loss =  0.4022791087627411

# %%
# Accuracy ve Loss değerlerinin görselleştirilmeleri

plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy ~ Adagrad')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss ~ Adagrad')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from keras.models import Sequential
from keras.layers import Dense

y_pred = np.argmax(model.predict(X_val), axis=-1)
y_test= np.argmax(y_val,axis=1)


# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy: %f' % accuracy)
# precision tp / (tp + fp)
precision = precision_score(y_test, y_pred)
print('Precision: %f' % precision)
# recall: tp / (tp + fn)
recall = recall_score(y_test, y_pred)
print('Recall: %f' % recall)
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(y_test, y_pred)
print('F1 score: %f' % f1)

#kappa
kappa = cohen_kappa_score(y_test, y_pred)
print('Cohens kappa: %f' % kappa)
# ROC AUC
auc = roc_auc_score(y_test, y_pred)
print('ROC AUC: %f' % auc)

# precision
pre=precision_score(y_test, y_pred)
print('Precision =  %.3f'%pre)

# confusion matrix
cf = confusion_matrix(y_test, y_pred)
print(cf)
# Out:
# Accuracy: 0.810738
# Precision: 0.916667
# Recall: 0.681941
# F1 score: 0.782071
# Cohens kappa: 0.621081
# ROC AUC: 0.810222
# Precision =  0.917
# [[351  23]
#  [118 253]]

# %%
# R2 & MSE

def scoreResults(model, x_train, x_test, y_train, y_test):

    y_train_predict = model.predict(x_train)
    y_test_predict = model.predict(x_test)

    r2_train = metrics.r2_score(y_train, y_train_predict)
    r2_test = metrics.r2_score(y_test, y_test_predict)

    mse_train = metrics.mean_squared_error(y_train, y_train_predict)
    mse_test = metrics.mean_squared_error(y_test, y_test_predict)



    return [r2_train, r2_test, mse_train, mse_test]

from sklearn import metrics

lr=model
result_lr = scoreResults(model = lr, x_train = X_train, x_test = X_val, y_train = y_train, y_test = y_val)

print(f"Train R2 Score: {result_lr[0]:.4f} MSE: {result_lr[2]:.4f}")
print(f"Test R2 Score: {result_lr[1]:9.4f} MSE: {result_lr[3]:.4f}")
# Out:
# Train R2 Score: 0.5208 MSE: 0.1198
# Test R2 Score:    0.4046 MSE: 0.1489

# %% [markdown]
# ### Karmaşıklık Matrisi

# %%
plt.matshow(cf)
plt.title('Confusion Matrix Plot')
plt.colorbar()
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
class_names = ["Covid","non-covid"]

from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(cm, classes, title='Confusion matrix', cmap=plt.cm.Blues):
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    plt.figure(figsize=(10,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="black" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    
# compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=2)

# plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, title='Normalized confusion matrix')
plt.show()

# %% [markdown]
# #### ROC AUC Score

# %%
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

fp1, tp1, threshold1 = roc_curve(y_test, y_pred)


def plotRoc():
    plt.subplots(1, figsize=(10,10))
    plt.title('Receiver Operating Characteristic - DecisionTree')
    plt.plot(fp1, tp1)
    plt.plot([0, 1], ls="--")
    plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()

print('roc_auc_score for Model: ', roc_auc_score(y_test, y_pred))

plotRoc()
# Out:
# roc_auc_score for Model:  0.8102216873027084
